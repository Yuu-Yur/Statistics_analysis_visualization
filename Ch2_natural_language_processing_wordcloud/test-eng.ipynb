# %% [markdown]
# # 영문 분석 -> 워드 클라우드로 그리기(시각화)
#
# ## 샘플 데이터 영문 학술 문서의 제목만 추출, 그 단어의 빈도 분석 시각화
# ## 데이터 수집 : Big data 키워드로 검색 후, 해당 학술 연구 정보 서비스에서 수집 해보기.
# ## 조합, pandas.concat(), 정제 re 정규식, 기본적인 유효성 체크.
# ## 변환 : word_tokenize(), lower(),
# ## matplotlib.pyplot 이용하기.
# ## 단어 빈도 구해주는 Counter() 이용.
#
# ## 비정형 빅데이터 분석을 말하고 -> 자연어 처리 (nature language processing )
# ## 자연어 처리 예) 음성, 텍스트 정보 추출.
#
# ## 단어 빈도를 추출해서, 해당 단어 시각화하기.

# %% [markdown]
# # 관련 단어 용어 정리
# ## 텍스트 분석: 자연어 처리와 데이터 마이닝 결합하여 발전되었고,
# ## 비정형 텍스트 데이터에서 정보를 추출하는 분석 방법.
# ## 분석 방법 : 1) 텍스트 분류 2) 텍스트 군집화 3) 감성 분석.
#
# ## 전처리 : 분석 작업의 정확도를 높이기 위해서 사용할 데이터 정리하고 변환하는 작업.
# ### 수행하는 작업
# ### 정제 (cleaning): 불필요한 기호, 문자 필터하는 작업, 정규식을 이용해서 작업을 함.
# ### 정규화 ( normallization) : 형태가 다른 단어를 특정의 형태로 변환 작업 , 대문자, 소문자 통합 하는 작업, 의미가 비슷한 단어끼리 통합작업.
# ### 토큰화 (tokenization) : 토큰으로 정하는 기본 단위로 분리 작업. 문장 기준, 단어 기준이 될수 도 있다.
# ### 불용어제거(stopword) : 의미 있는 단어를 추출하기 위해서, 조사, 관사, 접미사, 접두사 등. 제거하는 작업.
# ### 어간 추출(semming) : 단수, 복수, 진행형(시제), 분리하는 작업
# ### 표제어 추출(lemmatization ): 단어의 기본형 형태로 일반화 하는 작업.
# ### 예)
# ### Gone -> go
# ### am -> be
# ### going -> go
#
# ## 워드클라우드 : 텍스트 분석에서 빈도를 시각화 할 때 많이 사용됨.

# %% [markdown]
# # 데이터 수집
# # 한국교육학술정보원 (KERIS)의 RISS 사이트
# # https://www.riss.kr/index.do
# # Big data 검색해보기.
# # 한 페이지당 100개씩 내보내기 엑셀 파일 간략 정보 , 반복 10번
# # 1000개의 데이터에서 제목만 추출 및 분류 작업하기.

# %% [markdown]
# # 데이터 준비 작업.
# # 제목 컬럼 빈도 분석 해보기.

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from wordcloud) (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\it\anaconda3\envs\pytorch\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
# 관련 패키지들 임포트 하기. 
import pandas as pd 
# 경로 이름 지정해서 파일 처리할 때 사용하는 도구
import glob 
# 정규 표현식에 사용하는 도구 
import re 
# 2차원 리스트를 -> 1차원 리스트로 차원 축소시 사용하는 도구 
from functools import reduce
# 자연어 처리 패키지 중에서, 단어 토큰화 작업.
from nltk.tokenize import word_tokenize
# 불용어 처리 작업. 
from nltk.corpus import stopwords 
# 표제어 추출 
from nltk.stem import WordNetLemmatizer 
# 단어의 빈도를 추출하는 도구. 
from collections import Counter 
import matplotlib.pyplot as plt
# 단어의 빈도수를 시각화하는 도구, 빈도가 높을수록 글자 크기가 커짐. 
from wordcloud import STOPWORDS, WordCloud

# %%
# 데이터 조합(병합)하기. 
# 현재 폴더 내부에 있는 , 받았던 엑셀 파일명 10개를 선택하기. 
# all_files = glob.glob("./myCabinetExcelData*.xls")
all_files = glob.glob("./exportExcelData_*.xls")
all_files

# 엑셀 파일 읽어서 -> 데이터 프레임 (표형태) 변환 ->특정 리스트에 담아두기 
# 임시로 저장할 리스트 변수 
all_files_data = []

# all_files 에 담겨진 엑셀 파일의 위치가 들어있고, 
# 해당 위치의 엑셀 파일을 읽어서, 데이터 프레임 표 형태로 변환하기. 
# 임시 리스트에 담기. 
for file in all_files:
  # 해당 엑셀 파일의 위치의 물리 파일 읽기
  data_frame = pd.read_excel(file)
  # 임시 리스트에 담기. 
  all_files_data.append(data_frame)

# 샘플 확인 해보기., 첫번째 요소 확인 해보기. 
# all_files_data = [엑셀1,엑셀2,엑셀3,...엑셀10]
all_files_data[0]

# 오류 발생, 모듈 미설치 : xlrd
# cmd -> pip install xlrd
# Out:
#     Unnamed: 0   번호                                                 제목  \
# 0          NaN    1                        A Holistic View of Big Data
# 1          NaN    2  A Big Data-Driven Business Data Analysis Syste...
# 2          NaN    3  IoT-Based Health Big-Data Process Technologies...
# 3          NaN    4  Big-Data Analysis for Manufacturing Processes ...
# 4          NaN    5  Analysis of Big-Data from Manufacturing Proces...
# ..         ...  ...                                                ...
# 95         NaN   96  Applying a sensor energy supply communication ...
# 96         NaN   97  Identifying the Effect of Product Types in the...
# 97         NaN   98  Informatics in emergency medicine -Big Data & ...
# 98         NaN   99  Modulation of senoinflammation by calorie rest...
# 99         NaN  100  Developing an Intrusion Detection Framework fo...
#
#                      저자         출판사   출판일
# 0              Kim, Won  IGI Global  2014
# 1                   김동근  사)한국빅데이터학회  2023
# 2          ( Hyun Yoo )   한국인터넷정보학회  2021
# 3      ( Seongsu Park )     한국목재공학회  2021
# 4      ( Seongsu Park )     한국목재공학회  2022
# ..                  ...         ...   ...
# 95     ( Zhigang Chen )   한국인터넷정보학회  2016
# 96           ( Lin Li )   한국인터넷정보학회  2018
# 97                  김홍기     대한응급의학회  2013
# 98      ( Eunjin Bang )   생화학분자생물학회  2019
# 99  ( Kamran Siddique )   한국인터넷정보학회  2018
#
# [100 rows x 6 columns]

# %%
# 엑셀 파일 10개를 병합해서 출력해보기. 
# axis=0 , 세로 방향으로 , 밑으로 데이터를 붙이는 작업. 
all_files_data_concat = pd.concat(all_files_data, axis=0, ignore_index=True)
print(f"all_files_data_concat.shape : {all_files_data_concat.shape}")

# 병합된 파일을 csv 파일로 변환하기. 
all_files_data_concat.to_csv("./riss_Bigdata_2025.csv", encoding="utf-8", index=False)
# Out:
# all_files_data_concat.shape : (1000, 6)

# %%
# 전처리 작업 하기. 
# 데이터 프레임에서 제목 열만 추출 
all_title = all_files_data_concat["제목"]
all_title

#불용어 제거 
# set(), 기본적으로 중복 제거

# NLTK(Natural Language Toolkit) 라이브러리의 stopwords 모듈에서
# 영어에 해당하는 불용어 리스트를 가져옵니다.
# 불용어는 "the", "is", "in" 등처럼 분석에 크게 기여하지 않는, 자주 등장하는 단어들을 의미합니다.
stopWords = set(stopwords.words("english"))

# lemma 작업 -> 표제어 추출, 영어, 시제를 제거하고, 원형(사전식 단어 추출)
lemma = WordNetLemmatizer()

# %%
# 임시로 담을 변수, 
words = []

# 기본적인 , 단어 추출(전처리 작업.)
for title in all_title:
  # 영문자, 대 소문자를 제외한 나머지 문자는 모두 공백으로 처리하겠다. 
  print(f"과정1 title 원본: {title}")
  enWords = re.sub(r"[^a-zA-Z]+"," ",str(title))
  print(f"과정2 title enWords(re: 대소문자남기기): {enWords}")
  # 남은 영문자를 -> 모두 소문자 변환하고 -> 각단어를 토큰으로 각각 분리 작업. 
  enWordsToken = word_tokenize(enWords.lower())
  print(f"과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): {enWordsToken}")
  # 컴프리헨션 파이썬 스타일 코드로 , 리스로 변경하기. 
  
  # 불용어 제거 작업, 조사, 관사 등 제거하는 작업. -> 오타:stopwords -> stopWords
  enWordsTokenStop= [w for w in enWordsToken if w not in stopWords]
  print(f"과정4 title enWordsTokenStop(불용어 제거): {enWordsTokenStop}")

  # 표제어 추출 작업. 
  enWordsTokenStopLemma = [lemma.lemmatize(w) for w in enWordsTokenStop]
  print(f"과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): {enWordsTokenStopLemma}")

  words.append(enWordsTokenStopLemma)
  
print(f"words(전처리, re 정규식, token화, stop 불용어 제거, 표제어 추출) : {words}")
# Out:
# 과정1 title 원본: A Holistic View of Big Data
# 과정2 title enWords(re: 대소문자남기기): A Holistic View of Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'holistic', 'view', 'of', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['holistic', 'view', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['holistic', 'view', 'big', 'data']
# 과정1 title 원본: A Big Data-Driven Business Data Analysis System: Applications of Artificial Intelligence Techniques in Problem Solving
# 과정2 title enWords(re: 대소문자남기기): A Big Data Driven Business Data Analysis System Applications of Artificial Intelligence Techniques in Problem Solving
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'big', 'data', 'driven', 'business', 'data', 'analysis', 'system', 'applications', 'of', 'artificial', 'intelligence', 'techniques', 'in', 'problem', 'solving']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'driven', 'business', 'data', 'analysis', 'system', 'applications', 'artificial', 'intelligence', 'techniques', 'problem', 'solving']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'driven', 'business', 'data', 'analysis', 'system', 'application', 'artificial', 'intelligence', 'technique', 'problem', 'solving']
# 과정1 title 원본: IoT-Based Health Big-Data Process Technologies: A Survey = IoT-Based Health Big-Data Process Technologies: A Survey
# 과정2 title enWords(re: 대소문자남기기): IoT Based Health Big Data Process Technologies A Survey IoT Based Health Big Data Process Technologies A Survey
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['iot', 'based', 'health', 'big', 'data', 'process', 'technologies', 'a', 'survey', 'iot', 'based', 'health', 'big', 'data', 'process', 'technologies', 'a', 'survey']
# 과정4 title enWordsTokenStop(불용어 제거): ['iot', 'based', 'health', 'big', 'data', 'process', 'technologies', 'survey', 'iot', 'based', 'health', 'big', 'data', 'process', 'technologies', 'survey']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['iot', 'based', 'health', 'big', 'data', 'process', 'technology', 'survey', 'iot', 'based', 'health', 'big', 'data', 'process', 'technology', 'survey']
# 과정1 title 원본: Big-Data Analysis for Manufacturing Processes of Medium Density Fiberboard Production = Big-Data Analysis for Manufacturing Processes of Medium Density Fiberboard Production
# 과정2 title enWords(re: 대소문자남기기): Big Data Analysis for Manufacturing Processes of Medium Density Fiberboard Production Big Data Analysis for Manufacturing Processes of Medium Density Fiberboard Production
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'analysis', 'for', 'manufacturing', 'processes', 'of', 'medium', 'density', 'fiberboard', 'production', 'big', 'data', 'analysis', 'for', 'manufacturing', 'processes', 'of', 'medium', 'density', 'fiberboard', 'production']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'analysis', 'manufacturing', 'processes', 'medium', 'density', 'fiberboard', 'production', 'big', 'data', 'analysis', 'manufacturing', 'processes', 'medium', 'density', 'fiberboard', 'production']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'analysis', 'manufacturing', 'process', 'medium', 'density', 'fiberboard', 'production', 'big', 'data', 'analysis', 'manufacturing', 'process', 'medium', 'density', 'fiberboard', 'production']
# 과정1 title 원본: Analysis of Big-Data from Manufacturing Processes of Medium Density Fiberboard Production = Analysis of Big-Data from Manufacturing Processes of Medium Density Fiberboard Production
# 과정2 title enWords(re: 대소문자남기기): Analysis of Big Data from Manufacturing Processes of Medium Density Fiberboard Production Analysis of Big Data from Manufacturing Processes of Medium Density Fiberboard Production
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['analysis', 'of', 'big', 'data', 'from', 'manufacturing', 'processes', 'of', 'medium', 'density', 'fiberboard', 'production', 'analysis', 'of', 'big', 'data', 'from', 'manufacturing', 'processes', 'of', 'medium', 'density', 'fiberboard', 'production']
# 과정4 title enWordsTokenStop(불용어 제거): ['analysis', 'big', 'data', 'manufacturing', 'processes', 'medium', 'density', 'fiberboard', 'production', 'analysis', 'big', 'data', 'manufacturing', 'processes', 'medium', 'density', 'fiberboard', 'production']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['analysis', 'big', 'data', 'manufacturing', 'process', 'medium', 'density', 'fiberboard', 'production', 'analysis', 'big', 'data', 'manufacturing', 'process', 'medium', 'density', 'fiberboard', 'production']
# 과정1 title 원본: Big-data Analytics: Exploring the Well-being Trend in South Korea Through Inductive Reasoning = Big-data Analytics: Exploring the Well-being Trend in South Korea Through Inductive Reasoning
# 과정2 title enWords(re: 대소문자남기기): Big data Analytics Exploring the Well being Trend in South Korea Through Inductive Reasoning Big data Analytics Exploring the Well being Trend in South Korea Through Inductive Reasoning
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'analytics', 'exploring', 'the', 'well', 'being', 'trend', 'in', 'south', 'korea', 'through', 'inductive', 'reasoning', 'big', 'data', 'analytics', 'exploring', 'the', 'well', 'being', 'trend', 'in', 'south', 'korea', 'through', 'inductive', 'reasoning']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'analytics', 'exploring', 'well', 'trend', 'south', 'korea', 'inductive', 'reasoning', 'big', 'data', 'analytics', 'exploring', 'well', 'trend', 'south', 'korea', 'inductive', 'reasoning']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'analytics', 'exploring', 'well', 'trend', 'south', 'korea', 'inductive', 'reasoning', 'big', 'data', 'analytics', 'exploring', 'well', 'trend', 'south', 'korea', 'inductive', 'reasoning']
# 과정1 title 원본: 빅데이터(Big-data)에 나타난 감성 분석 = Autocorrelation Analysis of the Sentiment with Stock Information Appearing on Big-Data
# 과정2 title enWords(re: 대소문자남기기):  Big data Autocorrelation Analysis of the Sentiment with Stock Information Appearing on Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'autocorrelation', 'analysis', 'of', 'the', 'sentiment', 'with', 'stock', 'information', 'appearing', 'on', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'autocorrelation', 'analysis', 'sentiment', 'stock', 'information', 'appearing', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'autocorrelation', 'analysis', 'sentiment', 'stock', 'information', 'appearing', 'big', 'data']
# 과정1 title 원본: Big-Data Meta Analysis in the Last Quarter Century of Mass Communication Research : Four Subfields of PR, Journalism, Political communication, and Advertising = Big-Data Meta Analysis in the Last Quarter Century of Mass Communication Research : Four Subfields of PR, Journalism, Political communication, and Advertising
# 과정2 title enWords(re: 대소문자남기기): Big Data Meta Analysis in the Last Quarter Century of Mass Communication Research Four Subfields of PR Journalism Political communication and Advertising Big Data Meta Analysis in the Last Quarter Century of Mass Communication Research Four Subfields of PR Journalism Political communication and Advertising
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'meta', 'analysis', 'in', 'the', 'last', 'quarter', 'century', 'of', 'mass', 'communication', 'research', 'four', 'subfields', 'of', 'pr', 'journalism', 'political', 'communication', 'and', 'advertising', 'big', 'data', 'meta', 'analysis', 'in', 'the', 'last', 'quarter', 'century', 'of', 'mass', 'communication', 'research', 'four', 'subfields', 'of', 'pr', 'journalism', 'political', 'communication', 'and', 'advertising']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'meta', 'analysis', 'last', 'quarter', 'century', 'mass', 'communication', 'research', 'four', 'subfields', 'pr', 'journalism', 'political', 'communication', 'advertising', 'big', 'data', 'meta', 'analysis', 'last', 'quarter', 'century', 'mass', 'communication', 'research', 'four', 'subfields', 'pr', 'journalism', 'political', 'communication', 'advertising']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'meta', 'analysis', 'last', 'quarter', 'century', 'mass', 'communication', 'research', 'four', 'subfields', 'pr', 'journalism', 'political', 'communication', 'advertising', 'big', 'data', 'meta', 'analysis', 'last', 'quarter', 'century', 'mass', 'communication', 'research', 'four', 'subfields', 'pr', 'journalism', 'political', 'communication', 'advertising']
# 과정1 title 원본: Almighty Google knows everything! - big-data and network science = Almighty Google knows everything! - big-data and network science
# 과정2 title enWords(re: 대소문자남기기): Almighty Google knows everything big data and network science Almighty Google knows everything big data and network science
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['almighty', 'google', 'knows', 'everything', 'big', 'data', 'and', 'network', 'science', 'almighty', 'google', 'knows', 'everything', 'big', 'data', 'and', 'network', 'science']
# 과정4 title enWordsTokenStop(불용어 제거): ['almighty', 'google', 'knows', 'everything', 'big', 'data', 'network', 'science', 'almighty', 'google', 'knows', 'everything', 'big', 'data', 'network', 'science']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['almighty', 'google', 'know', 'everything', 'big', 'data', 'network', 'science', 'almighty', 'google', 'know', 'everything', 'big', 'data', 'network', 'science']
# 과정1 title 원본: 빅테이터(Big Data) 융합예술의 세계적 양상과 전망분석 = Global Tendencies and Prospects of the Big Data Convergence Art
# 과정2 title enWords(re: 대소문자남기기):  Big Data Global Tendencies and Prospects of the Big Data Convergence Art
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'global', 'tendencies', 'and', 'prospects', 'of', 'the', 'big', 'data', 'convergence', 'art']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'global', 'tendencies', 'prospects', 'big', 'data', 'convergence', 'art']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'global', 'tendency', 'prospect', 'big', 'data', 'convergence', 'art']
# 과정1 title 원본: The Limitations on the Use of Big Data Pursuant to Data Privacy Regulations in Korea = The Limitations on the Use of Big Data Pursuant to Data Privacy Regulations in Korea
# 과정2 title enWords(re: 대소문자남기기): The Limitations on the Use of Big Data Pursuant to Data Privacy Regulations in Korea The Limitations on the Use of Big Data Pursuant to Data Privacy Regulations in Korea
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['the', 'limitations', 'on', 'the', 'use', 'of', 'big', 'data', 'pursuant', 'to', 'data', 'privacy', 'regulations', 'in', 'korea', 'the', 'limitations', 'on', 'the', 'use', 'of', 'big', 'data', 'pursuant', 'to', 'data', 'privacy', 'regulations', 'in', 'korea']
# 과정4 title enWordsTokenStop(불용어 제거): ['limitations', 'use', 'big', 'data', 'pursuant', 'data', 'privacy', 'regulations', 'korea', 'limitations', 'use', 'big', 'data', 'pursuant', 'data', 'privacy', 'regulations', 'korea']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['limitation', 'use', 'big', 'data', 'pursuant', 'data', 'privacy', 'regulation', 'korea', 'limitation', 'use', 'big', 'data', 'pursuant', 'data', 'privacy', 'regulation', 'korea']
# 과정1 title 원본: AI와 Big Data 쟁점 분석 및 교육정치학의 발전 과제 = An Analysis of Future Tasks of Political Education and Issues of AI (&amp; Big Data)
# 과정2 title enWords(re: 대소문자남기기): AI Big Data An Analysis of Future Tasks of Political Education and Issues of AI amp Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['ai', 'big', 'data', 'an', 'analysis', 'of', 'future', 'tasks', 'of', 'political', 'education', 'and', 'issues', 'of', 'ai', 'amp', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['ai', 'big', 'data', 'analysis', 'future', 'tasks', 'political', 'education', 'issues', 'ai', 'amp', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['ai', 'big', 'data', 'analysis', 'future', 'task', 'political', 'education', 'issue', 'ai', 'amp', 'big', 'data']
# 과정1 title 원본: 클라우드 환경에서 정량적, 정성적 Big Data를 활용한 공급사슬관리 = Supply Chain Management Using Quantitative and Qualitative Big Data in Cloud Environments
# 과정2 title enWords(re: 대소문자남기기):  Big Data Supply Chain Management Using Quantitative and Qualitative Big Data in Cloud Environments
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'supply', 'chain', 'management', 'using', 'quantitative', 'and', 'qualitative', 'big', 'data', 'in', 'cloud', 'environments']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'supply', 'chain', 'management', 'using', 'quantitative', 'qualitative', 'big', 'data', 'cloud', 'environments']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'supply', 'chain', 'management', 'using', 'quantitative', 'qualitative', 'big', 'data', 'cloud', 'environment']
# 과정1 title 원본: Business Intelligence and Marketing Insights in an Era of Big Data: The Q-sorting Approach = Business Intelligence and Marketing Insights in an Era of Big Data: The Q-sorting Approach
# 과정2 title enWords(re: 대소문자남기기): Business Intelligence and Marketing Insights in an Era of Big Data The Q sorting Approach Business Intelligence and Marketing Insights in an Era of Big Data The Q sorting Approach
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['business', 'intelligence', 'and', 'marketing', 'insights', 'in', 'an', 'era', 'of', 'big', 'data', 'the', 'q', 'sorting', 'approach', 'business', 'intelligence', 'and', 'marketing', 'insights', 'in', 'an', 'era', 'of', 'big', 'data', 'the', 'q', 'sorting', 'approach']
# 과정4 title enWordsTokenStop(불용어 제거): ['business', 'intelligence', 'marketing', 'insights', 'era', 'big', 'data', 'q', 'sorting', 'approach', 'business', 'intelligence', 'marketing', 'insights', 'era', 'big', 'data', 'q', 'sorting', 'approach']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['business', 'intelligence', 'marketing', 'insight', 'era', 'big', 'data', 'q', 'sorting', 'approach', 'business', 'intelligence', 'marketing', 'insight', 'era', 'big', 'data', 'q', 'sorting', 'approach']
# 과정1 title 원본: Big Data의 활용을 위한 새로운 Six Sigma 프로젝트 실행 방법 = New Six Sigma Breakthrough using Big Data
# 과정2 title enWords(re: 대소문자남기기): Big Data Six Sigma New Six Sigma Breakthrough using Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'six', 'sigma', 'new', 'six', 'sigma', 'breakthrough', 'using', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'six', 'sigma', 'new', 'six', 'sigma', 'breakthrough', 'using', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'six', 'sigma', 'new', 'six', 'sigma', 'breakthrough', 'using', 'big', 'data']
# 과정1 title 원본: 특집 2 : 개인정보 보호와 이용자 권리 ; 기업의 빅데이터(Big Data) 활용과 개인정보의 보호의 조화 = Special Lssue 2: Data Protection and User`s Rights : Big Data and Personal Information Protection
# 과정2 title enWords(re: 대소문자남기기):  Big Data Special Lssue Data Protection and User s Rights Big Data and Personal Information Protection
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'special', 'lssue', 'data', 'protection', 'and', 'user', 's', 'rights', 'big', 'data', 'and', 'personal', 'information', 'protection']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'special', 'lssue', 'data', 'protection', 'user', 'rights', 'big', 'data', 'personal', 'information', 'protection']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'special', 'lssue', 'data', 'protection', 'user', 'right', 'big', 'data', 'personal', 'information', 'protection']
# 과정1 title 원본: Does Big Data Matter to Value Creation? = Does Big Data Matter to Value Creation? : Based on Oracle Solution Case
# 과정2 title enWords(re: 대소문자남기기): Does Big Data Matter to Value Creation Does Big Data Matter to Value Creation Based on Oracle Solution Case
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['does', 'big', 'data', 'matter', 'to', 'value', 'creation', 'does', 'big', 'data', 'matter', 'to', 'value', 'creation', 'based', 'on', 'oracle', 'solution', 'case']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'matter', 'value', 'creation', 'big', 'data', 'matter', 'value', 'creation', 'based', 'oracle', 'solution', 'case']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'matter', 'value', 'creation', 'big', 'data', 'matter', 'value', 'creation', 'based', 'oracle', 'solution', 'case']
# 과정1 title 원본: Semantic Computing for Big Data: Approaches, Tools, and Emerging Directions (2011-2014) = Semantic Computing for Big Data: Approaches, Tools, and Emerging Directions (2011-2014)
# 과정2 title enWords(re: 대소문자남기기): Semantic Computing for Big Data Approaches Tools and Emerging Directions Semantic Computing for Big Data Approaches Tools and Emerging Directions
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['semantic', 'computing', 'for', 'big', 'data', 'approaches', 'tools', 'and', 'emerging', 'directions', 'semantic', 'computing', 'for', 'big', 'data', 'approaches', 'tools', 'and', 'emerging', 'directions']
# 과정4 title enWordsTokenStop(불용어 제거): ['semantic', 'computing', 'big', 'data', 'approaches', 'tools', 'emerging', 'directions', 'semantic', 'computing', 'big', 'data', 'approaches', 'tools', 'emerging', 'directions']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['semantic', 'computing', 'big', 'data', 'approach', 'tool', 'emerging', 'direction', 'semantic', 'computing', 'big', 'data', 'approach', 'tool', 'emerging', 'direction']
# 과정1 title 원본: A Keyword-Based Big Data Analysis for Individualized Health Activity: Focusing on Methodological Approach = A Keyword-Based Big Data Analysis for Individualized Health Activity: Focusing on Methodological Approach
# 과정2 title enWords(re: 대소문자남기기): A Keyword Based Big Data Analysis for Individualized Health Activity Focusing on Methodological Approach A Keyword Based Big Data Analysis for Individualized Health Activity Focusing on Methodological Approach
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'keyword', 'based', 'big', 'data', 'analysis', 'for', 'individualized', 'health', 'activity', 'focusing', 'on', 'methodological', 'approach', 'a', 'keyword', 'based', 'big', 'data', 'analysis', 'for', 'individualized', 'health', 'activity', 'focusing', 'on', 'methodological', 'approach']
# 과정4 title enWordsTokenStop(불용어 제거): ['keyword', 'based', 'big', 'data', 'analysis', 'individualized', 'health', 'activity', 'focusing', 'methodological', 'approach', 'keyword', 'based', 'big', 'data', 'analysis', 'individualized', 'health', 'activity', 'focusing', 'methodological', 'approach']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['keyword', 'based', 'big', 'data', 'analysis', 'individualized', 'health', 'activity', 'focusing', 'methodological', 'approach', 'keyword', 'based', 'big', 'data', 'analysis', 'individualized', 'health', 'activity', 'focusing', 'methodological', 'approach']
# 과정1 title 원본: Optimization Driven MapReduce Framework for Indexing and Retrieval of Big Data = Optimization Driven MapReduce Framework for Indexing and Retrieval of Big Data
# 과정2 title enWords(re: 대소문자남기기): Optimization Driven MapReduce Framework for Indexing and Retrieval of Big Data Optimization Driven MapReduce Framework for Indexing and Retrieval of Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['optimization', 'driven', 'mapreduce', 'framework', 'for', 'indexing', 'and', 'retrieval', 'of', 'big', 'data', 'optimization', 'driven', 'mapreduce', 'framework', 'for', 'indexing', 'and', 'retrieval', 'of', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['optimization', 'driven', 'mapreduce', 'framework', 'indexing', 'retrieval', 'big', 'data', 'optimization', 'driven', 'mapreduce', 'framework', 'indexing', 'retrieval', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['optimization', 'driven', 'mapreduce', 'framework', 'indexing', 'retrieval', 'big', 'data', 'optimization', 'driven', 'mapreduce', 'framework', 'indexing', 'retrieval', 'big', 'data']
# 과정1 title 원본: 국내 금융기관의 빅 데이터(Big Data)활용 사례에 관한 연구 = A Case Study on the Use of Big Data in the Korean Financial Institutions
# 과정2 title enWords(re: 대소문자남기기):  Big Data A Case Study on the Use of Big Data in the Korean Financial Institutions
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'a', 'case', 'study', 'on', 'the', 'use', 'of', 'big', 'data', 'in', 'the', 'korean', 'financial', 'institutions']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'case', 'study', 'use', 'big', 'data', 'korean', 'financial', 'institutions']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'case', 'study', 'use', 'big', 'data', 'korean', 'financial', 'institution']
# 과정1 title 원본: Hadoop Based Wavelet Histogram for Big Data in Cloud = Hadoop Based Wavelet Histogram for Big Data in Cloud
# 과정2 title enWords(re: 대소문자남기기): Hadoop Based Wavelet Histogram for Big Data in Cloud Hadoop Based Wavelet Histogram for Big Data in Cloud
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['hadoop', 'based', 'wavelet', 'histogram', 'for', 'big', 'data', 'in', 'cloud', 'hadoop', 'based', 'wavelet', 'histogram', 'for', 'big', 'data', 'in', 'cloud']
# 과정4 title enWordsTokenStop(불용어 제거): ['hadoop', 'based', 'wavelet', 'histogram', 'big', 'data', 'cloud', 'hadoop', 'based', 'wavelet', 'histogram', 'big', 'data', 'cloud']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['hadoop', 'based', 'wavelet', 'histogram', 'big', 'data', 'cloud', 'hadoop', 'based', 'wavelet', 'histogram', 'big', 'data', 'cloud']
# 과정1 title 원본: 빅 데이터 (Big Data)의 공법적 재조명 = A Research For Big Data In Public Law
# 과정2 title enWords(re: 대소문자남기기):  Big Data A Research For Big Data In Public Law
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'a', 'research', 'for', 'big', 'data', 'in', 'public', 'law']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'research', 'big', 'data', 'public', 'law']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'research', 'big', 'data', 'public', 'law']
# 과정1 title 원본: 유통업 Big Data를 이용한 고객 행태 분석에 대한 연구 = study on the customer behavior analysis using Big data from Distribution industry
# 과정2 title enWords(re: 대소문자남기기):  Big Data study on the customer behavior analysis using Big data from Distribution industry
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'study', 'on', 'the', 'customer', 'behavior', 'analysis', 'using', 'big', 'data', 'from', 'distribution', 'industry']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'study', 'customer', 'behavior', 'analysis', 'using', 'big', 'data', 'distribution', 'industry']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'study', 'customer', 'behavior', 'analysis', 'using', 'big', 'data', 'distribution', 'industry']
# 과정1 title 원본: A Survey of Homomorphic Encryption for Outsourced Big Data Computation = A Survey of Homomorphic Encryption for Outsourced Big Data Computation
# 과정2 title enWords(re: 대소문자남기기): A Survey of Homomorphic Encryption for Outsourced Big Data Computation A Survey of Homomorphic Encryption for Outsourced Big Data Computation
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'survey', 'of', 'homomorphic', 'encryption', 'for', 'outsourced', 'big', 'data', 'computation', 'a', 'survey', 'of', 'homomorphic', 'encryption', 'for', 'outsourced', 'big', 'data', 'computation']
# 과정4 title enWordsTokenStop(불용어 제거): ['survey', 'homomorphic', 'encryption', 'outsourced', 'big', 'data', 'computation', 'survey', 'homomorphic', 'encryption', 'outsourced', 'big', 'data', 'computation']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['survey', 'homomorphic', 'encryption', 'outsourced', 'big', 'data', 'computation', 'survey', 'homomorphic', 'encryption', 'outsourced', 'big', 'data', 'computation']
# 과정1 title 원본: Data-driven Modeling and Service based on Big Data Analytics and Perception Process = Data-driven Modeling and Service based on Big Data Analytics and Perception Process
# 과정2 title enWords(re: 대소문자남기기): Data driven Modeling and Service based on Big Data Analytics and Perception Process Data driven Modeling and Service based on Big Data Analytics and Perception Process
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['data', 'driven', 'modeling', 'and', 'service', 'based', 'on', 'big', 'data', 'analytics', 'and', 'perception', 'process', 'data', 'driven', 'modeling', 'and', 'service', 'based', 'on', 'big', 'data', 'analytics', 'and', 'perception', 'process']
# 과정4 title enWordsTokenStop(불용어 제거): ['data', 'driven', 'modeling', 'service', 'based', 'big', 'data', 'analytics', 'perception', 'process', 'data', 'driven', 'modeling', 'service', 'based', 'big', 'data', 'analytics', 'perception', 'process']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['data', 'driven', 'modeling', 'service', 'based', 'big', 'data', 'analytics', 'perception', 'process', 'data', 'driven', 'modeling', 'service', 'based', 'big', 'data', 'analytics', 'perception', 'process']
# 과정1 title 원본: Market Trend Analysis of Cosmetics Products U sing Big Data: Focused on AMOREPACIFIC = Market Trend Analysis of Cosmetics Products U sing Big Data: Focused on AMOREPACIFIC
# 과정2 title enWords(re: 대소문자남기기): Market Trend Analysis of Cosmetics Products U sing Big Data Focused on AMOREPACIFIC Market Trend Analysis of Cosmetics Products U sing Big Data Focused on AMOREPACIFIC
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['market', 'trend', 'analysis', 'of', 'cosmetics', 'products', 'u', 'sing', 'big', 'data', 'focused', 'on', 'amorepacific', 'market', 'trend', 'analysis', 'of', 'cosmetics', 'products', 'u', 'sing', 'big', 'data', 'focused', 'on', 'amorepacific']
# 과정4 title enWordsTokenStop(불용어 제거): ['market', 'trend', 'analysis', 'cosmetics', 'products', 'u', 'sing', 'big', 'data', 'focused', 'amorepacific', 'market', 'trend', 'analysis', 'cosmetics', 'products', 'u', 'sing', 'big', 'data', 'focused', 'amorepacific']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['market', 'trend', 'analysis', 'cosmetic', 'product', 'u', 'sing', 'big', 'data', 'focused', 'amorepacific', 'market', 'trend', 'analysis', 'cosmetic', 'product', 'u', 'sing', 'big', 'data', 'focused', 'amorepacific']
# 과정1 title 원본: 효과적인 디스플레이 제조를 위한 AI/BIG DATA 기반 스마트 팩토리 기술 현황 분석 = AI/BIG DATA-based Smart Factory Technology Status Analysis for Effective Display Manufacturing
# 과정2 title enWords(re: 대소문자남기기):  AI BIG DATA AI BIG DATA based Smart Factory Technology Status Analysis for Effective Display Manufacturing
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['ai', 'big', 'data', 'ai', 'big', 'data', 'based', 'smart', 'factory', 'technology', 'status', 'analysis', 'for', 'effective', 'display', 'manufacturing']
# 과정4 title enWordsTokenStop(불용어 제거): ['ai', 'big', 'data', 'ai', 'big', 'data', 'based', 'smart', 'factory', 'technology', 'status', 'analysis', 'effective', 'display', 'manufacturing']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['ai', 'big', 'data', 'ai', 'big', 'data', 'based', 'smart', 'factory', 'technology', 'status', 'analysis', 'effective', 'display', 'manufacturing']
# 과정1 title 원본: DTG Big Data Analysis for Fuel Consumption Estimation = DTG Big Data Analysis for Fuel Consumption Estimation
# 과정2 title enWords(re: 대소문자남기기): DTG Big Data Analysis for Fuel Consumption Estimation DTG Big Data Analysis for Fuel Consumption Estimation
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['dtg', 'big', 'data', 'analysis', 'for', 'fuel', 'consumption', 'estimation', 'dtg', 'big', 'data', 'analysis', 'for', 'fuel', 'consumption', 'estimation']
# 과정4 title enWordsTokenStop(불용어 제거): ['dtg', 'big', 'data', 'analysis', 'fuel', 'consumption', 'estimation', 'dtg', 'big', 'data', 'analysis', 'fuel', 'consumption', 'estimation']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['dtg', 'big', 'data', 'analysis', 'fuel', 'consumption', 'estimation', 'dtg', 'big', 'data', 'analysis', 'fuel', 'consumption', 'estimation']
# 과정1 title 원본: Performance Evaluation and Analysis of Multiple Scenarios of Big Data Stream Computing on Storm Platform = Performance Evaluation and Analysis of Multiple Scenarios of Big Data Stream Computing on Storm Platform
# 과정2 title enWords(re: 대소문자남기기): Performance Evaluation and Analysis of Multiple Scenarios of Big Data Stream Computing on Storm Platform Performance Evaluation and Analysis of Multiple Scenarios of Big Data Stream Computing on Storm Platform
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['performance', 'evaluation', 'and', 'analysis', 'of', 'multiple', 'scenarios', 'of', 'big', 'data', 'stream', 'computing', 'on', 'storm', 'platform', 'performance', 'evaluation', 'and', 'analysis', 'of', 'multiple', 'scenarios', 'of', 'big', 'data', 'stream', 'computing', 'on', 'storm', 'platform']
# 과정4 title enWordsTokenStop(불용어 제거): ['performance', 'evaluation', 'analysis', 'multiple', 'scenarios', 'big', 'data', 'stream', 'computing', 'storm', 'platform', 'performance', 'evaluation', 'analysis', 'multiple', 'scenarios', 'big', 'data', 'stream', 'computing', 'storm', 'platform']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['performance', 'evaluation', 'analysis', 'multiple', 'scenario', 'big', 'data', 'stream', 'computing', 'storm', 'platform', 'performance', 'evaluation', 'analysis', 'multiple', 'scenario', 'big', 'data', 'stream', 'computing', 'storm', 'platform']
# 과정1 title 원본: Self-organization Scheme of WSNs with Mobile Sensors and Mobile Multiple Sinks for Big Data Computing = Self-organization Scheme of WSNs with Mobile Sensors and Mobile Multiple Sinks for Big Data Computing
# 과정2 title enWords(re: 대소문자남기기): Self organization Scheme of WSNs with Mobile Sensors and Mobile Multiple Sinks for Big Data Computing Self organization Scheme of WSNs with Mobile Sensors and Mobile Multiple Sinks for Big Data Computing
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['self', 'organization', 'scheme', 'of', 'wsns', 'with', 'mobile', 'sensors', 'and', 'mobile', 'multiple', 'sinks', 'for', 'big', 'data', 'computing', 'self', 'organization', 'scheme', 'of', 'wsns', 'with', 'mobile', 'sensors', 'and', 'mobile', 'multiple', 'sinks', 'for', 'big', 'data', 'computing']
# 과정4 title enWordsTokenStop(불용어 제거): ['self', 'organization', 'scheme', 'wsns', 'mobile', 'sensors', 'mobile', 'multiple', 'sinks', 'big', 'data', 'computing', 'self', 'organization', 'scheme', 'wsns', 'mobile', 'sensors', 'mobile', 'multiple', 'sinks', 'big', 'data', 'computing']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['self', 'organization', 'scheme', 'wsns', 'mobile', 'sensor', 'mobile', 'multiple', 'sink', 'big', 'data', 'computing', 'self', 'organization', 'scheme', 'wsns', 'mobile', 'sensor', 'mobile', 'multiple', 'sink', 'big', 'data', 'computing']
# 과정1 title 원본: 디지털 광고 효과 향상을 위한 Big Data 기반의 목표 그룹 세분화에 대한 연구 = A study on Target Audience Segmentation based on Big Data for enhancing the effects of digital advertising
# 과정2 title enWords(re: 대소문자남기기):  Big Data A study on Target Audience Segmentation based on Big Data for enhancing the effects of digital advertising
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'a', 'study', 'on', 'target', 'audience', 'segmentation', 'based', 'on', 'big', 'data', 'for', 'enhancing', 'the', 'effects', 'of', 'digital', 'advertising']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'study', 'target', 'audience', 'segmentation', 'based', 'big', 'data', 'enhancing', 'effects', 'digital', 'advertising']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'study', 'target', 'audience', 'segmentation', 'based', 'big', 'data', 'enhancing', 'effect', 'digital', 'advertising']
# 과정1 title 원본: Sequential Pattern Mining for Intrusion Detection System with Feature Selection on Big Data = Sequential Pattern Mining for Intrusion Detection System with Feature Selection on Big Data
# 과정2 title enWords(re: 대소문자남기기): Sequential Pattern Mining for Intrusion Detection System with Feature Selection on Big Data Sequential Pattern Mining for Intrusion Detection System with Feature Selection on Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['sequential', 'pattern', 'mining', 'for', 'intrusion', 'detection', 'system', 'with', 'feature', 'selection', 'on', 'big', 'data', 'sequential', 'pattern', 'mining', 'for', 'intrusion', 'detection', 'system', 'with', 'feature', 'selection', 'on', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['sequential', 'pattern', 'mining', 'intrusion', 'detection', 'system', 'feature', 'selection', 'big', 'data', 'sequential', 'pattern', 'mining', 'intrusion', 'detection', 'system', 'feature', 'selection', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['sequential', 'pattern', 'mining', 'intrusion', 'detection', 'system', 'feature', 'selection', 'big', 'data', 'sequential', 'pattern', 'mining', 'intrusion', 'detection', 'system', 'feature', 'selection', 'big', 'data']
# 과정1 title 원본: Big data를 이용한실시간 SOC 구조물 거동분석 시스템 연구 = A Study on Real-Time SOC Structure Behavior Evaluation System using Big Data
# 과정2 title enWords(re: 대소문자남기기): Big data SOC A Study on Real Time SOC Structure Behavior Evaluation System using Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'soc', 'a', 'study', 'on', 'real', 'time', 'soc', 'structure', 'behavior', 'evaluation', 'system', 'using', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'soc', 'study', 'real', 'time', 'soc', 'structure', 'behavior', 'evaluation', 'system', 'using', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'soc', 'study', 'real', 'time', 'soc', 'structure', 'behavior', 'evaluation', 'system', 'using', 'big', 'data']
# 과정1 title 원본: An Automatic Urban Function District Division Method Based on Big Data Analysis of POI = An Automatic Urban Function District Division Method Based on Big Data Analysis of POI
# 과정2 title enWords(re: 대소문자남기기): An Automatic Urban Function District Division Method Based on Big Data Analysis of POI An Automatic Urban Function District Division Method Based on Big Data Analysis of POI
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['an', 'automatic', 'urban', 'function', 'district', 'division', 'method', 'based', 'on', 'big', 'data', 'analysis', 'of', 'poi', 'an', 'automatic', 'urban', 'function', 'district', 'division', 'method', 'based', 'on', 'big', 'data', 'analysis', 'of', 'poi']
# 과정4 title enWordsTokenStop(불용어 제거): ['automatic', 'urban', 'function', 'district', 'division', 'method', 'based', 'big', 'data', 'analysis', 'poi', 'automatic', 'urban', 'function', 'district', 'division', 'method', 'based', 'big', 'data', 'analysis', 'poi']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['automatic', 'urban', 'function', 'district', 'division', 'method', 'based', 'big', 'data', 'analysis', 'poi', 'automatic', 'urban', 'function', 'district', 'division', 'method', 'based', 'big', 'data', 'analysis', 'poi']
# 과정1 title 원본: Prediction Model for Chronic Obstructive Pulmonary Disease Exacerbation, Based on Big Data Analysis and Machine Learning = Prediction Model for Chronic Obstructive Pulmonary Disease Exacerbation, Based on Big Data Analysis and Machine Learning
# 과정2 title enWords(re: 대소문자남기기): Prediction Model for Chronic Obstructive Pulmonary Disease Exacerbation Based on Big Data Analysis and Machine Learning Prediction Model for Chronic Obstructive Pulmonary Disease Exacerbation Based on Big Data Analysis and Machine Learning
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['prediction', 'model', 'for', 'chronic', 'obstructive', 'pulmonary', 'disease', 'exacerbation', 'based', 'on', 'big', 'data', 'analysis', 'and', 'machine', 'learning', 'prediction', 'model', 'for', 'chronic', 'obstructive', 'pulmonary', 'disease', 'exacerbation', 'based', 'on', 'big', 'data', 'analysis', 'and', 'machine', 'learning']
# 과정4 title enWordsTokenStop(불용어 제거): ['prediction', 'model', 'chronic', 'obstructive', 'pulmonary', 'disease', 'exacerbation', 'based', 'big', 'data', 'analysis', 'machine', 'learning', 'prediction', 'model', 'chronic', 'obstructive', 'pulmonary', 'disease', 'exacerbation', 'based', 'big', 'data', 'analysis', 'machine', 'learning']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['prediction', 'model', 'chronic', 'obstructive', 'pulmonary', 'disease', 'exacerbation', 'based', 'big', 'data', 'analysis', 'machine', 'learning', 'prediction', 'model', 'chronic', 'obstructive', 'pulmonary', 'disease', 'exacerbation', 'based', 'big', 'data', 'analysis', 'machine', 'learning']
# 과정1 title 원본: 빅 데이터(Big Data) 시대의 소비자보호 문제 -소비자 개인정보의 범위와 정보주체 동의를 중심으로- = A Study on Consumer Protection Issue in the era of Big Data -Focusing on the Scope of Consumers` Personal Information and Consent of Primary Information Provider-
# 과정2 title enWords(re: 대소문자남기기):  Big Data A Study on Consumer Protection Issue in the era of Big Data Focusing on the Scope of Consumers Personal Information and Consent of Primary Information Provider
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'a', 'study', 'on', 'consumer', 'protection', 'issue', 'in', 'the', 'era', 'of', 'big', 'data', 'focusing', 'on', 'the', 'scope', 'of', 'consumers', 'personal', 'information', 'and', 'consent', 'of', 'primary', 'information', 'provider']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'study', 'consumer', 'protection', 'issue', 'era', 'big', 'data', 'focusing', 'scope', 'consumers', 'personal', 'information', 'consent', 'primary', 'information', 'provider']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'study', 'consumer', 'protection', 'issue', 'era', 'big', 'data', 'focusing', 'scope', 'consumer', 'personal', 'information', 'consent', 'primary', 'information', 'provider']
# 과정1 title 원본: 클라우드 환경에서 IoT 데이터 기반 빅데이터 서비스를 위한 Big Data-as-a-Service 모델 = Big Data-as-a-Service Model for IoT Data-based Big Data Service in Cloud Environment
# 과정2 title enWords(re: 대소문자남기기):  IoT Big Data as a Service Big Data as a Service Model for IoT Data based Big Data Service in Cloud Environment
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['iot', 'big', 'data', 'as', 'a', 'service', 'big', 'data', 'as', 'a', 'service', 'model', 'for', 'iot', 'data', 'based', 'big', 'data', 'service', 'in', 'cloud', 'environment']
# 과정4 title enWordsTokenStop(불용어 제거): ['iot', 'big', 'data', 'service', 'big', 'data', 'service', 'model', 'iot', 'data', 'based', 'big', 'data', 'service', 'cloud', 'environment']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['iot', 'big', 'data', 'service', 'big', 'data', 'service', 'model', 'iot', 'data', 'based', 'big', 'data', 'service', 'cloud', 'environment']
# 과정1 title 원본: Big Data의 통계기법을 이용한 기업고용 성장요인 분석 = An Analysis of Employment Growth Using Big Data
# 과정2 title enWords(re: 대소문자남기기): Big Data An Analysis of Employment Growth Using Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'an', 'analysis', 'of', 'employment', 'growth', 'using', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'analysis', 'employment', 'growth', 'using', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'analysis', 'employment', 'growth', 'using', 'big', 'data']
# 과정1 title 원본: Big Data-driven Tourist Flow focasting with Interpretable Machine Learning = Big Data-driven Tourist Flow focasting with Interpretable Machine Learning
# 과정2 title enWords(re: 대소문자남기기): Big Data driven Tourist Flow focasting with Interpretable Machine Learning Big Data driven Tourist Flow focasting with Interpretable Machine Learning
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'driven', 'tourist', 'flow', 'focasting', 'with', 'interpretable', 'machine', 'learning', 'big', 'data', 'driven', 'tourist', 'flow', 'focasting', 'with', 'interpretable', 'machine', 'learning']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'driven', 'tourist', 'flow', 'focasting', 'interpretable', 'machine', 'learning', 'big', 'data', 'driven', 'tourist', 'flow', 'focasting', 'interpretable', 'machine', 'learning']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'driven', 'tourist', 'flow', 'focasting', 'interpretable', 'machine', 'learning', 'big', 'data', 'driven', 'tourist', 'flow', 'focasting', 'interpretable', 'machine', 'learning']
# 과정1 title 원본: 대기오염에 따른 환경성 질환의 인자분석: Big Data를 통한 Google 트렌드 데이터의 분석 및 영향 = Factor analysis of Environmental Disease by Air Pollution: Analysis and Implication of Google Trends Data with Big Data
# 과정2 title enWords(re: 대소문자남기기):  Big Data Google Factor analysis of Environmental Disease by Air Pollution Analysis and Implication of Google Trends Data with Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'google', 'factor', 'analysis', 'of', 'environmental', 'disease', 'by', 'air', 'pollution', 'analysis', 'and', 'implication', 'of', 'google', 'trends', 'data', 'with', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'google', 'factor', 'analysis', 'environmental', 'disease', 'air', 'pollution', 'analysis', 'implication', 'google', 'trends', 'data', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'google', 'factor', 'analysis', 'environmental', 'disease', 'air', 'pollution', 'analysis', 'implication', 'google', 'trend', 'data', 'big', 'data']
# 과정1 title 원본: "Does Big Data Matter to Value Creation?" : 오라클(Oracle) 솔루션 사례를 바탕으로 = &quot;Does Big Data Matter to Value Creation?&quot;-Based on Oracle Solution Case
# 과정2 title enWords(re: 대소문자남기기):  Does Big Data Matter to Value Creation Oracle quot Does Big Data Matter to Value Creation quot Based on Oracle Solution Case
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['does', 'big', 'data', 'matter', 'to', 'value', 'creation', 'oracle', 'quot', 'does', 'big', 'data', 'matter', 'to', 'value', 'creation', 'quot', 'based', 'on', 'oracle', 'solution', 'case']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'matter', 'value', 'creation', 'oracle', 'quot', 'big', 'data', 'matter', 'value', 'creation', 'quot', 'based', 'oracle', 'solution', 'case']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'matter', 'value', 'creation', 'oracle', 'quot', 'big', 'data', 'matter', 'value', 'creation', 'quot', 'based', 'oracle', 'solution', 'case']
# 과정1 title 원본: Inter-category Map: Building Cognition Network of General Customers through Big Data Mining = Inter-category Map: Building Cognition Network of General Customers through Big Data Mining
# 과정2 title enWords(re: 대소문자남기기): Inter category Map Building Cognition Network of General Customers through Big Data Mining Inter category Map Building Cognition Network of General Customers through Big Data Mining
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['inter', 'category', 'map', 'building', 'cognition', 'network', 'of', 'general', 'customers', 'through', 'big', 'data', 'mining', 'inter', 'category', 'map', 'building', 'cognition', 'network', 'of', 'general', 'customers', 'through', 'big', 'data', 'mining']
# 과정4 title enWordsTokenStop(불용어 제거): ['inter', 'category', 'map', 'building', 'cognition', 'network', 'general', 'customers', 'big', 'data', 'mining', 'inter', 'category', 'map', 'building', 'cognition', 'network', 'general', 'customers', 'big', 'data', 'mining']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['inter', 'category', 'map', 'building', 'cognition', 'network', 'general', 'customer', 'big', 'data', 'mining', 'inter', 'category', 'map', 'building', 'cognition', 'network', 'general', 'customer', 'big', 'data', 'mining']
# 과정1 title 원본: Smart Factory Big Data를 활용한 공정 이상 탐지 프로세스 적용 사례 연구 = A case study on the application of process abnormal detection process using big data in smart factory, A case study on the application of process abnormal detection process using big data in smart factory
# 과정2 title enWords(re: 대소문자남기기): Smart Factory Big Data A case study on the application of process abnormal detection process using big data in smart factory A case study on the application of process abnormal detection process using big data in smart factory
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['smart', 'factory', 'big', 'data', 'a', 'case', 'study', 'on', 'the', 'application', 'of', 'process', 'abnormal', 'detection', 'process', 'using', 'big', 'data', 'in', 'smart', 'factory', 'a', 'case', 'study', 'on', 'the', 'application', 'of', 'process', 'abnormal', 'detection', 'process', 'using', 'big', 'data', 'in', 'smart', 'factory']
# 과정4 title enWordsTokenStop(불용어 제거): ['smart', 'factory', 'big', 'data', 'case', 'study', 'application', 'process', 'abnormal', 'detection', 'process', 'using', 'big', 'data', 'smart', 'factory', 'case', 'study', 'application', 'process', 'abnormal', 'detection', 'process', 'using', 'big', 'data', 'smart', 'factory']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['smart', 'factory', 'big', 'data', 'case', 'study', 'application', 'process', 'abnormal', 'detection', 'process', 'using', 'big', 'data', 'smart', 'factory', 'case', 'study', 'application', 'process', 'abnormal', 'detection', 'process', 'using', 'big', 'data', 'smart', 'factory']
# 과정1 title 원본: The Countermeasure Strategy Based on Big Data against North Korean Cyber-attacks = The Countermeasure Strategy Based on Big Data against North Korean Cyber-attacks
# 과정2 title enWords(re: 대소문자남기기): The Countermeasure Strategy Based on Big Data against North Korean Cyber attacks The Countermeasure Strategy Based on Big Data against North Korean Cyber attacks
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['the', 'countermeasure', 'strategy', 'based', 'on', 'big', 'data', 'against', 'north', 'korean', 'cyber', 'attacks', 'the', 'countermeasure', 'strategy', 'based', 'on', 'big', 'data', 'against', 'north', 'korean', 'cyber', 'attacks']
# 과정4 title enWordsTokenStop(불용어 제거): ['countermeasure', 'strategy', 'based', 'big', 'data', 'north', 'korean', 'cyber', 'attacks', 'countermeasure', 'strategy', 'based', 'big', 'data', 'north', 'korean', 'cyber', 'attacks']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['countermeasure', 'strategy', 'based', 'big', 'data', 'north', 'korean', 'cyber', 'attack', 'countermeasure', 'strategy', 'based', 'big', 'data', 'north', 'korean', 'cyber', 'attack']
# 과정1 title 원본: Prevalence, incidence and birth rate of endometriosis in Korea using big data = Prevalence, incidence and birth rate of endometriosis in Korea using big data
# 과정2 title enWords(re: 대소문자남기기): Prevalence incidence and birth rate of endometriosis in Korea using big data Prevalence incidence and birth rate of endometriosis in Korea using big data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['prevalence', 'incidence', 'and', 'birth', 'rate', 'of', 'endometriosis', 'in', 'korea', 'using', 'big', 'data', 'prevalence', 'incidence', 'and', 'birth', 'rate', 'of', 'endometriosis', 'in', 'korea', 'using', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['prevalence', 'incidence', 'birth', 'rate', 'endometriosis', 'korea', 'using', 'big', 'data', 'prevalence', 'incidence', 'birth', 'rate', 'endometriosis', 'korea', 'using', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['prevalence', 'incidence', 'birth', 'rate', 'endometriosis', 'korea', 'using', 'big', 'data', 'prevalence', 'incidence', 'birth', 'rate', 'endometriosis', 'korea', 'using', 'big', 'data']
# 과정1 title 원본: Big Data를 활용한 송 · 배전 선로 고장 진단 표준화에 관한 연구 = A Study on Standardization of Fault Diagnosis of Transmission and Distribution Line using Big Data
# 과정2 title enWords(re: 대소문자남기기): Big Data A Study on Standardization of Fault Diagnosis of Transmission and Distribution Line using Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data', 'a', 'study', 'on', 'standardization', 'of', 'fault', 'diagnosis', 'of', 'transmission', 'and', 'distribution', 'line', 'using', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data', 'study', 'standardization', 'fault', 'diagnosis', 'transmission', 'distribution', 'line', 'using', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data', 'study', 'standardization', 'fault', 'diagnosis', 'transmission', 'distribution', 'line', 'using', 'big', 'data']
# 과정1 title 원본: Big Data중 비정형Data인 소셜미디어가 기업의 매출액에 미치는 효과 = The Effect of Social Media Related to Informal Data of Big Data on Sales
# 과정2 title enWords(re: 대소문자남기기): Big Data Data The Effect of Social Media Related to Informal Data of Big Data on Sales
# ...
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['k', 'nearest', 'neighbor', 'join', 'big', 'data', 'processing', 'based', 'spark', 'spark', 'k']
# 과정1 title 원본: The Influence of AI-CRM Adoption and Big Data Analytical Capability on Firm Performance of Large Enterprises in Thailand
# 과정2 title enWords(re: 대소문자남기기): The Influence of AI CRM Adoption and Big Data Analytical Capability on Firm Performance of Large Enterprises in Thailand
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['the', 'influence', 'of', 'ai', 'crm', 'adoption', 'and', 'big', 'data', 'analytical', 'capability', 'on', 'firm', 'performance', 'of', 'large', 'enterprises', 'in', 'thailand']
# 과정4 title enWordsTokenStop(불용어 제거): ['influence', 'ai', 'crm', 'adoption', 'big', 'data', 'analytical', 'capability', 'firm', 'performance', 'large', 'enterprises', 'thailand']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['influence', 'ai', 'crm', 'adoption', 'big', 'data', 'analytical', 'capability', 'firm', 'performance', 'large', 'enterprise', 'thailand']
# 과정1 title 원본: A Study on the Application of Social Big Data in Energy Management System Using BlockChain Network for SmartCity
# 과정2 title enWords(re: 대소문자남기기): A Study on the Application of Social Big Data in Energy Management System Using BlockChain Network for SmartCity
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'study', 'on', 'the', 'application', 'of', 'social', 'big', 'data', 'in', 'energy', 'management', 'system', 'using', 'blockchain', 'network', 'for', 'smartcity']
# 과정4 title enWordsTokenStop(불용어 제거): ['study', 'application', 'social', 'big', 'data', 'energy', 'management', 'system', 'using', 'blockchain', 'network', 'smartcity']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['study', 'application', 'social', 'big', 'data', 'energy', 'management', 'system', 'using', 'blockchain', 'network', 'smartcity']
# 과정1 title 원본: A Comparative Study of Business Hotels in Busan and Seoul through Big Data Analysis: Evaluating Online Customer Review
# 과정2 title enWords(re: 대소문자남기기): A Comparative Study of Business Hotels in Busan and Seoul through Big Data Analysis Evaluating Online Customer Review
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'comparative', 'study', 'of', 'business', 'hotels', 'in', 'busan', 'and', 'seoul', 'through', 'big', 'data', 'analysis', 'evaluating', 'online', 'customer', 'review']
# 과정4 title enWordsTokenStop(불용어 제거): ['comparative', 'study', 'business', 'hotels', 'busan', 'seoul', 'big', 'data', 'analysis', 'evaluating', 'online', 'customer', 'review']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['comparative', 'study', 'business', 'hotel', 'busan', 'seoul', 'big', 'data', 'analysis', 'evaluating', 'online', 'customer', 'review']
# 과정1 title 원본: Use of big data for estimation of impacts of meteorological variables on environmental radiation dose on Ulleung Island, Republic of Korea
# 과정2 title enWords(re: 대소문자남기기): Use of big data for estimation of impacts of meteorological variables on environmental radiation dose on Ulleung Island Republic of Korea
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['use', 'of', 'big', 'data', 'for', 'estimation', 'of', 'impacts', 'of', 'meteorological', 'variables', 'on', 'environmental', 'radiation', 'dose', 'on', 'ulleung', 'island', 'republic', 'of', 'korea']
# 과정4 title enWordsTokenStop(불용어 제거): ['use', 'big', 'data', 'estimation', 'impacts', 'meteorological', 'variables', 'environmental', 'radiation', 'dose', 'ulleung', 'island', 'republic', 'korea']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['use', 'big', 'data', 'estimation', 'impact', 'meteorological', 'variable', 'environmental', 'radiation', 'dose', 'ulleung', 'island', 'republic', 'korea']
# 과정1 title 원본: Status and Issue Analysis on Indie Game through Big Data Analysis
# 과정2 title enWords(re: 대소문자남기기): Status and Issue Analysis on Indie Game through Big Data Analysis
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['status', 'and', 'issue', 'analysis', 'on', 'indie', 'game', 'through', 'big', 'data', 'analysis']
# 과정4 title enWordsTokenStop(불용어 제거): ['status', 'issue', 'analysis', 'indie', 'game', 'big', 'data', 'analysis']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['status', 'issue', 'analysis', 'indie', 'game', 'big', 'data', 'analysis']
# 과정1 title 원본: Linking Species with the Ecosystem: The Emergence of Big Data and Artificial Intelligence in Ecological Research
# 과정2 title enWords(re: 대소문자남기기): Linking Species with the Ecosystem The Emergence of Big Data and Artificial Intelligence in Ecological Research
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['linking', 'species', 'with', 'the', 'ecosystem', 'the', 'emergence', 'of', 'big', 'data', 'and', 'artificial', 'intelligence', 'in', 'ecological', 'research']
# 과정4 title enWordsTokenStop(불용어 제거): ['linking', 'species', 'ecosystem', 'emergence', 'big', 'data', 'artificial', 'intelligence', 'ecological', 'research']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['linking', 'specie', 'ecosystem', 'emergence', 'big', 'data', 'artificial', 'intelligence', 'ecological', 'research']
# 과정1 title 원본: Evaluating Conversion Rate from Advertising in Social Media using Big Data Clustering
# 과정2 title enWords(re: 대소문자남기기): Evaluating Conversion Rate from Advertising in Social Media using Big Data Clustering
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['evaluating', 'conversion', 'rate', 'from', 'advertising', 'in', 'social', 'media', 'using', 'big', 'data', 'clustering']
# 과정4 title enWordsTokenStop(불용어 제거): ['evaluating', 'conversion', 'rate', 'advertising', 'social', 'media', 'using', 'big', 'data', 'clustering']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['evaluating', 'conversion', 'rate', 'advertising', 'social', 'medium', 'using', 'big', 'data', 'clustering']
# 과정1 title 원본: Towards a New Digital Urbanity: A Future for Smart Cities in the Century of Sustainability and Big Data = 새로운 디지털 도시성을 향해: 지속가능성과 빅데이터의 세기에서 스마트시티의 미래
# 과정2 title enWords(re: 대소문자남기기): Towards a New Digital Urbanity A Future for Smart Cities in the Century of Sustainability and Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['towards', 'a', 'new', 'digital', 'urbanity', 'a', 'future', 'for', 'smart', 'cities', 'in', 'the', 'century', 'of', 'sustainability', 'and', 'big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['towards', 'new', 'digital', 'urbanity', 'future', 'smart', 'cities', 'century', 'sustainability', 'big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['towards', 'new', 'digital', 'urbanity', 'future', 'smart', 'city', 'century', 'sustainability', 'big', 'data']
# 과정1 title 원본: Applying a big data analysis to evaluate the suitability of shelter locations for the evacuation of residents in case of radiological emergencies
# 과정2 title enWords(re: 대소문자남기기): Applying a big data analysis to evaluate the suitability of shelter locations for the evacuation of residents in case of radiological emergencies
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['applying', 'a', 'big', 'data', 'analysis', 'to', 'evaluate', 'the', 'suitability', 'of', 'shelter', 'locations', 'for', 'the', 'evacuation', 'of', 'residents', 'in', 'case', 'of', 'radiological', 'emergencies']
# 과정4 title enWordsTokenStop(불용어 제거): ['applying', 'big', 'data', 'analysis', 'evaluate', 'suitability', 'shelter', 'locations', 'evacuation', 'residents', 'case', 'radiological', 'emergencies']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['applying', 'big', 'data', 'analysis', 'evaluate', 'suitability', 'shelter', 'location', 'evacuation', 'resident', 'case', 'radiological', 'emergency']
# 과정1 title 원본: Vessel Trajectory Big data analysis using Apache Spark and prediction based on Machine Learning
# 과정2 title enWords(re: 대소문자남기기): Vessel Trajectory Big data analysis using Apache Spark and prediction based on Machine Learning
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['vessel', 'trajectory', 'big', 'data', 'analysis', 'using', 'apache', 'spark', 'and', 'prediction', 'based', 'on', 'machine', 'learning']
# 과정4 title enWordsTokenStop(불용어 제거): ['vessel', 'trajectory', 'big', 'data', 'analysis', 'using', 'apache', 'spark', 'prediction', 'based', 'machine', 'learning']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['vessel', 'trajectory', 'big', 'data', 'analysis', 'using', 'apache', 'spark', 'prediction', 'based', 'machine', 'learning']
# 과정1 title 원본: NoSQL Database: New Era of Databases for Big data Analytics-Classification, Characteristics and Comparison
# 과정2 title enWords(re: 대소문자남기기): NoSQL Database New Era of Databases for Big data Analytics Classification Characteristics and Comparison
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['nosql', 'database', 'new', 'era', 'of', 'databases', 'for', 'big', 'data', 'analytics', 'classification', 'characteristics', 'and', 'comparison']
# 과정4 title enWordsTokenStop(불용어 제거): ['nosql', 'database', 'new', 'era', 'databases', 'big', 'data', 'analytics', 'classification', 'characteristics', 'comparison']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['nosql', 'database', 'new', 'era', 'database', 'big', 'data', 'analytics', 'classification', 'characteristic', 'comparison']
# 과정1 title 원본: A Study on Big Data Analysis Related to ‘Digital literacy’ Using Newspaper Media in South Korea
# 과정2 title enWords(re: 대소문자남기기): A Study on Big Data Analysis Related to Digital literacy Using Newspaper Media in South Korea
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'study', 'on', 'big', 'data', 'analysis', 'related', 'to', 'digital', 'literacy', 'using', 'newspaper', 'media', 'in', 'south', 'korea']
# 과정4 title enWordsTokenStop(불용어 제거): ['study', 'big', 'data', 'analysis', 'related', 'digital', 'literacy', 'using', 'newspaper', 'media', 'south', 'korea']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['study', 'big', 'data', 'analysis', 'related', 'digital', 'literacy', 'using', 'newspaper', 'medium', 'south', 'korea']
# 과정1 title 원본: Fault Detection of Plasma Etchers using Big Data Analysis
# 과정2 title enWords(re: 대소문자남기기): Fault Detection of Plasma Etchers using Big Data Analysis
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['fault', 'detection', 'of', 'plasma', 'etchers', 'using', 'big', 'data', 'analysis']
# 과정4 title enWordsTokenStop(불용어 제거): ['fault', 'detection', 'plasma', 'etchers', 'using', 'big', 'data', 'analysis']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['fault', 'detection', 'plasma', 'etcher', 'using', 'big', 'data', 'analysis']
# 과정1 title 원본: A Case Study of Topic Modeling for Papers Related to Big Data Using Python Modules
# 과정2 title enWords(re: 대소문자남기기): A Case Study of Topic Modeling for Papers Related to Big Data Using Python Modules
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'case', 'study', 'of', 'topic', 'modeling', 'for', 'papers', 'related', 'to', 'big', 'data', 'using', 'python', 'modules']
# 과정4 title enWordsTokenStop(불용어 제거): ['case', 'study', 'topic', 'modeling', 'papers', 'related', 'big', 'data', 'using', 'python', 'modules']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['case', 'study', 'topic', 'modeling', 'paper', 'related', 'big', 'data', 'using', 'python', 'module']
# 과정1 title 원본: A Study on Feasibility of Evaluating IT Project Proposals based on Big Data Analysis
# 과정2 title enWords(re: 대소문자남기기): A Study on Feasibility of Evaluating IT Project Proposals based on Big Data Analysis
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['a', 'study', 'on', 'feasibility', 'of', 'evaluating', 'it', 'project', 'proposals', 'based', 'on', 'big', 'data', 'analysis']
# 과정4 title enWordsTokenStop(불용어 제거): ['study', 'feasibility', 'evaluating', 'project', 'proposals', 'based', 'big', 'data', 'analysis']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['study', 'feasibility', 'evaluating', 'project', 'proposal', 'based', 'big', 'data', 'analysis']
# 과정1 title 원본: 설비 품질 Big Data 분석을 통한 선제적 품질 관리 체계 구축
# 과정2 title enWords(re: 대소문자남기기):  Big Data
# 과정3 title enWordsToken(모두 소문자 -> 각각 분리 토큰화): ['big', 'data']
# 과정4 title enWordsTokenStop(불용어 제거): ['big', 'data']
# 과정5 title enWordsTokenStopLemma(표제어 추출 작업 후): ['big', 'data']
# words(전처리, re 정규식, token화, stop 불용어 제거, 표제어 추출) : [['holistic', 'view', 'big', 'data'], ['big', 'data', 'driven', 'business', 'data', 'analysis', 'system', 'application', 'artificial', 'intelligence', 'technique', 'problem', 'solving'], ['iot', 'based', 'health', 'big', 'data', 'process', 'technology', 'survey', 'iot', 'based', 'health', 'big', 'data', 'process', 'technology', 'survey'], ['big', 'data', 'analysis', 'manufacturing', 'process', 'medium', 'density', 'fiberboard', 'production', 'big', 'data', 'analysis', 'manufacturing', 'process', 'medium', 'density', 'fiberboard', 'production'], ['analysis', 'big', 'data', 'manufacturing', 'process', 'medium', 'density', 'fiberboard', 'production', 'analysis', 'big', 'data', 'manufacturing', 'process', 'medium', 'density', 'fiberboard', 'production'], ['big', 'data', 'analytics', 'exploring', 'well', 'trend', 'south', 'korea', 'inductive', 'reasoning', 'big', 'data', 'analytics', 'exploring', 'well', 'trend', 'south', 'korea', 'inductive', 'reasoning'], ['big', 'data', 'autocorrelation', 'analysis', 'sentiment', 'stock', 'information', 'appearing', 'big', 'data'], ['big', 'data', 'meta', 'analysis', 'last', 'quarter', 'century', 'mass', 'communication', 'research', 'four', 'subfields', 'pr', 'journalism', 'political', 'communication', 'advertising', 'big', 'data', 'meta', 'analysis', 'last', 'quarter', 'century', 'mass', 'communication', 'research', 'four', 'subfields', 'pr', 'journalism', 'political', 'communication', 'advertising'], ['almighty', 'google', 'know', 'everything', 'big', 'data', 'network', 'science', 'almighty', 'google', 'know', 'everything', 'big', 'data', 'network', 'science'], ['big', 'data', 'global', 'tendency', 'prospect', 'big', 'data', 'convergence', 'art'], ['limitation', 'use', 'big', 'data', 'pursuant', 'data', 'privacy', 'regulation', 'korea', 'limitation', 'use', 'big', 'data', 'pursuant', 'data', 'privacy', 'regulation', 'korea'], ['ai', 'big', 'data', 'analysis', 'future', 'task', 'political', 'education', 'issue', 'ai', 'amp', 'big', 'data'], ['big', 'data', 'supply', 'chain', 'management', 'using', 'quantitative', 'qualitative', 'big', 'data', 'cloud', 'environment'], ['business', 'intelligence', 'marketing', 'insight', 'era', 'big', 'data', 'q', 'sorting', 'approach', 'business', 'intelligence', 'marketing', 'insight', 'era', 'big', 'data', 'q', 'sorting', 'approach'], ['big', 'data', 'six', 'sigma', 'new', 'six', 'sigma', 'breakthrough', 'using', 'big', 'data'], ['big', 'data', 'special', 'lssue', 'data', 'protection', 'user', 'right', 'big', 'data', 'personal', 'information', 'protection'], ['big', 'data', 'matter', 'value', 'creation', 'big', 'data', 'matter', 'value', 'creation', 'based', 'oracle', 'solution', 'case'], ['semantic', 'computing', 'big', 'data', 'approach', 'tool', 'emerging', 'direction', 'semantic', 'computing', 'big', 'data', 'approach', 'tool', 'emerging', 'direction'], ['keyword', 'based', 'big', 'data', 'analysis', 'individualized', 'health', 'activity', 'focusing', 'methodological', 'approach', 'keyword', 'based', 'big', 'data', 'analysis', 'individualized', 'health', 'activity', 'focusing', 'methodological', 'approach'], ['optimization', 'driven', 'mapreduce', 'framework', 'indexing', 'retrieval', 'big', 'data', 'optimization', 'driven', 'mapreduce', 'framework', 'indexing', 'retrieval', 'big', 'data'], ['big', 'data', 'case', 'study', 'use', 'big', 'data', 'korean', 'financial', 'institution'], ['hadoop', 'based', 'wavelet', 'histogram', 'big', 'data', 'cloud', 'hadoop', 'based', 'wavelet', 'histogram', 'big', 'data', 'cloud'], ['big', 'data', 'research', 'big', 'data', 'public', 'law'], ['big', 'data', 'study', 'customer', 'behavior', 'analysis', 'using', 'big', 'data', 'distribution', 'industry'], ['survey', 'homomorphic', 'encryption', 'outsourced', 'big', 'data', 'computation', 'survey', 'homomorphic', 'encryption', 'outsourced', 'big', 'data', 'computation'], ['data', 'driven', 'modeling', 'service', 'based', 'big ...

# %%
# 2차원 리스트 -> 1차원 리스트 , 차원 축소 
# reduce 함수 이용하기. 차원 축소 
# list 함수 이용해서, 1차원 리스트로 만들기. 
result = reduce(lambda x,y : x+y, words)
words2 = list(result)
#result
print(f"result 타입 조사 : {type(words2)}")
print(f"words2 : {words2}")
# Out:
# result 타입 조사 : <class 'list'>
# words2 : ['holistic', 'view', 'big', 'data', 'big', 'data', 'driven', 'business', 'data', 'analysis', 'system', 'application', 'artificial', 'intelligence', 'technique', 'problem', 'solving', 'iot', 'based', 'health', 'big', 'data', 'process', 'technology', 'survey', 'iot', 'based', 'health', 'big', 'data', 'process', 'technology', 'survey', 'big', 'data', 'analysis', 'manufacturing', 'process', 'medium', 'density', 'fiberboard', 'production', 'big', 'data', 'analysis', 'manufacturing', 'process', 'medium', 'density', 'fiberboard', 'production', 'analysis', 'big', 'data', 'manufacturing', 'process', 'medium', 'density', 'fiberboard', 'production', 'analysis', 'big', 'data', 'manufacturing', 'process', 'medium', 'density', 'fiberboard', 'production', 'big', 'data', 'analytics', 'exploring', 'well', 'trend', 'south', 'korea', 'inductive', 'reasoning', 'big', 'data', 'analytics', 'exploring', 'well', 'trend', 'south', 'korea', 'inductive', 'reasoning', 'big', 'data', 'autocorrelation', 'analysis', 'sentiment', 'stock', 'information', 'appearing', 'big', 'data', 'big', 'data', 'meta', 'analysis', 'last', 'quarter', 'century', 'mass', 'communication', 'research', 'four', 'subfields', 'pr', 'journalism', 'political', 'communication', 'advertising', 'big', 'data', 'meta', 'analysis', 'last', 'quarter', 'century', 'mass', 'communication', 'research', 'four', 'subfields', 'pr', 'journalism', 'political', 'communication', 'advertising', 'almighty', 'google', 'know', 'everything', 'big', 'data', 'network', 'science', 'almighty', 'google', 'know', 'everything', 'big', 'data', 'network', 'science', 'big', 'data', 'global', 'tendency', 'prospect', 'big', 'data', 'convergence', 'art', 'limitation', 'use', 'big', 'data', 'pursuant', 'data', 'privacy', 'regulation', 'korea', 'limitation', 'use', 'big', 'data', 'pursuant', 'data', 'privacy', 'regulation', 'korea', 'ai', 'big', 'data', 'analysis', 'future', 'task', 'political', 'education', 'issue', 'ai', 'amp', 'big', 'data', 'big', 'data', 'supply', 'chain', 'management', 'using', 'quantitative', 'qualitative', 'big', 'data', 'cloud', 'environment', 'business', 'intelligence', 'marketing', 'insight', 'era', 'big', 'data', 'q', 'sorting', 'approach', 'business', 'intelligence', 'marketing', 'insight', 'era', 'big', 'data', 'q', 'sorting', 'approach', 'big', 'data', 'six', 'sigma', 'new', 'six', 'sigma', 'breakthrough', 'using', 'big', 'data', 'big', 'data', 'special', 'lssue', 'data', 'protection', 'user', 'right', 'big', 'data', 'personal', 'information', 'protection', 'big', 'data', 'matter', 'value', 'creation', 'big', 'data', 'matter', 'value', 'creation', 'based', 'oracle', 'solution', 'case', 'semantic', 'computing', 'big', 'data', 'approach', 'tool', 'emerging', 'direction', 'semantic', 'computing', 'big', 'data', 'approach', 'tool', 'emerging', 'direction', 'keyword', 'based', 'big', 'data', 'analysis', 'individualized', 'health', 'activity', 'focusing', 'methodological', 'approach', 'keyword', 'based', 'big', 'data', 'analysis', 'individualized', 'health', 'activity', 'focusing', 'methodological', 'approach', 'optimization', 'driven', 'mapreduce', 'framework', 'indexing', 'retrieval', 'big', 'data', 'optimization', 'driven', 'mapreduce', 'framework', 'indexing', 'retrieval', 'big', 'data', 'big', 'data', 'case', 'study', 'use', 'big', 'data', 'korean', 'financial', 'institution', 'hadoop', 'based', 'wavelet', 'histogram', 'big', 'data', 'cloud', 'hadoop', 'based', 'wavelet', 'histogram', 'big', 'data', 'cloud', 'big', 'data', 'research', 'big', 'data', 'public', 'law', 'big', 'data', 'study', 'customer', 'behavior', 'analysis', 'using', 'big', 'data', 'distribution', 'industry', 'survey', 'homomorphic', 'encryption', 'outsourced', 'big', 'data', 'computation', 'survey', 'homomorphic', 'encryption', 'outsourced', 'big', 'data', 'computation', 'data', 'driven', 'modeling', 'service', 'based', 'big', 'data', 'analytics', 'perception', 'process', 'data', 'driven', 'modeling', 'service', 'b ...

# %%
# 데이터 탐색, 기본 분석 모델 만들기. 
# Counter -> 해당 단어 빈도 집계 해주는 함수. 
count = Counter(words2)
count
# Out:
# Counter({'data': 1243,
#          'big': 1158,
#          'analysis': 366,
#          'based': 227,
#          'using': 209,
#          'study': 184,
#          'system': 98,
#          'social': 79,
#          'research': 78,
#          'analytics': 77,
#          'model': 61,
#          'application': 60,
#          'korea': 60,
#          'management': 52,
#          'service': 49,
#          'development': 48,
#          'information': 42,
#          'network': 42,
#          'smart': 42,
#          'platform': 42,
#          'industry': 40,
#          'trend': 38,
#          'environment': 38,
#          'health': 37,
#          'cloud': 37,
#          'processing': 37,
#          'medium': 36,
#          'technology': 35,
#          'prediction': 35,
#          'factor': 34,
#          'mining': 33,
#          'learning': 33,
#          'design': 33,
#          'ai': 32,
#          'case': 32,
#          'korean': 32,
#          'era': 31,
#          'method': 31,
#          'intelligence': 30,
#          'framework': 29,
#          'healthcare': 29,
#          'use': 28,
#          'strategy': 28,
#          'future': 27,
#          'perception': 27,
#          'technique': 26,
#          'performance': 26,
#          'tourism': 25,
#          'business': 24,
#          'approach': 24,
#          'focusing': 24,
#          'utilization': 24,
#          'computing': 23,
#          'policy': 23,
#          'city': 23,
#          'artificial': 22,
#          'process': 22,
#          'detection': 22,
#          'security': 22,
#          'iot': 21,
#          'marketing': 21,
#          'value': 21,
#          'public': 21,
#          'medical': 21,
#          'customer': 20,
#          'evaluation': 20,
#          'time': 20,
#          'machine': 20,
#          'challenge': 20,
#          'china': 20,
#          'personal': 19,
#          'real': 19,
#          'modeling': 18,
#          'change': 18,
#          'market': 17,
#          'spatial': 17,
#          'decision': 17,
#          'covid': 17,
#          'impact': 17,
#          'review': 17,
#          'communication': 16,
#          'consumption': 16,
#          'energy': 16,
#          'driven': 15,
#          'manufacturing': 15,
#          'south': 15,
#          'privacy': 15,
#          'financial': 15,
#          'hadoop': 15,
#          'focused': 15,
#          'tourist': 15,
#          'online': 15,
#          'emergency': 15,
#          'medicine': 15,
#          'quality': 15,
#          'education': 14,
#          'protection': 14,
#          'product': 14,
#          'pattern': 14,
#          'sport': 14,
#          'implementation': 14,
#          'risk': 14,
#          'database': 14,
#          'care': 14,
#          'problem': 13,
#          'direction': 13,
#          'effect': 13,
#          'digital': 13,
#          'consumer': 13,
#          'relationship': 13,
#          'classification': 13,
#          'cancer': 13,
#          'company': 13,
#          'efficient': 13,
#          'new': 12,
#          'keyword': 12,
#          'disease': 12,
#          'building': 12,
#          'deep': 12,
#          'visualization': 12,
#          'utilizing': 12,
#          'algorithm': 12,
#          'dynamic': 12,
#          'comparative': 12,
#          'making': 12,
#          'assessment': 12,
#          'food': 12,
#          'meta': 11,
#          'google': 11,
#          'amp': 11,
#          'scheme': 11,
#          'mobile': 11,
#          'storage': 11,
#          'traffic': 11,
#          'spark': 11,
#          'integration': 11,
#          'construction': 11,
#          'recommendation': 11,
#          'web': 11,
#          'usage': 11,
#          'tool': 10,
#          'activity': 10,
#          'mapreduce': 10,
#          'age': 10,
#          'insurance': 10,
#          'multi': 10,
#          'perspective': 10,
#          'national': 10,
#          'sharing': 10,
#          'news': 10,
#          'text': 10,
#          'project': 10,
#          'evidence': 10,
#          'exploring': 9,
#          'stock': 9,
#          'global': 9,
#          'issue': 9,
#          'optimization': 9,
#          'factory': 9,
#          'estimation': 9,
#          'legal': 9,
#          'syndrome': 9,
#          'r': 9,
#          'vehicle': 9,
#          'internet': 9,
#          'power': 9,
#          'comparison': 9,
#          'e': 9,
#          'brand': 9,
#          'fashion': 9,
#          'survey': 8,
#          'prospect': 8,
#          'user': 8,
#          'matter': 8,
#          'creation': 8,
#          'semantic': 8,
#          'status': 8,
#          'structure': 8,
#          'urban': 8,
#          'environmental': 8,
#          'air': 8,
#          'incidence': 8,
#          'game': 8,
#          'chinese': 8,
#          'type': 8,
#          'characteristic': 8,
#          'cultural': 8,
#          'advanced': 8,
#          'commerce': 8,
#          'metabolic': 8,
#          'predicting': 8,
#          'start': 8,
#          'intention': 8,
#          'collection': 8,
#          'government': 8,
#          'current': 8,
#          'analyzing': 8,
#          'architecture': 8,
#          'knowledge': 8,
#          'weather': 8,
#          'sentiment': 7,
#          'supply': 7,
#          'chain': 7,
#          'effective': 7,
#          'multiple': 7,
#          'intrusion': 7,
#          'implication': 7,
#          'map': 7,
#          'rate': 7,
#          'related': 7,
#          'industrial': 7,
#          'support': 7,
#          'clustering': 7,
#          'term': 7,
#          'predict': 7,
#          'human': 7,
#          'prevention': 7,
#          'sustainable': 7,
#          'focus': 7,
#          'ict': 7,
#          'developing': 7,
#          'high': 7,
#          'generation': 7,
#          'image': 7,
#          'foreign': 7,
#          'center': 7,
#          'university': 7,
#          'satisfaction': 7,
#          'forecasting': 7,
#          'plan': 7,
#          'need': 7,
#          'geo': 7,
#          'large': 7,
#          'capability': 7,
#          'response': 7,
#          'small': 7,
#          'thing': 7,
#          'context': 7,
#          'distributed': 7,
#          'search': 7,
#          'content': 7,
#          'library': 7,
#          'hotel': 7,
#          'event': 7,
#          'restaurant': 7,
#          'production': 6,
#          'political': 6,
#          'behavior': 6,
#          'stream': 6,
#          'selection': 6,
#          'countermeasure': 6,
#          'finding': 6,
#          'field': 6,
#          'economic': 6,
#          'patient': 6,
#          'connected': 6,
#          'analytic': 6,
#          'international': 6,
#          'child': 6,
#          'waste': 6,
#          'enterprise': 6,
#          'area': 6,
#          'sn': 6,
#          'college': 6,
#          'extraction': 6,
#          'crisis': 6,
#          'agriculture': 6,
#          'sector': 6,
#          'open': 6,
#          'investment': 6,
#          'ahp': 6,
#          'innovation': 6,
#          'apache': 6,
#          'toward': 6,
#          'ecosystem': 6,
#          'cost': 6,
#          'monitoring': 6,
#          'unstructured': 6,
#          'python': 6,
#          'evaluating': 6,
#          'group': 6,
#          'condition': 6,
#          'historical': 6,
#          'c': 6,
#          'index': 6,
#          'seoul': 6,
#          'major': 6,
#          'adoption': 6,
#          'role': 6,
#          'firm': 6,
#          'influencing': 6,
#          'solving': 5,
#          'advertising': 5,
#          'insight': 5,
#          'solution': 5,
#          'retrieval': 5,
#          'institution': 5,
#          'cosmetic': 5,
#          'automatic': 5,
#          'flow': 5,
#          'acute': 5,
#          'registry': 5,
#          'apos': 5,
#          'experience': 5,
#          'enhanced': 5,
#          'leveraging': 5,
#          'concept': 5,
#          'comprehensive': 5,
#          'crime': 5,
#          'applying': 5,
#          'speed': 5,
#          'tree': 5,
#          'different': 5,
#          'language': 5,
#          'resource': 5,
#          'post': 5,
#          'yield': 5,
#          'example': 5,
#          'low': 5,
#          'query': 5,
#          'cluster': 5,
#          'lesson': 5,
#          'opinion': 5,
#          'scale': 5,
#          'film': 5,
#          'mechanism': 5,
#          'regional': 5,
#          'population': 5,
#          'improve': 5,
#          'blockchain': 5,
#          'integrated': 5,
#          'saudi': 5,
#          'k': 5,
#          'sized': 5,
#          'empirical': 5,
#          'methodology': 5,
#          'collaboration': 5,
#          'inference': 5,
#          'topic': 5,
#          'student': 5,
#          'towards': 5,
#          'analyze': 5,
#          'opportunity': 5,
#          'analytical': 5,
#          'improvement': 5,
#          'bike': 5,
#          'density': 4,
#          'fiberboard': 4,
#          'four': 4,
#          'science': 4,
#          'regulation': 4,
#          'qualitative': 4,
#          'oracle': 4,
#          'wavelet': 4,
#          'histogram': 4,
#          'law': 4,
#          'distribution': 4,
#          'u': 4,
#          'dtg': 4,
#          'fuel': 4,
#          'sensor': 4,
#          'feature': 4,
#          'employment': 4,
#          'growth': 4,
#          'general': 4,
#          'cyber': 4,
#          'sale': 4,
#          'key': 4,
#          'revolution': 4,
#          'ethical': 4,
#          'asthma': 4,
#          'society': 4,
#          'utility': 4,
#          'noise': 4,
#          'floor': 4,
#          'channel': 4,
#          'heterogeneous': 4,
#          'code': 4,
#          'governance': 4,
#          'informatics': 4,
#          'driving': 4,
#          'customized': 4,
#          'injury': 4,
#          'source': 4,
#          'soil': 4,
#          'via': 4,
#          'ontology': 4,
#          'fertility': 4,
#          'feasibility': 4,
#          'vitiligo': 4,
#          'private': 4,
#          'collecting': 4,
#          'chicago': 4,
#          'carbon': 4,
#          'autonomous': 4,
#          'world': 4,
#          'accident': 4,
#          'tv': 4,
#          'patent': 4,
#          'price': 4,
#          'therapy': 4,
#          'safety': 4,
#          'implementing': 4,
#          'traditional': 4,
#          'practical': 4,
#          'influence': 4,
#          'proposal': 4,
#          'residential': 4,
#          'agricultural': 4,
#          'background': 4,
#          'hyper': 4,
#          'statistical': 4,
#          'sensitivity': 4,
#          'culture': 4,
#          'stroke': 4,
#          'enabled': 4,
#          'file': 4,
#          'awareness': 4,
#          'franchise': 4,
#          'hybrid': 4,
#          'basis': 4,
#          'forecast': 4,
#          'trading': 4,
#          'integrating': 4,
#          'pollutant': 4,
#          'charging': 4,
#          'demand': 4,
#          'viewer': 4,
#          'planning': 4,
#          'competitive': 4,
#          'coffee': 4,
#          'standard': 4,
#          'optimal': 4,
#          'fuzzy': 4,
#          'arabia': 4,
#          'efficiency': 4,
#          'pandemic': 4,
#          'dental': 4,
#          'article': 4,
#          'among': 4,
#          'determinant': 4,
#          'rna': 4,
#          'biomedical': 4,
#          'diabetes': 4,
#          'cross': 4,
#          'location': 4,
#          'practice': 4,
#          'ups': 4,
#          'optimizing': 4,
#          'activation': 4,
#          'evolution': 4,
#          'logistics': 4,
#          'home': 4,
#          'next': 4,
#          'multimedia': 4,
#          'middle': 4,
#          'forestry': 4,
#          'fishery': 4,
#          'view': 3,
#          'well': 3,
#          'autocorrelation': 3,
#          'last': 3,
#          'century': 3,
#          'know': 3,
#          'convergence': 3,
#          'limitation': 3,
#          'pursuant': 3,
#          'quantitative': 3,
#          'special': 3,
#          'right': 3,
#          'emerging': 3,
#          'indexing': 3,
#          'encryption': 3,
#          'computation': 3,
#          'scenario': 3,
#          'self': 3,
#          'organization': 3,
#          'target': 3,
#          'sequential': 3,
#          'function': 3,
#          'chronic': 3,
#          'cognition': 3,
#          'abnormal': 3,
#          'attack': 3,
#          'prevalence': 3,
#          'standardization': 3,
#          'diagnosis': 3,
#          'line': 3,
#          'good': 3,
#          'extract': 3,
#          'series': 3,
#          'incremental': 3,
#          'character': 3,
#          'th': 3,
#          'literature': 3,
#          'batch': 3,
#          'lake': 3,
#          'reduction': 3,
#          'rating': 3,
#          'catering': 3,
#          'access': 3,
#          'edge': 3,
#          'animal': 3,
#          'g': 3,
#          'designing': 3,
#          'qr': 3,
#          'consideration': 3,
#          'exchange': 3,
#          'identifying': 3,
#          'land': 3,
#          'hypertension': 3,
#          'created': 3,
#          'difference': 3,
#          'chemical': 3,
#          'water': 3,
#          'renewable': 3,
#          'return': 3,
#          'climate': 3,
#          'ancient': 3,
#          'state': 3,
#          'welfare': 3,
#          'biology': 3,
#          'press': 3,
#          'dilemma': 3,
#          'paradox': 3,
#          'diplomacy': 3,
#          'electronic': 3,
#          'genetic': 3,
#          'clinical': 3,
#          'adult': 3,
#          'socio': 3,
#          'centric': 3,
#          'credit': 3,
#          'emotional': 3,
#          'regarding': 3,
#          'infrastructure': 3,
#          'corona': 3,
#          'defense': 3,
#          'long': 3,
#          'radiation': 3,
#          'mobility': 3,
#          'pre': 3,
#          'measure': 3,
#          'transportation': 3,
#          'api': 3,
#          'activating': 3,
#          'citizen': 3,
#          'optimized': 3,
#          'preference': 3,
#          'educational': 3,
#          'physical': 3,
#          'modern': 3,
#          'transport': 3,
#          'modelling': 3,
#          'electric': 3,
#          'laboratory': 3,
#          'secure': 3,
#          'score': 3,
#          'software': 3,
#          'networking': 3,
#          'functional': 3,
#          'play': 3,
#          'correlation': 3,
#          'log': 3,
#          'investigation': 3,
#          'bankruptcy': 3,
#          'accounting': 3,
#          'reality': 3,
#          'newspaper': 3,
#          'base': 3,
#          'collaborative': 3,
#          'site': 3,
#          'end': 3,
#          'sub': 3,
#          'component': 3,
#          'affecting': 3,
#          'skin': 3,
#          'systematic': 3,
#          'job': 3,
#          'dbaas': 3,
#          'english': 3,
#          'sensing': 3,
#          'indonesia': 3,
#          'memory': 3,
#          'shopping': 3,
#          'trajectory': 3,
#          'word': 3,
#          'period': 3,
#          'embedded': 3,
#          'procedure': 3,
#          'various': 3,
#          'road': 3,
#          'local': 3,
#          'resident': 3,
#          'constructing': 3,
#          'hazardous': 3,
#          'conceptual': 3,
#          'advantage': 3,
#          'regression': 3,
#          'neural': 3,
#          'nationwide': 3,
#          'surgery': 3,
#          'volume': 3,
#          'domestic': 3,
#          'republic': 3,
#          'disaster': 3,
#          'potential': 3,
#          'delivery': 3,
#          'professional': 3,
#          'balance': 3,
#          'border': 3,
#          'recognition': 3,
#          'school': 3,
#          'adjustment': 3,
#          'community': 3,
#          'according': 3,
#          'test': 3,
#          'statistic': 3,
#          'operation': 3,
#          'meaning': 3,
#          'attribute': 3,
#          'scalable': 3,
#          'feedback': 3,
#          'ship': 3,
#          'v': 3,
#          'busan': 3,
#          'considering': 3,
#          'nuclear': 3,
#          'sequencing': 3,
#          'shared': 3,
#          'success': 3,
#          'tvn': 3,
#          'variety': 3,
#          'sinseoyugi': 3,
#          'naver': 3,
#          'cast': 3,
#          'programming': 3,
#          'graph': 3,
#          'ev': 3,
#          'breast': 3,
#          'mental': 3,
#          'bdas': 3,
#          'short': 3,
#          'crm': 3,
#          'inductive': 2,
#          'reasoning': 2,
#          'quarter': 2,
#          'mass': 2,
#          'subfields': 2,
#          'pr': 2,
#          'journalism': 2,
#          'almighty': 2,
#          'everything': 2,
#          'art': 2,
#          'task': 2,
#          'q': 2,
#          'sorting': 2,
#          'six': 2,
#          'sigma': 2,
#          'individualized': 2,
#          'methodological': 2,
#          'homomorphic': 2,
#          'outsourced': 2,
#          'sing': 2,
#          'amorepacific': 2,
#          'storm': 2,
#          'wsns': 2,
#          'sink': 2,
#          'audience': 2,
#          'enhancing': 2,
#          'soc': 2,
#          'district': 2,
#          'division': 2,
#          'poi': 2,
#          'obstructive': 2,
#          'pulmonary': 2,
#          'exacerbation': 2,
#          'consent': 2,
#          'primary': 2,
#          'focasting': 2,
#          'interpretable': 2,
#          'pollution': 2,
#          'quot': 2,
#          'inter': 2,
#          'category': 2,
#          'north': 2,
#          'birth': 2,
#          'endometriosis': 2,
#          'fault': 2,
#          'variable': 2,
#          'myocardial': 2,
#          'infarction': 2,
#          'one': 2,
#          'smes': 2,
#          'fourth': 2,
#          'packaging': 2,
#          'ux': 2,
#          'argument': 2,
#          'situationism': 2,
#          'identity': 2,
#          'provable': 2,
#          'possession': 2,
#          'bdba': 2,
#          'scm': 2,
#          'severe': 2,
#          'los': 2,
#          'angeles': 2,
#          'cmf': 2,
#          'often': 2,
#          'fails': 2,
#          'ticket': 2,
#          'london': 2,
#          'olympic': 2,
#          'utilised': 2,
#          'geohazards': 2,
#          'cache': 2,
#          'placement': 2,
#          'diet': 2,
#          'companion': 2,
#          'aggregation': 2,
#          'slicing': 2,
#          'converging': 2,
#          'evolutionary': 2,
#          'opportunistic': 2,
#          'discount': 2,
#          'distrust': 2,
#          'level': 2,
#          'modulation': 2,
#          'senoinflammation': 2,
#          'calorie': 2,
#          'restriction': 2,
#          'biochemical': 2,
#          'omics': 2,
#          'force': 2,
#          'cultivated': 2,
#          'coupling': 2,
#          'temporal': 2,
#          'presence': 2,
#          'pregnancy': 2,
#          'determines': 2,
#          'nhis': 2,
#          'gender': 2,
#          'affect': 2,
#          'physiological': 2,
#          'marker': 2,
#          'exercise': 2,
#          'modality': 2,
#          'anterior': 2,
#          'cruciate': 2,
#          'ligament': 2,
#          'substation': 2,
#          'pain': 2,
#          'repair': 2,
#          'message': 2,
#          'board': 2,
#          'causality': 2,
#          'climatic': 2,
#          'italian': 2,
#          'ryegrass': 2,
#          'paddy': 2,
#          'scenic': 2,
#          'take': 2,
#          'let': 2,
#          'syndromic': 2,
#          'surveillance': 2,
#          'outbreak': 2,
#          'nuc': 2,
#          'getting': 2,
#          'started': 2,
#          'ssd': 2,
#          'enhancement': 2,
#          'bio': 2,
#          'bruno': 2,
#          'j': 2,
#          'strasser': 2,
#          'experiment': 2,
#          'xv': 2,
#          'pp': 2,
#          'dictator': 2,
#          'macroeconomic': 2,
#          'poster': 2,
#          'session': 2,
#          'coverage': 2,
#          'neutrality': 2,
#          'treatment': 2,
#          'manifest': 2,
#          'psoriasis': 2,
#          'constructivism': 2,
#          'early': 2,
#          'childhood': 2,
#          'symptomatic': 2,
#          'discoid': 2,
#          'meniscus': 2,
#          'epidemiologic': 2,
#          'hira': 2,
#          'neoplasia': 2,
#          'colorectal': 2,
#          'screening': 2,
#          'asymptomatic': 2,
#          'fog': 2,
#          'trans': 2,
#          'disciplinary': 2,
#          'studying': 2,
#          'eye': 2,
#          'microfinance': 2,
#          'analyzed': 2,
#          'load': 2,
#          'balancing': 2,
#          'document': 2,
#          'incheon': 2,
#          'adaptive': 2,
#          'participation': 2,
#          'critical': 2,
#          'plant': 2,
#          'integrative': 2,
#          'understanding': 2,
#          'genomic': 2,
#          'improving': 2,
#          'handling': 2,
#          'connection': 2,
#          'outlier': 2,
#          'removal': 2,
#          'weight': 2,
#          'protecting': 2,
#          'farm': 2,
#          'gyeonggi': 2,
#          'recent': 2,
#          'live': 2,
#          'hlm': 2,
#          'aspect': 2,
#          'consolidation': 2,
#          'identification': 2,
#          'make': 2,
#          'economy': 2,
#          'anonymity': 2,
#          'linked': 2,
#          'claim': 2,
#          'property': 2,
#          'discovery': 2,
#          'reduce': 2,
#          'jeonnam': 2,
#          'taxonomy': 2,
#          'hpc': 2,
#          'domain': 2,
#          'reference': 2,
#          'housing': 2,
#          'result': 2,
#          'bda': 2,
#          'forensic': 2,
#          'listed': 2,
#          'kospi': 2,
#          'provide': 2,
#          'technical': 2,
#          'aimed': 2,
#          'embezzlement': 2,
#          'aid': 2,
#          'gap': 2,
#          'book': 2,
#          'join': 2,
#          'family': 2,
#          'landscape': 2,
#          'inventory': 2,
#          'beer': 2,
#          'particulate': 2,
#          'purchasing': 2,
#          'random': 2,
#          'airline': 2,
#          'indoor': 2,
#          'healthy': 2,
#          'principal': 2,
#          'wellness': 2,
#          'advancing': 2,
#          'examination': 2,
#          'arrival': 2,
#          'importance': 2,
#          'corporate': 2,
#          'matching': 2,
#          'ecological': 2,
#          'drone': 2,
#          'writing': 2,
#          'teaching': 2,
#          'crowd': 2,
#          'lstm': 2,
#          'examining': 2,
#          'vitalization': 2,
#          'foundation': 2,
#          'simulation': 2,
#          'oriented': 2,
#          'prior': 2,
#          'continuous': 2,
#          'iran': 2,
#          'adolescent': 2,
#          'adopting': 2,
#          'anomaly': 2,
#          'cnn': 2,
#          'bilstm': 2,
#          'paprika': 2,
#          'achieve': 2,
#          'oral': 2,
#          'pcp': 2,
#          'tsk': 2,
#          'export': 2,
#          'import': 2,
#          'nowcasting': 2,
#          'ethnic': 2,
#          'overcoming': 2,
#          'twitter': 2,
#          'intelligent': 2,
#          'combination': 2,
#          'cause': 2,
#          'interaction': 2,
#          'managing': 2,
#          'meeting': 2,
#          'email': 2,
#          'vector': 2,
#          'obesity': 2,
#          'music': 2,
#          'video': 2,
#          'structured': 2,
#          'experimental': 2,
#          'epidemiology': 2,
#          'transformation': 2,
#          'increased': 2,
#          'province': 2,
#          'esg': 2,
#          'consulting': 2,
#          'antiplatelet': 2,
#          'concern': 2,
#          'de': 2,
#          'identified': 2,
#          'without': 2,
#          'occupational': 2,
#          'requirement': 2,
#          'mediating': 2,
#          'perceived': 2,
#          'contemporary': 2,
#          'history': 2,
#          'indian': 2,
#          'parliamentary': 2,
#          'training': 2,
#          'mode': 2,
#          'beyond': 2,
#          'profiling': 2,
#          'dimensional': 2,
#          'bk': 2,
#          'plus': 2,
#          'strategic': 2,
#          'epidemic': 2,
#          'double': 2,
#          'three': 2,
#          'round': 2,
#          'garden': 2,
#          'floral': 2,
#          'common': 2,
#          'distancing': 2,
#          'thailand': 2,
#          'gi': 2,
#          'bim': 2,
#          'christian': 2,
#          'civil': 2,
#          'ethic': 2,
#          'joint': 2,
#          'computer': 2,
#          'exploratory': 2,
#          'predictive': 2,
#          'entertainment': 2,
#          'program': 2,
#          'cadastral': 2,
#          'resurvey': 2,
#          'situation': 2,
#          'authentication': 2,
#          'inspection': 2,
#          'dairy': 2,
#          'course': 2,
#          'seosan': 2,
#          'virtual': 2,
#          'sustainability': 2,
#          'expenditure': 2,
#          'share': 2,
#          'operational': 2,
#          'suggestion': 2,
#          'warning': 2,
#          'solo': 2,
#          'traveler': 2,
#          'iomt': 2,
#          'protective': 2,
#          'achyranthes': 2,
#          'radix': 2,
#          'root': 2,
#          'cddp': 2,
#          'induced': 2,
#          'liver': 2,
#          'kidney': 2,
#          'damage': 2,
#          'sd': 2,
#          'rat': 2,
#          'criterion': 2,
#          'nation': 2,
#          'p': 2,
#          'complex': 2,
#          ...})

# %%
# 임시 딕션너리 만들기. 
word_count = dict()

# 상위 50개 정도만 추출 해보기. 
for tag, counts in count.most_common(50):
  if(len(str(tag)) >1):
    word_count[tag] = counts
    print(f"tag : {tag}, counts : {counts}")

word_count
# Out:
# tag : data, counts : 1243
# tag : big, counts : 1158
# tag : analysis, counts : 366
# tag : based, counts : 227
# tag : using, counts : 209
# tag : study, counts : 184
# tag : system, counts : 98
# tag : social, counts : 79
# tag : research, counts : 78
# tag : analytics, counts : 77
# tag : model, counts : 61
# tag : application, counts : 60
# tag : korea, counts : 60
# tag : management, counts : 52
# tag : service, counts : 49
# tag : development, counts : 48
# tag : information, counts : 42
# tag : network, counts : 42
# tag : smart, counts : 42
# tag : platform, counts : 42
# tag : industry, counts : 40
# tag : trend, counts : 38
# tag : environment, counts : 38
# tag : health, counts : 37
# tag : cloud, counts : 37
# tag : processing, counts : 37
# tag : medium, counts : 36
# tag : technology, counts : 35
# tag : prediction, counts : 35
# tag : factor, counts : 34
# tag : mining, counts : 33
# tag : learning, counts : 33
# tag : design, counts : 33
# tag : ai, counts : 32
# tag : case, counts : 32
# tag : korean, counts : 32
# tag : era, counts : 31
# tag : method, counts : 31
# tag : intelligence, counts : 30
# tag : framework, counts : 29
# tag : healthcare, counts : 29
# tag : use, counts : 28
# tag : strategy, counts : 28
# tag : future, counts : 27
# tag : perception, counts : 27
# tag : technique, counts : 26
# tag : performance, counts : 26
# tag : tourism, counts : 25
# tag : business, counts : 24
# tag : approach, counts : 24
# {'data': 1243,
#  'big': 1158,
#  'analysis': 366,
#  'based': 227,
#  'using': 209,
#  'study': 184,
#  'system': 98,
#  'social': 79,
#  'research': 78,
#  'analytics': 77,
#  'model': 61,
#  'application': 60,
#  'korea': 60,
#  'management': 52,
#  'service': 49,
#  'development': 48,
#  'information': 42,
#  'network': 42,
#  'smart': 42,
#  'platform': 42,
#  'industry': 40,
#  'trend': 38,
#  'environment': 38,
#  'health': 37,
#  'cloud': 37,
#  'processing': 37,
#  'medium': 36,
#  'technology': 35,
#  'prediction': 35,
#  'factor': 34,
#  'mining': 33,
#  'learning': 33,
#  'design': 33,
#  'ai': 32,
#  'case': 32,
#  'korean': 32,
#  'era': 31,
#  'method': 31,
#  'intelligence': 30,
#  'framework': 29,
#  'healthcare': 29,
#  'use': 28,
#  'strategy': 28,
#  'future': 27,
#  'perception': 27,
#  'technique': 26,
#  'performance': 26,
#  'tourism': 25,
#  'business': 24,
#  'approach': 24}

# %%
# 추출된 상위 50개 단어 시각화하기. 
# 막대그래프 
# word_count : 상위 50개 단어 추출한 , 딕션너리 = Map 비슷 ,key : value 
# 기본이 : 오름 차순, reverse, 내림 차순이라고 보면 됨. 
sorted_Keys = sorted(word_count, key = word_count.get, reverse=True)

# values 추출, 내림 차순 
sorted_Values= sorted(word_count.values(), reverse=True)

# 시각화 
# x축 : range(len(word_count))
# Y축 : sorted_Values
plt.bar(range(len(word_count)),sorted_Values, align='center')
# 눈금 옵션 조정. x축 라벨 붙이기 작업. rotation 세로 방향으로 기울이기. 
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = "vertical")

plt.show()

# %%
# 기존 데이터 프레임에 새로운 컬럼(doc_count) 추가, 임의로 0으로 값 넣기. 
all_files_data_concat["doc_count"] = 0

#  출판일 기준으로 그룹화해서, count 집계 표기 하기.
# as_index=False 옵션을 사용하면 그룹화된 결과의 "출판일"이 인덱스가 아닌 일반 열로 유지됩니다.
summary_date = all_files_data_concat.groupby("출판일", as_index=False)["doc_count"].count()
summary_date
# Out:
#      출판일  doc_count
# 0   2011          2
# 1   2012         20
# 2   2013         35
# 3   2014         54
# 4   2015         94
# 5   2016        120
# 6   2017         80
# 7   2018         81
# 8   2019        109
# 9   2020         80
# 10  2021        103
# 11  2022         66
# 12  2023         78
# 13  2024         75
# 14  2025          3

# %%
# 꺽은선 그래프 
# 가로 세로 비율
plt.figure(figsize=(12,5))
plt.xlabel("year")
plt.ylabel("doc_count")
plt.grid(True)
# x축 : range(len(summary_date))
# y축 : summary_date["doc_count"]
plt.plot(range(len(summary_date)), summary_date["doc_count"] )
# x축 라벨링 옵션 
plt.xticks(range(len(summary_date)), [text for text in summary_date["출판일"]])
plt.show()

# %%
# 워드 클라우드 공식 문서 , 다양한 이미지 위에 처리하기. 
# https://amueller.github.io/word_cloud/index.html

# 워드 클라우드 시각화
# STOPWORDS는 WordCloud 라이브러리에서 제공하는 기본 불용어 집합입니다.
# 이 코드는 STOPWORDS를 집합(set)으로 변환하여,
# 워드 클라우드 생성 시 불필요한 단어(예: "the", "and" 등)를 제거하는 데 사용합니다.
stopwords = set(STOPWORDS)

# stopwords=stopwords:
# 위에서 정의한 불용어 집합을 사용하여, 워드 클라우드에 포함하지 않을 단어들을 지정합니다.
wc = WordCloud(background_color="ivory", stopwords=stopwords, width=800, height=600)
# word_count는 단어와 해당 단어의 빈도수를 담은 사전(dictionary)입니다.
# 이 메서드는 word_count에 저장된 단어들의 빈도 정보를 바탕으로 워드 클라우드를 생성하고, 그 결과를 cloud에 저장합니다.
cloud = wc.generate_from_frequencies(word_count)

plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis("off")
plt.show()
# data': 1235,
#  'big': 1113,
#  'analytics': 110,
#  'based': 102,
#  'analysis': 93,
#  'driven': 70,
#  'system': 64,
#  'using': 57,
