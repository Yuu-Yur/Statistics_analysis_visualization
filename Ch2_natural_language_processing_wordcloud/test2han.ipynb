# %% [markdown]
# ## 한글 형태소 분석 ,시각화, 워드 클라우드 등.
# ### 형태소 분석, 품사 태깅.
# ### 데이터 : 샘플 데이터 , 페이스북 전자 신문에서 크롤링 한 임시 데이터로  대체
# ### 설치 가 조금 복잡함.
# ### 1) jdk 17 이상 2) JPype(자바, 파이썬 연결하는 도구) 3) konlpy 패키지 설치.
#
# ## 주의사항, JPype 버전 1.4,  파이썬 버전 3.10.7 다운그레이드
# ## 시스템 환경 변수 , ex) JAVA_HOME : 경로 추가 하기. jdk 17
# ### 변수명 : JAVA_HOME (동일하게)
# ### 시스템 환경 변수의 경로 값 예제: C:\Program Files\Java\jdk-17
# ### 변수명 : Path
# ### 경로 : C:\Program Files\Java\jdk-17\bin
#
# ## 파이썬 3.10.x , 예) 3.10.7 버전으로 다운 받기.
# ### 시스템 환경 변수 추가 작업
#
# ### 변수명 : Path
# ### 경로C:\Python\Python39\
#
# ### 변수명 : Path
# ### 경로C:\Python\Python39\Scripts
#
# ### cmd -> python -V
#
# ## 2) JPype(자바, 파이썬 연결하는 도구)
# ### 다운로드 사이트 주소 : https://github.com/jpype-project/jpype/releases
# ### JPype 검색하고, 버전은 JPype1‑1.4.0‑cp310‑cp310‑win_amd64.whl 받아서,
# ### 해당 다운로드 받은 폴더 이동하고, 해당 폴더 검색경로에서, cmd 실행하고,
# ### cmd -> pip install JPype1‑1.4.0‑cp310‑cp310‑win_amd64.whl
# ### 업그레이드 경고창 뜨면 :
# ### python.exe -m pip install --upgrade pip
# ### 업그레이드 후 , 다시 설치
# ### pip install JPype1‑1.4.0‑cp310‑cp310‑win_amd64.whl
# ### , 명령어 붙여넣기.
# ### pip install konlpy
#
# ### 코드 실행시, 설치한(다운그레이드한 버전, 3.10.7) 선택,
# ### 해당 쥬피터 노트북 관련 커널 설치도 자동으로 함.

# %% [markdown]
# # 용어 정리
# ## 형태소 , 형태소 분석
# ### 형태소: 언어에서 의미가 가장 작은 단위.
# ### 형태소 분석: 형태소, 어근, 접두사/접미사, 품사 등 다양한 속성 구조.
# ### 품사 태깅 예) 상용 이가 좋아 하는 음식 은 국밥 이다.
# ### 음식 : NNG, 이가/JKM , 좋아하는/VV, 이다/EFN , 높임말 : 하신다 -> 신/EPH
# ### 품사 태깅 해주는 패키지 : Hananum, Kkma, Komoran, Okt(Twitter 제공)
# ### Okt , 명사 /Noun , 에/ Josa, 먹는/ Verb , 다/Eomi

# %% [markdown]
# # 샘플 데이터 사용.
# #

# %%
# 최초 실행 때는, 설치 후에 주석하기. 
# !pip install matplotlib
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\it\appdata\roaming\python\python310\site-packages (3.9.1.post1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\it\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in c:\users\it\appdata\roaming\python\python310\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\it\appdata\roaming\python\python310\site-packages (from wordcloud) (2.0.1)
# Requirement already satisfied: pillow in c:\users\it\appdata\roaming\python\python310\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\it\appdata\roaming\python\python310\site-packages (from wordcloud) (3.9.1.post1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\it\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
import json
import re 
# Okt , 한글 품사 태깅하기위한 모듈, 도구.
from konlpy.tag import Okt
from collections import Counter
import matplotlib
import matplotlib.pyplot as plt 
from matplotlib import font_manager, rc 
from wordcloud import WordCloud

# %%
# 샘플 데이터 읽어서, 메모리에서 확인해보기. 
# inputFileName = "./etnews.kr_facebook_2016-01-01_2018-08-01_4차 산업혁명.json"
inputFileName = "./트럼프_naver_news.json"
data = json.loads(open(inputFileName,"r",encoding = "utf-8").read())
data
# Out:
# [{'cnt': 1,
#   'description': '로이터통신은 이날 <b>트럼프</b> 행정부 소식통들을 인용해 이같이 전하면서 특히 도널드 <b>트럼프</b> 대통령은 이날 오후 9시10분(한국시간 5일 오전 11시 10분) 시작하는 상·하원 합동회의 연설 때 협정 합의를 발표하길 희망한다는... ',
#   'link': 'https://www.mk.co.kr/article/11255654',
#   'org_link': 'https://www.mk.co.kr/article/11255654',
#   'pDate': '2025-03-05 09:15:00',
#   'title': '“싸운 건 ‘쇼’”...로이터, “미-우크라 간 광물협정 체결할 수도”'},
#  {'cnt': 2,
#   'description': "중국 국무원은 5일 올해 경제성장률 목표치를 '5%안팎'으로 제시했다. ※CBS노컷뉴스는 여러분의 제보로 함께 세상을 바꿉니다. 각종 비리와 부당대우, 사건사고와 미담 등 모든 얘깃거리를 알려주세요.이메일... ",
#   'link': 'https://www.nocutnews.co.kr/news/6302637?utm_source=naver&utm_medium=article&utm_campaign=20250305091420',
#   'org_link': 'https://www.nocutnews.co.kr/news/6302637?utm_source=naver&utm_medium=article&utm_campaign=20250305091420',
#   'pDate': '2025-03-05 09:15:00',
#   'title': "[속보]<b>트럼프</b>發 '무역전쟁'에도 中 올해 경제성장률 '5% 안팎' 목표"},
#  {'cnt': 3,
#   'description': '도널드 <b>트럼프</b> 미국 대통령 [연합뉴스]  <b>트럼프</b> 행정부의 관세전쟁이 격화하면서 뉴욕증시가 2일 연속 하락 마감했다. 4일(미국 현지시간) 뉴욕증권거래소(NYSE)에 따르면 이날 다우존스30산업평균지수는 전장보다... ',
#   'link': 'https://www.ziksir.com/news/articleView.html?idxno=83782',
#   'org_link': 'https://www.ziksir.com/news/articleView.html?idxno=83782',
#   'pDate': '2025-03-05 09:14:00',
#   'title': '뉴욕증시, 관세전쟁 격화에 2일 연속 하락 마감'},
#  {'cnt': 4,
#   'description': '일부 언론에서 <b>트럼프</b> 행정부 인사들을 인용해 발표가 임박한 것으로 보도했지만 주무 장관은 시기상조라는 인식을 드러낸 것이다. 로이터통신은 4일(현지시간) <b>트럼프</b> 행정부 소식통들을 인용해 양국이 광물 협정에... ',
#   'link': 'https://biz.heraldcorp.com/article/10433631?ref=naver',
#   'org_link': 'https://biz.heraldcorp.com/article/10433631?ref=naver',
#   'pDate': '2025-03-05 09:13:00',
#   'title': '美-우크라 광물협정 임박 보도에…美재무 “지금은 아냐”'},
#  {'cnt': 5,
#   'description': '도널드 <b>트럼프</b> 미국 대통령이 개입해 타결이 임박한 것처럼 보였던 PGA 투어와 LIV 골프 통합 협상이 이른 시일 안에 마무리되기 쉽지 않다는 뜻이다. <b>트럼프</b> 대통령은 최근 2차례나 모너핸 커미셔너를 포함한 PGA 투어... ',
#   'link': 'https://isplus.com/article/view/isp202503050040',
#   'org_link': 'https://isplus.com/article/view/isp202503050040',
#   'pDate': '2025-03-05 09:13:00',
#   'title': '<b>트럼프</b> 개입했지만...PGA 투어 커미셔너 &quot;LIV와 통합 쉽지 않다&quot;'},
#  {'cnt': 6,
#   'description': '도널드 <b>트럼프</b> 대통령의 예고대로 이날 주요 무역국에 대한 관세 부과에 이어 상대국들도 즉각 보복관세로 맞불을 놓으면서 글로벌 무역전쟁 우려 확대 속에 이 같은 흐름이 나타났다고 미국 경제방송... ',
#   'link': 'http://www.choicenews.co.kr/news/articleView.html?idxno=143670',
#   'org_link': 'http://www.choicenews.co.kr/news/articleView.html?idxno=143670',
#   'pDate': '2025-03-05 09:12:00',
#   'title': "美 엔비디아 급반등 이어...삼성전자 · SK하이닉스 '상승 출발'"},
#  {'cnt': 7,
#   'description': '‘영국판 <b>트럼프</b>’로 불리는 나이절 패라지 영국개혁당 대표도 “(밴스는) 틀렸다, 틀렸다, 틀렸다”면서 영국은 아프가니스탄에서 20년 동안 ‘미국의 편’에 섰다고 강조했습니다. 프랑스군 대령 출신인 미셸 고야도... ',
#   'link': 'https://news.kbs.co.kr/news/pc/view/view.do?ncd=8191826&ref=A',
#   'org_link': 'https://news.kbs.co.kr/news/pc/view/view.do?ncd=8191826&ref=A',
#   'pDate': '2025-03-05 09:12:00',
#   'title': '미국 부통령, 우크라 파병 추진 유럽국에 ‘어중이떠중이’ 지칭 논란'},
#  {'cnt': 8,
#   'description': '도널드 <b>트럼프</b> 대통령이 파나마 운하를 미국이 소유해야 한다는 주장의 근거로 삼았던 홍콩 회사의 항만... 그런데 지난해 당선된 <b>트럼프</b> 미국 대통령이 파나마 운하를 미국 소유로 만들어야 한다면서 중국이 파나마... ',
#   'link': 'https://www.hani.co.kr/arti/international/america/1185351.html',
#   'org_link': 'https://www.hani.co.kr/arti/international/america/1185351.html',
#   'pDate': '2025-03-05 09:12:00',
#   'title': '루비오 방문 한 달만에…홍콩 기업 결국 파나마운하 항만지분 미국 기업...'},
#  {'cnt': 9,
#   'description': '김학균 신영證 리서치센터장 인터뷰 <b>트럼프</b> 관세戰, 美 증시에 부담 불가피 전망 “證 조정기, 장기 박스권에... 도널드 <b>트럼프</b> 미국 대통령 발(發) 글로벌 ‘관세 전쟁’이 국내외 증시에 미칠 영향과 이에 따른 투자... ',
#   'link': 'https://biz.heraldcorp.com/article/10433627?ref=naver',
#   'org_link': 'https://biz.heraldcorp.com/article/10433627?ref=naver',
#   'pDate': '2025-03-05 09:11:00',
#   'title': '“<b>트럼프</b> 관세, ‘협상용 엄포’ 아닌 ‘진심’”…그럼에도 韓 증시 기...'},
#  {'cnt': 10,
#   'description': '<b>트럼프</b> 정부가 대(對)러시아 제재 완화를 추진하고 있다는 로이터 통신 보도에 대해선 제재가 해제돼야 러시아와 미국 관계가 정상화될 수 있다고 강조했다. 페스코프 대변인은 &quot;우리가 양국 관계 정상화에 관해 얘기하고... ',
#   'link': 'https://www.pinpointnews.co.kr/news/articleView.html?idxno=325697',
#   'org_link': 'https://www.pinpointnews.co.kr/news/articleView.html?idxno=325697',
#   'pDate': '2025-03-05 09:10:00',
#   'title': '전진건설로봇 주가 방긋...우크라이나 전쟁 종전 임박'},
#  {'cnt': 11,
#   'description': '올해는 <b>트럼프</b> 2기의 보호무역과 관세 부과 등이 인천항에 미치는 영향이 클 것으로 보인다. 이 사장은 물동량 유치 해법으로 타깃 마케팅 강화와 항로 다변화, 특화화물 유치 등을 내세웠다. 구체적으로 미주에서... ',
#   'link': 'https://www.ksg.co.kr/news/main_newsView.jsp?pNum=143935',
#   'org_link': 'https://www.ksg.co.kr/news/main_newsView.jsp?pNum=143935',
#   'pDate': '2025-03-05 09:10:00',
#   'title': '‘물동량 500만TEU시대 마중물’ 인천신항 완전자동화부두 조성 순항'},
#  {'cnt': 12,
#   'description': '사진=연합 미 EPA, 70억 달러 규모 태양광 프로그램 보조금 동결 해제 블룸버그의 5일(현지시간) 보도에 따르면, 미국 환경보호청(EPA)이 도널드 <b>트럼프</b> 대통령 취임 이후 동결했던 모두를 위한... ',
#   'link': 'https://www.esgeconomy.com/news/articleView.html?idxno=10216',
#   'org_link': 'https://www.esgeconomy.com/news/articleView.html?idxno=10216',
#   'pDate': '2025-03-05 09:10:00',
#   'title': '[해외브리핑] 미 EPA, 70억弗 규모 태양광 프로그램 보조금 동결 해제'},
#  {'cnt': 13,
#   'description': '<b>트럼프</b>발 관세 영향으로 미국 증시가 하락 마감했지만, 미국 장 마감 이후 미국 상무부 장관이 캐나다와 멕시코에 부과한 25% 관세 정책과 관련 타협안을 발표할 수 있다고 밝히면서 일부 투자심리가 개선된... ',
#   'link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=02145126642100368',
#   'org_link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=02145126642100368',
#   'pDate': '2025-03-05 09:09:00',
#   'title': '코스피, 美 증시 변동성 속 상승 출발…2550선 등락'},
#  {'cnt': 14,
#   'description': '온타리오와 퀘벡 등 캐나다 주요 주(州)들이 4일(현지시간) 도널드 <b>트럼프</b> 미국 행정부의 관세 부과에 맞서 미국산 술 판매를 금지했다. 더그 포드 온타리오 주지사는 미국산 알코올 판매 금지 조치를 발표하며 &quot;이는... ',
#   'link': 'https://www.news1.kr/world/usa-canada/5708526',
#   'org_link': 'https://www.news1.kr/world/usa-canada/5708526',
#   'pDate': '2025-03-05 09:09:00',
#   'title': '&quot;미국 술 치워라&quot;…캐나다 주 정부들 <b>트럼프</b> 관세에 맞불'},
#  {'cnt': 15,
#   'description': '도널드 <b>트럼프</b> 2기 행정부 출범 이후 미국의 한미동맹에 대한 변함없는 의지를 보여주는 신호라는 해석도 나온다. 에반스 리비어 전 국무부 동아태 담당 수석 부차관보는 미국의소리(VOA) 방송에 “<b>트럼프</b> 행정부에서... ',
#   'link': 'https://biz.heraldcorp.com/article/10433617?ref=naver',
#   'org_link': 'https://biz.heraldcorp.com/article/10433617?ref=naver',
#   'pDate': '2025-03-05 09:08:00',
#   'title': '美, 김여정 ‘칼빈슨함’ 발끈하자 “한국 방어 공약 분명”'},
#  {'cnt': 16,
#   'description': '도널드 <b>트럼프</b> 미국 대통령은 전쟁 중인 우크라이나에 군사원조를 잠정적으로 중단하기로 하면서 유럽 국가들의 안보 우려감을 키우고 있다. 유럽 정상들은 <b>트럼프</b> 대통령 탈세계화 정책이 가시화되자 군사력 증강을... ',
#   'link': 'https://www.etoday.co.kr/news/view/2449778',
#   'org_link': 'https://www.etoday.co.kr/news/view/2449778',
#   'pDate': '2025-03-05 09:08:00',
#   'title': '대성하이텍 &quot;방산 수주 비중 급증…유럽 및 이스라엘과 장기 계약 기대...'},
#  {'cnt': 17,
#   'description': '도널드 <b>트럼프</b> 대통령이 4일(현지시간) 멕시코·캐나다·중국 등 3개국산 수입품에 신규 관세 부과를 발효하고 이들 3개국이 보복 조치에 나서거나 보복을 예고, 관세전쟁이 격화 양상을 보이면서 위험회피... ',
#   'link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=02138566642100368',
#   'org_link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=02138566642100368',
#   'pDate': '2025-03-05 09:08:00',
#   'title': '코스닥, 외인·기관 사자에 1%대 상승…740선'},
#  {'cnt': 18,
#   'description': '도널드 <b>트럼프</b> 미국 대통령이 자유무역협정을 맺은 캐나다와 멕시코에 25%의 관세를 부과한 가운데 미... 그는 &quot;<b>트럼프</b> 대통령은 매우 공정하고 합리적&quot;이라면서 &quot;그래서 저는 그가 그들(멕시코·캐나다)과 함께 뭔가... ',
#   'link': 'https://www.joongang.co.kr/article/25318267',
#   'org_link': 'https://www.joongang.co.kr/article/25318267',
#   'pDate': '2025-03-05 09:07:00',
#   'title': '미 상무 &quot;중간서 만날 수도&quot;…캐·멕 관세 경감 가능 시사'},
#  {'cnt': 19,
#   'description': "도널드 <b>트럼프</b> 미국 대통령이 4일(현지시간)부터 부과하기 시작한 대캐나다 25%의 관세에 대해 캐나다 측이 '보복관세'로 맞불을 놓자, 이에 상응하는 상호관세를 추가로 즉각 부과하겠다고 맞받았다. <b>트럼프</b> 대통령은 이날... ",
#   'link': 'https://www.newsworks.co.kr/news/articleView.html?idxno=786707',
#   'org_link': 'https://www.newsworks.co.kr/news/articleView.html?idxno=786707',
#   'pDate': '2025-03-05 09:06:00',
#   'title': "<b>트럼프</b>, 캐나다 '총리'를 '주지사'로 호칭…상호관세 부과 으름장"},
#  {'cnt': 20,
#   'description': '<b>트럼프</b> 미국 대통령이 캐나다와 멕시코에 대한 관세 경감을 고려하고 있다고 밝혔다. 미국 관세부과 소식 전하는 멕시코 신문(멕시코시티=연합뉴스) 이재림 특파원 = 멕시코산 제품에 대한 미국 도널드 <b>트럼프</b> 2기... ',
#   'link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345450',
#   'org_link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345450',
#   'pDate': '2025-03-05 09:06:00',
#   'title': '美상무 &quot;<b>트럼프</b>, 加ㆍ멕 관세 경감 고려…내일 발표할 듯&quot;(상보)'},
#  {'cnt': 21,
#   'description': '볼로디미르 젤렌스키 우크라이나 대통령(왼쪽)과 도널드 <b>트럼프</b> 미국 대통령. 사진=AFP/연합뉴스  미국이 군사... 않는다&quot;며 &quot;우리는 <b>트럼프</b> 대통령의 강력한 리더십 아래에서 지속적인 평화를 이루기 위해 노력할 준비가 돼... ',
#   'link': 'https://daily.hankooki.com/news/articleView.html?idxno=1186506',
#   'org_link': 'https://daily.hankooki.com/news/articleView.html?idxno=1186506',
#   'pDate': '2025-03-05 09:06:00',
#   'title': '美 원조중단에 속탄 젤렌스키 &quot;백악관 일 유감…바로잡을 때&quot;'},
#  {'cnt': 22,
#   'description': '미국 <b>트럼프</b> 2기 행정부의 국방정책을 설계할 엘브리지 콜비 미국 국방부 정책 담당 차관 지명자가 4일(현지... 도널드 <b>트럼프</b> 대통령의 비전에는 한국과 같이 유능하고 의욕적인 동맹국에 힘을 실어주는 것이 포함된다&quot;고... ',
#   'link': 'https://www.pennmike.com/news/articleView.html?idxno=95380',
#   'org_link': 'https://www.pennmike.com/news/articleView.html?idxno=95380',
#   'pDate': '2025-03-05 09:06:00',
#   'title': '美 국방차관 후보, 한국 정치상황에 공개 우려 입장'},
#  {'cnt': 23,
#   'description': '라이언 대표는 “미국이 해외 원조 사업에 믿을 수 없을 정도로 큰 지원을 해 오다 도널드 <b>트럼프</b> 대통령 취임 이후 갑작스레 지원을 중단해 그리스도교 박해와 난민 발생의 중요한 원인이 되고 있다”고... ',
#   'link': 'https://www.catholictimes.org/article/20250228500132',
#   'org_link': 'https://www.catholictimes.org/article/20250228500132',
#   'pDate': '2025-03-05 09:06:00',
#   'title': '예수회난민봉사기구, 지원 중단에 활동 위축 우려'},
#  {'cnt': 24,
#   'description': '도널드 <b>트럼프</b> 미국 대통령의 재집권과 함께 백악관에 복귀한 배우자 멜라니아 <b>트럼프</b> 여사의 갑작스러운 스타일 변화가 눈길을 끌고 있다. 멜라니아 <b>트럼프</b> 미국 영부인이 3일 베이지색 정장 차림으로 미국 워싱턴 DC... ',
#   'link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=02125446642100368',
#   'org_link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=02125446642100368',
#   'pDate': '2025-03-05 09:06:00',
#   'title': '‘보스레이디’로 변신한 멜라니아...슈트 빼입고 성큼 돌진'},
#  {'cnt': 25,
#   'description': '그는 &quot;<b>트럼프</b> 대통령은 매우 공정하고 합리적&quot;이라며 &quot;그래서 저는 그가 그들(멕시코·캐나다)과 함께 뭔가를 해결할 것이라고 생각한다&quot;고 했습니다. 이어 &quot;그것은 (관세 부과) 유예가 아니며 <b>트럼프</b> 대통령은 방법을... ',
#   'link': 'https://news.jtbc.co.kr/article/NB12237590?influxDiv=NAVER',
#   'org_link': 'https://news.jtbc.co.kr/article/NB12237590?influxDiv=NAVER',
#   'pDate': '2025-03-05 09:06:00',
#   'title': '미 상무 &quot;중간서 만날 수도&quot;…5일 캐·멕 관세 경감 가능성 시사'},
#  {'cnt': 26,
#   'description': '국민의힘은 <b>트럼프</b> 2기 행정부 출범 등 급변하는 국제정세 속에서 국내 철강산업이 당면하고 있는 과제를 논의하고자 포스코 포항제철소를 방문합니다. 권성동 원내대표를 비롯한 원내지도부는 오늘 포스코... ',
#   'link': 'https://www.obsnews.co.kr/news/articleView.html?idxno=1474888',
#   'org_link': 'https://www.obsnews.co.kr/news/articleView.html?idxno=1474888',
#   'pDate': '2025-03-05 09:06:00',
#   'title': '여 지도부, 철강산업 현장간담회…경주 APEC 현장 점검'},
#  {'cnt': 27,
#   'description': '도널드 <b>트럼프</b>(Donald Trump) 미국 대통령이 지난 주말 국가 암호화폐 준비금 계획에 비트코인(Bitcoin)뿐... 이 소식에 암호화폐 시장 매도세는 잠시 주춤했으나 다시 하락했으며 업계 리더들은 <b>트럼프</b>의 다자산 계획에... ',
#   'link': 'https://www.fortunekorea.co.kr/news/articleView.html?idxno=47183',
#   'org_link': 'https://www.fortunekorea.co.kr/news/articleView.html?idxno=47183',
#   'pDate': '2025-03-05 09:06:00',
#   'title': '<b>트럼프</b> 암호화폐 비축 계획, 업계 대립 초래'},
#  {'cnt': 28,
#   'description': '도널드 <b>트럼프</b> 미국 대통령이 서구 동맹이 아닌 러시아와 밀착하면서 유럽의 안보 위기가 고조되고... 월스트리트저널(WSJ)은 &quot;이 계획은 유럽 지도자들이 <b>트럼프</b>의 요구에 패닉에 빠져 있는 순간에 중요한 정책 변화를... ',
#   'link': 'https://view.asiae.co.kr/article/2025030509040360906',
#   'org_link': 'https://view.asiae.co.kr/article/2025030509040360906',
#   'pDate': '2025-03-05 09:06:00',
#   'title': '美로부터 안보 독립 꾀하는 유럽…재무장에 1229조 쓴다'},
#  {'cnt': 29,
#   'description': '미국교회가 <b>트럼프</b> 행정부의 정책, 특히 이민자와 난민 정책에 저항할 것을 공개적으로 촉구했다. 또한 교황은 미국의 JD 밴스 부통령이 국수주의적 정책을 정당화하기 위해 가톨릭 신학을 사용하는 것을 거부했다. <b>트럼프</b>... ',
#   'link': 'https://www.catholictimes.org/article/20250226500031',
#   'org_link': 'https://www.catholictimes.org/article/20250226500031',
#   'pDate': '2025-03-05 09:06:00',
#   'title': '[글로벌칼럼] 프란치스코 교황의 입원이 불러온 예상치 못한 영향'},
#  {'cnt': 30,
#   'description': 'IBM 같은 기업들로 구성된 이사회가 관리하며, 의사 결정과 토큰 배포를 담당한다. 도널드 <b>트럼프</b> 대통령의 재선 이후, 미국에서는 비트코인과 이더리움을 넘어 다양한 토큰 기반의 암호화폐 ETF 신청이 쇄도하고 있다.',
#   'link': 'https://www.digitaltoday.co.kr/news/articleView.html?idxno=555695',
#   'org_link': 'https://www.digitaltoday.co.kr/news/articleView.html?idxno=555695',
#   'pDate': '2025-03-05 09:04:00',
#   'title': 'ETF 다음 타자는 헤데라?…나스닥, SEC에 핵심 서류 제출'},
#  {'cnt': 31,
#   'description': '도널드 <b>트럼프</b> 미국 대통령이 멕시코·캐나다·중국 수입품에 신규 관세 부과를 발효한 첫날인 4일... <b>트럼프</b>의 고율 관세 발효를 불확실성 제거로 받아들여 장 중 저가 매수세가 활발히 유입됐으나 장 마감을 30여분... ',
#   'link': 'https://www.mk.co.kr/article/11255641',
#   'org_link': 'https://www.mk.co.kr/article/11255641',
#   'pDate': '2025-03-05 09:03:00',
#   'title': '[뉴욕증시] 관세전쟁 격화 양상에 일제히 하락…테슬라 4%↓'},
#  {'cnt': 32,
#   'description': '이어 “그래서 그(도널드 <b>트럼프</b> 미국 대통령)가 그들(멕시코·캐나다)과 함께 뭔가 만들어낼 수 있다고 생각한다&quot;며 “그것은 (관세 부과) 유예가 아니지만 그(<b>트럼프</b> 대통령)는 방법을 찾아낼 것&quot;이라고 덧붙였다.... ',
#   'link': 'https://www.ekn.kr/web/view.php?key=20250305026392647',
#   'org_link': 'https://www.ekn.kr/web/view.php?key=20250305026392647',
#   'pDate': '2025-03-05 09:02:00',
#   'title': '美, 멕·加 25% 관세 경감 가능성?…이르면 5일 발표'},
#  {'cnt': 33,
#   'description': '도널드 <b>트럼프</b> 미국 대통령은 4일(현지시간)부터 시행하기로 예고한 중국, 멕시코, 캐나다산 수입품에 대한... 이에따라 현대와 기아는 <b>트럼프</b>의 관세정책으로 인해 오히려 수혜를 볼 수 있다는 관측도 나오고 있다. 주요... ',
#   'link': 'https://www.greened.kr/news/articleView.html?idxno=323943',
#   'org_link': 'https://www.greened.kr/news/articleView.html?idxno=323943',
#   'pDate': '2025-03-05 09:02:00',
#   'title': '<b>트럼프</b>發 관세, GM 토요타보다 현대·기아 사정 낫지만... 우리도 풍전등...'},
#  {'cnt': 34,
#   'description': '도널드 <b>트럼프</b> 미국 대통령의 암호화폐 준비금 발표 이후 급등했으나, 뒤이은 관세 우려로 매도가 발생하면서 8만5000달러 수준을 회복하지 못했다. 4일(현지시간) 경제매체 CNBC에 따르면 <b>트럼프</b> 대통령의 관세 시행 발표... ',
#   'link': 'https://www.digitaltoday.co.kr/news/articleView.html?idxno=555687',
#   'org_link': 'https://www.digitaltoday.co.kr/news/articleView.html?idxno=555687',
#   'pDate': '2025-03-05 09:02:00',
#   'title': '美 암호화폐 준비금보다 관세 공포 컸다…비트코인 부진 계속'},
#  {'cnt': 35,
#   'description': '● 박용진&gt; <b>트럼프</b> 시대잖아요. 불안해 죽겠어요. ○ 앵 커&gt; <b>트럼프</b> 2기, 1기 때도 참 저희가 고전을 면치 못했는데 힘들었고 근데 2기 때는 지금 정부 국가 상황 때문에 준비가 안 되고 있는 상황이라서 더 많이 걱정이 되고.... ',
#   'link': 'http://www.mbn.co.kr/pages/vod/programContents.php?progCode=683&menuCode=4385&bcastSeqNo=1382475',
#   'org_link': 'http://www.mbn.co.kr/pages/vod/programContents.php?progCode=683&menuCode=4385&bcastSeqNo=1382475',
#   'pDate': '2025-03-05 09:02:00',
#   'title': '박용진 &quot;비명횡사 악연? 민주당 승리라는 대의명분 우선&quot; [나는정치인이...'},
#  {'cnt': 36,
#   'description': '아랍 국가들이 “팔레스타인 가자지구를 미국이 점령·소유해 개발하겠다”는 도널드 <b>트럼프</b> 행정부 구상에 맞서 자체 재건 계획을 채택했다. 아랍 국가가 참여하는 위원회가 가자지구를 관리하다가 요르단강... ',
#   'link': 'https://www.hankookilbo.com/News/Read/A2025030508550005279?did=NA',
#   'org_link': 'https://www.hankookilbo.com/News/Read/A2025030508550005279?did=NA',
#   'pDate': '2025-03-05 09:02:00',
#   'title': "아랍연맹 '자체 가자 재건 계획' 채택… <b>트럼프</b> 구상에 반발"},
#  {'cnt': 37,
#   'description': 'com <b>트럼프</b> 대통령과 회담하는 젤렌스키 대통령 [사진=연합뉴스] 지난달 28일 백악관에서 열린 정상회담이... 보도에 따르면 다수의 소식통은 <b>트럼프</b> 대통령이 이날 오후 9시 10분(한국시간 5일 오전 11시 10분) 상·하원... ',
#   'link': 'https://www.ajunews.com/view/20250305084932601',
#   'org_link': 'https://www.ajunews.com/view/20250305084932601',
#   'pDate': '2025-03-05 09:02:00',
#   'title': '로이터 &quot;<b>트럼프</b>, 오늘 연설서 우크라와 광물협정 발표&quot;…베센트 美재무...'},
#  {'cnt': 38,
#   'description': '미국 워싱턴주 공용 전기차 충전소 [사진: 로이터 통신] 도널드 <b>트럼프</b> 행정부가 촉발한 관세전쟁이 자동차... 이 같은 <b>트럼프</b> 행정부의 움직임에 미국 외 다른 나라의 입장은 어떨까. 매체에 따르면 캐나다는 필요하다면... ',
#   'link': 'https://www.digitaltoday.co.kr/news/articleView.html?idxno=555684',
#   'org_link': 'https://www.digitaltoday.co.kr/news/articleView.html?idxno=555684',
#   'pDate': '2025-03-05 09:02:00',
#   'title': '<b>트럼프</b>발 관세 전쟁이 美 전기차 시장에 미치는 영향'},
#  {'cnt': 39,
#   'description': '미국 <b>트럼프</b> 행정부의 관세 정책과 관련해 &quot;미중 무역전쟁이 커질 것이란 관측은 과도하다&quot;고 평가했다. 김병연·강승원·권아민 NH투자증권 연구원은 이날 미국의 정치·경제 전망 보고서에서 &quot;<b>트럼프</b> 대통령이 원하는... ',
#   'link': 'https://www.sentv.co.kr/article/view/sentv202503050025',
#   'org_link': 'https://www.sentv.co.kr/article/view/sentv202503050025',
#   'pDate': '2025-03-05 09:02:00',
#   'title': 'NH투자 &quot;美中 무역전쟁 우려는 과도…딥시크 덕 AI 확산&quot;'},
#  {'cnt': 40,
#   'description': "5일(현지시간) 암호화폐 전문매체 코인텔레그래프에 따르면, 도널드 <b>트럼프</b>(Donald Trump) 미국 대통령 취임... 급락했다가, <b>트럼프</b>의 '암호화폐 준비금' 계획 발표 후 96,000달러까지 반등했지만, 하루 만에 다시... ",
#   'link': 'http://coinreaders.com/148943',
#   'org_link': 'http://coinreaders.com/148943',
#   'pDate': '2025-03-05 09:02:00',
#   'title': '비트코인, 폭락 끝났나? PMI 상승이 가리키는 강세장 신호!'},
#  {'cnt': 41,
#   'description': '도널드 <b>트럼프</b> 대통령의 이민자 추방 계획이 미국 육가공 산업에 큰 타격을 줄 가능성이 제기되고 있다. 블룸버그통신은 4일(현지시간) <b>트럼프</b> 대통령의 정책 변화로 미국 전역의 육가공 공장에서 일하는 노동자들의 법적... ',
#   'link': 'https://zdnet.co.kr/view/?no=20250305085133',
#   'org_link': 'https://zdnet.co.kr/view/?no=20250305085133',
#   'pDate': '2025-03-05 09:01:00',
#   'title': '<b>트럼프</b> 이민자 추방 계획, 미국 육가공 산업에 타격 줄까'},
#  {'cnt': 42,
#   'description': '도널드 <b>트럼프</b> 미국 대통령이 캐나다와 멕시코, 중국의 모든 수입품에 부과하는 고율 관세가 이날부터 발효된 가운데 대상국들이 보복에 나서면서 관세 전쟁이 악화할 것이라는 우려가 시장을 짓눌렀다. <b>트럼프</b>의... ',
#   'link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345449',
#   'org_link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345449',
#   'pDate': '2025-03-05 09:00:00',
#   'title': '[뉴욕마켓워치] <b>트럼프</b> 관세 충격에 주가·달러 하락 지속…국채 혼조'},
#  {'cnt': 43,
#   'description': '로이터통신은 이날 <b>트럼프</b> 행정부 소식통들을 인용해 이같이 전하면서 특히 도널드 <b>트럼프</b> 대통령은 이날 오후 9시10분(한국시간 5일 오전 11시 10분) 시작하는 상·하원 합동회의 연설 때 협정 합의를 발표하길 희망한다는... ',
#   'link': 'https://www.newsworks.co.kr/news/articleView.html?idxno=786709',
#   'org_link': 'https://www.newsworks.co.kr/news/articleView.html?idxno=786709',
#   'pDate': '2025-03-05 09:00:00',
#   'title': '로이터 &quot;美·우크라 광물협상 타결….4일 <b>트럼프</b> 의회 연설 때 발표&quot;'},
#  {'cnt': 44,
#   'description': '도널드 <b>트럼프</b> 미국 대통령이 자유 무역협정을 맺고 있는 캐나다와 멕시코에 25%의 관세를 부과한 가운데... 그는 &quot;<b>트럼프</b> 대통령은 매우 공정하고 합리적&quot;이라면서 &quot;그래서 저는 그가 그들(멕시코·캐나다)과 함께 뭔가... ',
#   'link': 'http://mbnmoney.mbn.co.kr/news/view?news_no=MM1005485581',
#   'org_link': 'http://mbnmoney.mbn.co.kr/news/view?news_no=MM1005485581',
#   'pDate': '2025-03-05 09:00:00',
#   'title': '미 상무부 장관 &quot;중간서 만날 수도&quot;…5일 캐나다·멕시코 관세 경감 가능...'},
#  {'cnt': 45,
#   'description': '간밤 뉴욕장 마감 후 루트닉 미국 상무부 장관이 <b>트럼프</b>가 당장 내일 캐내다, 멕시코 관세를 일부 감면하는 정책을 발표할 수 있다고 발언. 중국 주미대사가 <b>트럼프</b> 관세에 공격적으로 대응하지 않겠다는 입장을... ',
#   'link': 'https://www.ajunews.com/view/20250305085711610',
#   'org_link': 'https://www.ajunews.com/view/20250305085711610',
#   'pDate': '2025-03-05 09:00:00',
#   'title': '[아주증시포커스] 하루 12시간 주식 거래…넥스트레이드 출범 첫날 外'},
#  {'cnt': 46,
#   'description': '쥐스탱 트뤼도 캐나다 총리는 도널드 <b>트럼프</b> 미국 대통령의 25% 관세 부과를 &quot;어리석은 짓&quot;이라고 비판하며... 트뤼도 총리는 4일(현지시간) 캐나다 오타와 의회에서 기자회견을 열고 <b>트럼프</b> 행정부의 관세에 대해 &quot;어떠한... ',
#   'link': 'https://www.newsworks.co.kr/news/articleView.html?idxno=786708',
#   'org_link': 'https://www.newsworks.co.kr/news/articleView.html?idxno=786708',
#   'pDate': '2025-03-05 08:58:00',
#   'title': '트뤼도 加총리 &quot;30조 규모 미국산 수입품에 보복관세 즉각 발효&quot;'},
#  {'cnt': 47,
#   'description': '또 “글로벌 기술 패권 경쟁과 공급망 재편이 가속화되는 가운데 <b>트럼프</b> 행정부의 관세 부과로 우리 주력 산업과 수출기업의 경쟁력이 위협받고 있다”며 “특히 AI 기술·산업 선점을 위한 전쟁에서 뒤처지지 않도록 GPU... ',
#   'link': 'https://view.asiae.co.kr/article/2025030508585298588',
#   'org_link': 'https://view.asiae.co.kr/article/2025030508585298588',
#   'pDate': '2025-03-05 08:58:00',
#   'title': '안도걸 “쿼드러플 경기 추락…추경 편성 필요”'},
#  {'cnt': 48,
#   'description': '도널드 <b>트럼프</b> 미국 대통령이 전날 캐나다와 멕시코에 관세 부과를 확정하면서 EU와 통상갈등도 가시화하고 있으나 유로화 강세에 영향을 미치지는 못했다. 유로화는 지난해 11월 <b>트럼프</b> 대통령 당선 이후... ',
#   'link': 'https://daily.hankooki.com/news/articleView.html?idxno=1186500',
#   'org_link': 'https://daily.hankooki.com/news/articleView.html?idxno=1186500',
#   'pDate': '2025-03-05 08:58:00',
#   'title': '정부 지출 증가에 유로화 올들어 최고치…증시는 급락'},
#  {'cnt': 49,
#   'description': '역설적으로 1월6일은 <b>트럼프</b> 재집권의 토대가 되었다. 종교의 신실함을 증명하는 믿음과 같이, 공화당 지지자와 정치인들 사이에서 1월6일에 대한 평가가 <b>트럼프</b> 대통령에 대한 지지의 시험대로 자리 잡았다. 그리고... ',
#   'link': 'https://www.sisain.co.kr/news/articleView.html?idxno=55083',
#   'org_link': 'https://www.sisain.co.kr/news/articleView.html?idxno=55083',
#   'pDate': '2025-03-05 08:58:00',
#   'title': '“중국이 한국 정치 개입” 믿을수록 반민주적 [시사IN·한국리서치 공...'},
#  {'cnt': 50,
#   'description': '도널드 <b>트럼프</b> 미국 대통령이 자유 무역협정을 맺고 있는 캐나다와 멕시코에 25%의 관세를 부과한 가운데... 그는 &quot;<b>트럼프</b> 대통령은 매우 공정하고 합리적&quot;이라면서 &quot;그래서 저는 그가 그들(멕시코·캐나다)과 함께 뭔가... ',
#   'link': 'https://www.getnews.co.kr/news/articleView.html?idxno=809844',
#   'org_link': 'https://www.getnews.co.kr/news/articleView.html?idxno=809844',
#   'pDate': '2025-03-05 08:58:00',
#   'title': '美상무 &quot;중간서 만날 수도&quot;…5일 加·멕 관세 경감 가능성 시사'},
#  {'cnt': 51,
#   'description': '미국 달러화는 도널드 <b>트럼프</b>의 미국 대선 승리 가능성이 점쳐지자 지난해 9월부터 줄곧 상승했고 <b>트럼프</b>의 대통령 당선 이후 더욱 기세를 올리며 지난해 4분기에만 7.1% 급등했다. <b>트럼프</b> 대통령이 당선인 시절부터 주요... ',
#   'link': 'http://www.g-enews.com/ko-kr/news/article/news_all/2025030505105692983bc914ac71_1/article.html',
#   'org_link': 'http://www.g-enews.com/ko-kr/news/article/news_all/2025030505105692983bc914ac71_1/article.html',
#   'pDate': '2025-03-05 08:58:00',
#   'title': "[초점] 기로에 선 美 달러, 약세 전망 '솔솔'...엔화 주목해야"},
#  {'cnt': 52,
#   'description': "'영국판 <b>트럼프</b>'로 불리는 나이절 패라지 영국개혁당 대표도 &quot;(밴스는) 틀렸다, 틀렸다, 틀렸다&quot;면서 영국은 아프가니스탄에서 20년 동안 '미국의 편'에 섰다고 강조했다. 프랑스군 대령 출신인 미셸 고야도 엑스(X·옛... ",
#   'link': 'https://www.yna.co.kr/view/AKR20250305026700009?input=1195m',
#   'org_link': 'https://www.yna.co.kr/view/AKR20250305026700009?input=1195m',
#   'pDate': '2025-03-05 08:58:00',
#   'title': "美부통령, 우크라 파병 추진 유럽국에 '어중이떠중이' 지칭 논란"},
#  {'cnt': 53,
#   'description': '루카셴코 대통령은 미국이 <b>트럼프</b> 대통령 당선 이후 암호화폐 중심지가 되겠다는 의지를 보인 데서 영감을 받아, 비트코인과 이더리움 등으로 국가 암호화폐 보유고를 만들 계획을 세웠다. 그는 &quot;세계가 가고 있는 길을... ',
#   'link': 'https://www.digitaltoday.co.kr/news/articleView.html?idxno=555676',
#   'org_link': 'https://www.digitaltoday.co.kr/news/articleView.html?idxno=555676',
#   'pDate': '2025-03-05 08:58:00',
#   'title': '벨라루스 대통령, 암호화폐 채굴 개발 지시…&quot;전력 남아돈다&quot;'},
#  {'cnt': 54,
#   'description': '[사진: 셔터스톡] 도널드 <b>트럼프</b> 대통령의 25% 관세 부과 조치로 인해 하루 동안 10억달러 이상의 암호화폐 파생상품 포지션이 청산됐다. 4일(현지시간) 블록체인 매체 코인텔레그래프에 따르면 <b>트럼프</b> 대통령은... ',
#   'link': 'https://www.digitaltoday.co.kr/news/articleView.html?idxno=555678',
#   'org_link': 'https://www.digitaltoday.co.kr/news/articleView.html?idxno=555678',
#   'pDate': '2025-03-05 08:58:00',
#   'title': '<b>트럼프</b> 관세 직격탄…암호화폐 파생상품 하루 만 10억달러 청산'},
#  {'cnt': 55,
#   'description': '베센트 재무장관 &quot;현재로선 테이블 위에 올라와 있지 않다&quot; 로이터 &quot;<b>트럼프</b>, 4일 의회 연설 때 광물협정 합의... 일부 언론에서 <b>트럼프</b> 행정부 인사들을 인용해 발표가 임박한 것으로 보도했지만 주무 장관은 시기상조라는... ',
#   'link': 'https://www.yna.co.kr/view/AKR20250305010551071?input=1195m',
#   'org_link': 'https://www.yna.co.kr/view/AKR20250305010551071?input=1195m',
#   'pDate': '2025-03-05 08:57:00',
#   'title': '美-우크라 광물협정 임박 보도 나왔지만 美재무 &quot;지금은 아냐&quot;(종합)'},
#  {'cnt': 56,
#   'description': '“미국 <b>트럼프</b> 대통령은, 취임 첫날 국가비상사태를 선포하고 군을 투입했다. 불법체류자와 마약 카르텔... 국가비상사태가 아니라고 단언할 수 있는가?” - 거짓 도널드 <b>트럼프</b> 미국 대통령이 발효했다는... ',
#   'link': 'https://www.sisain.co.kr/news/articleView.html?idxno=55139',
#   'org_link': 'https://www.sisain.co.kr/news/articleView.html?idxno=55139',
#   'pDate': '2025-03-05 08:57:00',
#   'title': '윤석열 최후의 변명 팩트체크 [쿠데타의 재구성]'},
#  {'cnt': 57,
#   'description': "울산시가 <b>트럼프</b> 2기 통상정책에 대응하기 위한 대책마련에 나선다. 울산시는 5일 시청 본관 중회의실에서 '수출 유관기관 대책 회의'를 개최한다고 밝혔다. 이날 회의는 3월부터 시행될 미국의 철강·알루미늄 25% 관세 부과... ",
#   'link': 'https://www.news1.kr/local/ulsan/5708568',
#   'org_link': 'https://www.news1.kr/local/ulsan/5708568',
#   'pDate': '2025-03-05 08:57:00',
#   'title': '울산시, <b>트럼프</b> 2기 통상정책 대응 ‘유관기관 대책회의’ 개최'},
#  {'cnt': 58,
#   'description': '테슬라 주가가 4일(현지시간) 또 4% 이상 급락하며 지난해 대선 이후 상승분을 거의 반납했다. 테슬라 주가는 이날 4.4% 하락한 272.04달러로 마감했다. 이는 지난해 11월5일 대선 당일 종가인 251.44달러 이후 최저가이다.... ',
#   'link': 'http://news.mt.co.kr/mtview.php?no=2025030508435319983',
#   'org_link': 'http://news.mt.co.kr/mtview.php?no=2025030508435319983',
#   'pDate': '2025-03-05 08:56:00',
#   'title': '&quot;테슬라 전기차 안 사&quot;…주가 또 4% 급락, <b>트럼프</b> 상승분 대부분 반납'},
#  {'cnt': 59,
#   'description': '<b>트럼프</b> 가상화폐 준비금 발표로 한 차례 폭풍이 지나간 가운데 오는 8일 백악관에서 개최 예정인 가상화폐 관련 수장 회의는 사장의 운명을 가를 중요한 계기가 될 것이라는 전망이다. 이번 주 금요일 백악관에서 <b>트럼프</b>가... ',
#   'link': 'http://www.joseilbo.com/news/news_read.php?uid=538027&class=78&grp=',
#   'org_link': 'http://www.joseilbo.com/news/news_read.php?uid=538027&class=78&grp=',
#   'pDate': '2025-03-05 08:55:00',
#   'title': '리플 등 가상화폐, 오는 8일 <b>트럼프</b> 가상화폐 회의에 운명 달려'},
#  {'cnt': 60,
#   'description': '4일(현지 시간) 미 캘리포니아주 샌프란시스코 시청 밖에서 시위대가 손팻말을 들고 반<b>트럼프</b> 시위를 벌이고 있다. 2025.03.05.',
#   'link': 'https://www.newsis.com/view/NISI20250305_0001783319',
#   'org_link': 'https://www.newsis.com/view/NISI20250305_0001783319',
#   'pDate': '2025-03-05 08:55:00',
#   'title': '&quot;젤렌스키는 영웅, <b>트럼프</b>는 빵점&quot;'},
#  {'cnt': 61,
#   'description': '도널드 <b>트럼프</b> 미국 대통령의 아내 멜라니아 여사의 스타일 변화에 이목이 쏠리고 있다. 멜라니아 여사는... <b>트럼프</b> 대통령 재집권 후 첫 단독 행보다. 이날 멜라니아 여사는 베이지색 정장에 검은색 넥타이를 착용해... ',
#   'link': 'https://www.hankyung.com/article/2025030529847',
#   'org_link': 'https://www.hankyung.com/article/2025030529847',
#   'pDate': '2025-03-05 08:55:00',
#   'title': "이번엔 '보스 레이디'…멜라니아, <b>트럼프</b> 1기와 다른 패션"},
#  {'cnt': 62,
#   'description': '미국의 25% 관세 부과 소식에 캐나다 총리도 25%의 관세 부과, <b>트럼프</b> &quot;캐나다, 美에 보복시 상호관세 즉각... 55%↓ - 달러 인덱스, 105선 진입… 작년 12월 9일 이후 처음 - <b>트럼프</b> &quot;캐나다, 美에 보복시 상호관세 즉각 대응... ',
#   'link': 'https://news.mtn.co.kr/news-detail/2025030508251557027',
#   'org_link': 'https://news.mtn.co.kr/news-detail/2025030508251557027',
#   'pDate': '2025-03-05 08:54:00',
#   'title': '[출근길 뉴스프레소] 상무 &quot;관세 철회 할수도&quot; <b>트럼프</b> 일보 후퇴? / 직격...'},
#  {'cnt': 63,
#   'description': '미국 <b>트럼프</b> 행정부의 관세 전쟁과 인플레이션 우려로 글로벌 금융시장 불확실성이 확대되면서... 운용업계 관계자는 &quot;괴리율은 줄었지만 <b>트럼프</b>발 관세 이슈 등으로 대외적인 불확실성이 큰 데다가 각국의... ',
#   'link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345448',
#   'org_link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345448',
#   'pDate': '2025-03-05 08:54:00',
#   'title': '美 주식 이어 金 사들인 투자자들…ETF 상품 경쟁 가속'},
#  {'cnt': 64,
#   'description': '존 윌리엄스 미국 뉴욕 연방준비은행(연은) 총재가 도널드 <b>트럼프</b> 미 행정부의 관세 정책에 따른 물가 영향이 연내 나타날 것으로 전망했다. 윌리엄스 총재는 4일(현지시간) 미국 뉴욕에서 열린 블룸버그 인베스트... ',
#   'link': 'https://view.asiae.co.kr/article/2025030508500213373',
#   'org_link': 'https://view.asiae.co.kr/article/2025030508500213373',
#   'pDate': '2025-03-05 08:54:00',
#   'title': '뉴욕 연은 총재 &quot;관세 물가 영향 연내 나타날 것&quot;'},
#  {'cnt': 65,
#   'description': '도널드 <b>트럼프</b> 미국 대통령이 관세 전쟁에 다시 힘을 싣고 있다는 점도 경기방어주 매력을 부각하는 요인으로 꼽혔다. 미국 증권시장에서도 필립모리스, 존슨앤드존슨, AT&amp;T 등 경기방어주로 투자 수요가 쏠리는... ',
#   'link': 'https://www.businesspost.co.kr/BP?command=article_view&num=385689',
#   'org_link': 'https://www.businesspost.co.kr/BP?command=article_view&num=385689',
#   'pDate': '2025-03-05 08:54:00',
#   'title': "공포탐욕지수 '극단적 공포' 수준, 하나증권 &quot;SK텔레콤 KT KT&amp;G 한국전력..."},
#  {'cnt': 66,
#   'description': '가자 주민 강제 이주와 부동산 개발 등 도널드 <b>트럼프</b> 미국 대통령이 제시한 가자지구 재건 계획에 대해 아랍... <b>트럼프</b> 대통령의 가자 주민을 이주시키고 가자지구를 중동의 리비에라(휴양지)로 만들겠다는 구상에... ',
#   'link': 'https://www.hani.co.kr/arti/international/arabafrica/1185350.html',
#   'org_link': 'https://www.hani.co.kr/arti/international/arabafrica/1185350.html',
#   'pDate': '2025-03-05 08:54:00',
#   'title': '아랍국가들, 자체 팔레스타인 재건 계획 채택…“팔레스타인인 자신들...'},
#  {'cnt': 67,
#   'description': '워싱턴 AFP=연합뉴스 도널드 <b>트럼프</b> 미국 행정부에서 미 국방정책을 설계할 엘브리지 콜비 미국 국방부 정책 담당 차관 지명자는 4일(현지 시간) 전시작전통제권(전작권) 이전 문제와 관련해 “<b>트럼프</b> 대통령의 외교정책... ',
#   'link': 'http://www.segye.com/newsView/20250305504006?OutUrl=naver',
#   'org_link': 'http://www.segye.com/newsView/20250305504006?OutUrl=naver',
#   'pDate': '2025-03-05 08:52:00',
#   'title': '美국방차관 후보, 韓전작권 이전에 “의욕적인 동맹국. 역할 강화 지지...'},
#  {'cnt': 68,
#   'description': '후보 시절, <b>트럼프</b>와 해리스의 노출량을 비교해 봤어요. 유튜브에서 <b>트럼프</b>의 노출량이 해리스보다 열 배 많았습니다. <b>트럼프</b>는 시시콜콜한 콘텐츠를 자기 채널에 수시로 올려요. <b>트럼프</b>는 노출 빈도가 높으니 친숙한... ',
#   'link': 'http://topclass.chosun.com/news/articleView.html?idxno=34236',
#   'org_link': 'http://topclass.chosun.com/news/articleView.html?idxno=34236',
#   'pDate': '2025-03-05 08:52:00',
#   'title': '사운드웨이브 부사장 최원준 ② / 내가 사는 세상을 사실에 가깝게 보는...'},
#  {'cnt': 69,
#   'description': '미 자산운용사 블랙록 투자그룹이 인수 홍콩기업 CK허치슨 &quot;33조원에 매각&quot; <b>트럼프</b> 압박에 백기…&quot;미국의... 이번 거래를 통해 중국으로부터 파나마 운하 운영권을 되찾겠다며 압박을 지속해 온 <b>트럼프</b> 행정부가 운하... ',
#   'link': 'https://www.asiatoday.co.kr/view.php?key=20250305010001335',
#   'org_link': 'https://www.asiatoday.co.kr/view.php?key=20250305010001335',
#   'pDate': '2025-03-05 08:52:00',
#   'title': "<b>트럼프</b> '파나마 운하' 항구 운영권 찾아왔다"},
#  {'cnt': 70,
#   'description': '도널드 <b>트럼프</b> 미국 대통령 발 관세 불안에도 멕시코, 캐나다와의 협상 가능성 등으로 인해 상승 출발할 것으로 전망했다. 한지영 키움증권 연구원은 “전일 국내 증시는 연휴 기간 중 <b>트럼프</b>의 관세 부과 공식화, M7 동반... ',
#   'link': 'https://www.etoday.co.kr/news/view/2449776',
#   'org_link': 'https://www.etoday.co.kr/news/view/2449776',
#   'pDate': '2025-03-05 08:52:00',
#   'title': '[오늘의 투자전략] 국내 증시, 미국과 멕시코ㆍ캐나다 관세 협상 가능성...'},
#  {'cnt': 71,
#   'description': '미국의 도널드 <b>트럼프</b> 대통령이 최대 무역상대국인 캐나다 멕시코와의 관세전쟁을 협상으로 마무리할 것으로 보인다. CNN방송 등에 따르면 미국의 하워드 러트닉 상무장관은 4일(현지시간) 폭스뉴스와 인터뷰에서 &quot;<b>트럼프</b>... ',
#   'link': 'http://www.seoulwire.com/news/articleView.html?idxno=640803',
#   'org_link': 'http://www.seoulwire.com/news/articleView.html?idxno=640803',
#   'pDate': '2025-03-05 08:50:00',
#   'title': '美 상무장관  &quot;<b>트럼프</b>, 멕시코·캐나다와 무역협상 타결 내일 발표할수...'},
#  {'cnt': 72,
#   'description': '4일(현지시간) 미국 뉴욕증시 주요 지수는 도널드 <b>트럼프</b> 미국 대통령이 선포한 관세 전쟁이... <b>트럼프</b> 대통령은 이날부터 캐나다와 멕시코에 대한 25%의 관세 부과를 전격 단행했다. 중국산 수입품에 대해서는... ',
#   'link': 'https://www.newspim.com/news/view/20250305000026',
#   'org_link': 'https://www.newspim.com/news/view/20250305000026',
#   'pDate': '2025-03-05 08:50:00',
#   'title': '[글로벌 마켓 리포트 3월 5일]'},
#  {'cnt': 73,
#   'description': '도널드 <b>트럼프</b> 미국 대통령이 그린란드를 차지하기 위해 강한 의지를 드러내고 있기 때문이다. 지구 온난화로 인해 북극해의 빙하가 녹으면서 북극 항로의 개척 가능성이 높아진 현 상황에서 그린란드는 북극 지역의... ',
#   'link': 'https://edu.chosun.com/site/data/html_dir/2025/03/05/2025030580017.html',
#   'org_link': 'https://edu.chosun.com/site/data/html_dir/2025/03/05/2025030580017.html',
#   'pDate': '2025-03-05 08:50:00',
#   'title': '[안성진의 본투비 지구과학 이야기] 그린란드와 지구과학'},
#  {'cnt': 74,
#   'description': '도널드 <b>트럼프</b> 미국 대통령(오른쪽)과 웨이저자 TSMC CEO[출처: 연합뉴스 자료사진] 5일 TSMC에 따르면 TSMC는... 전날 백악관에서 이런 계획을 발표한 웨이저자 TSMC 최고경영자(CEO) 옆에는 도널드 <b>트럼프</b> 미국 대통령과... ',
#   'link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345446',
#   'org_link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345446',
#   'pDate': '2025-03-05 08:50:00',
#   'title': '美 파운드리 장악력 높이는 TSMC, 수세 몰리는 삼성전자'},
#  {'cnt': 75,
#   'description': '도널드 <b>트럼프</b> 미국 대통령이 팔을 걷어붙이고 나서면서 급물살을 탈 것 같았던 미국프로골프(PGA) 투어와... <b>트럼프</b> 대통령의 개입으로 타결이 임박한 것처럼 보였던 PGA 투어와 LIV 골프 통합 협상이 이른 시일 안에... ',
#   'link': 'https://www.yna.co.kr/view/AKR20250305029400007?input=1195m',
#   'org_link': 'https://www.yna.co.kr/view/AKR20250305029400007?input=1195m',
#   'pDate': '2025-03-05 08:50:00',
#   'title': '대통령도 나섰는데 PGA 투어 커미셔너 &quot;LIV와 통합 쉽지 않다&quot;'},
#  {'cnt': 76,
#   'description': '도널드 <b>트럼프</b> 미 대통령이 캐나다, 멕시코, 중국을 상대로 시작한 무역 전쟁이 경제적 혼란을 일으킨 것과... NYT는 그러나 <b>트럼프</b>의 의도는 미국의 무역 적자를 줄이는 것이라며 무역 의존도가 낮은 미국이 받는 타격이... ',
#   'link': 'https://www.newsis.com/view/NISX20250305_0003086331',
#   'org_link': 'https://www.newsis.com/view/NISX20250305_0003086331',
#   'pDate': '2025-03-05 08:50:00',
#   'title': '&quot;<b>트럼프</b> 무역 전쟁, 미국보다 캐나다·멕시코 큰 타격&quot;-NYT'},
#  {'cnt': 77,
#   'description': '도널드 <b>트럼프</b> 미국 대통령이 불붙인 관세전쟁이 캐나다와 멕시코에 대한 관세 부과 당일인 4일(현지시간)... <b>트럼프</b> 대통령은 이날 소셜미디어 트루스소셜에 올린 글을 통해 &quot;캐나다의 (쥐스탱) 트뤼도 주지사에게 설명... ',
#   'link': 'http://news.mt.co.kr/mtview.php?no=2025030508445957543',
#   'org_link': 'http://news.mt.co.kr/mtview.php?no=2025030508445957543',
#   'pDate': '2025-03-05 08:49:00',
#   'title': '관세부과 첫날부터 보복선언·추가위협…<b>트럼프</b>發 무역전쟁 본격화'},
#  {'cnt': 78,
#   'description': '도널드 <b>트럼프</b> 미국 대통령이 4일(현지시간) 쥐스탱 트뤼도 캐나다 총리의 관세 대응 인상 발표에 대해 “보복 관세를 단행하면 그와 같은 금액의 상호관세를 즉각 부과하겠다”고 밝혔다. <b>트럼프</b> 대통령은 트뤼도... ',
#   'link': 'https://www.khan.co.kr/article/202503050848001',
#   'org_link': 'https://www.khan.co.kr/article/202503050848001',
#   'pDate': '2025-03-05 08:49:00',
#   'title': '“‘트뤼도 주지사’ 보복 관세? 그럼 우린 또 올려” 재보복 위협한 트...'},
#  {'cnt': 79,
#   'description': '60% 급등 4일(현지시간) 뉴욕증시에서는 도널드 <b>트럼프</b> 미국 대통령의 관세가 촉발한 관세 전쟁으로 소비자... 코리 배리 베스트바이 최고경영자(CEO)는 실적 발표에서 “<b>트럼프</b> 대통령이 부과한 멕시코에 대한 25% 관세와... ',
#   'link': 'https://www.etoday.co.kr/news/view/2449788',
#   'org_link': 'https://www.etoday.co.kr/news/view/2449788',
#   'pDate': '2025-03-05 08:48:00',
#   'title': '[오늘의 뉴욕증시 무버] 관세전쟁에 인플레 우려한 유통주 폭락...베스트...'},
#  {'cnt': 80,
#   'description': '뉴욕증시는 도널드 <b>트럼프</b> 미국 대통령이 캐나다·멕시코·중국에 고율의 관세를 부과하고 상대국이... 또 <b>트럼프</b> 행정부를 세계무역기구(WTO)에 제소하는 방침도 공개했다. 클라우디아 셰인바움 멕시코 대통령은... ',
#   'link': 'https://www.goodkyung.com/news/articleView.html?idxno=259237',
#   'org_link': 'https://www.goodkyung.com/news/articleView.html?idxno=259237',
#   'pDate': '2025-03-05 08:48:00',
#   'title': '뉴욕증시, <b>트럼프</b> 관세 격화에 약세…다우 1.55% 하락'},
#  {'cnt': 81,
#   'description': '배 연구원은 &quot;두산밥캣은 <b>트럼프</b> 2기 행정부 시대에 주목할 만한 업체라고 판단한다&quot;며 &quot;올해 경영계획도 환율 가정이 1320원인 점과 하반기 북미 회복 가능성을 고려하면 보수적 목표라고 보인다&quot;고 분석했다.... ',
#   'link': 'https://www.businesspost.co.kr/BP?command=article_view&num=385688',
#   'org_link': 'https://www.businesspost.co.kr/BP?command=article_view&num=385688',
#   'pDate': '2025-03-05 08:48:00',
#   'title': '두산밥캣 북미 생산으로 업황 반등 수혜 기대, 한화투자 &quot;목표주가 상향...'},
#  {'cnt': 82,
#   'description': '막판 협상이 가능할 줄 알았던 <b>트럼프</b>발 관세 전쟁이 본격화하는 모습에 간밤 뉴욕증시 3대 지수는 일제히 하락했다. <b>트럼프</b> 행정부는 4일(현지시간) 캐나다·멕시코·중국의 수입품에 관세 부과를 발효했다. 이에... ',
#   'link': 'https://news.dealsitetv.com/articles/151674',
#   'org_link': 'https://news.dealsitetv.com/articles/151674',
#   'pDate': '2025-03-05 08:48:00',
#   'title': '[뉴욕 브리핑] <b>트럼프</b>發 관세전쟁 격화…뉴욕증시 동반 하락'},
#  {'cnt': 83,
#   'description': '젤렌스키 대통령은 또 도널드 <b>트럼프</b> 대통령에 대해서도 언급했다. 그는 &quot;우리 가운데 누구도 끝없는 전쟁을 원하지 않는다&quot;며 &quot;우리는 <b>트럼프</b> 대통령의 강력한 리더십 아래에서 지속적인 평화를 이루기 위해 노력할... ',
#   'link': 'http://www.fnnews.com/news/202503050841262303',
#   'org_link': 'http://www.fnnews.com/news/202503050841262303',
#   'pDate': '2025-03-05 08:47:00',
#   'title': '미국이 군사 지원 중단하자 젤렌스키가 제안한 것은'},
#  {'cnt': 84,
#   'description': '도널드 <b>트럼프</b> 미국 대통령은 지난달 이시바 시게루 일본 총리와의 정상회담에서 &quot;일본은 2027년까지 방위비를 내 첫 임기 때보다 2배로 늘릴 것을 약속했다&quot;고 지적했다. 지난해 일본의 방위비 예산은 GDP의 1.6... ',
#   'link': 'https://www.hankyung.com/article/2025030529747',
#   'org_link': 'https://www.hankyung.com/article/2025030529747',
#   'pDate': '2025-03-05 08:47:00',
#   'title': '美국방차관 후보, 동북아 동맹국에 국방비 증액 요구'},
#  {'cnt': 85,
#   'description': '테슬라가 연일 급락하며 <b>트럼프</b> 당선 이후 상승분을 거의 반납한 것은 물론, 전고점 대비 43% 이상... 캐나다는 <b>트럼프</b>가 관세 폭탄을 터트리자 테슬라 전기차에 100% 관세를 부과할 것이라고 천명했었다. 악재투성이인... ',
#   'link': 'https://www.news1.kr/world/usa-canada/5708503',
#   'org_link': 'https://www.news1.kr/world/usa-canada/5708503',
#   'pDate': '2025-03-05 08:47:00',
#   'title': '테슬라 전고점 대비 43% 폭락, 어디까지 떨어지나(종합2)'},
#  {'cnt': 86,
#   'description': '권지언 특파원 = 도널드 <b>트럼프</b> 미국 대통령의 관세 정책이 인플레이션을 일정 수준 부추긴다고 존 윌리엄스... 한다&quot;면서 &quot;<b>트럼프</b>의 관세 정책 여파가 올 하반기 정도에 나타날 것 같기 때문에 관세로 인한 물가 영향도... ',
#   'link': 'https://www.newspim.com/news/view/20250305000075',
#   'org_link': 'https://www.newspim.com/news/view/20250305000075',
#   'pDate': '2025-03-05 08:47:00',
#   'title': '연준 윌리엄스 &quot;<b>트럼프</b> 관세 물가 영향, 올 하반기 나타날 듯&quot;'},
#  {'cnt': 87,
#   'description': '(사진=이미지투데이) ▲도널드 <b>트럼프</b> 미국 대통령 관세 부과로 인한 경제 우려가 커지면서 주식 폭락. <b>트럼프</b> 대통령은 캐나다와 멕시코에 25% 관세를 부과한다고 발표. 중국 상품에 10% 추가 관세 부과. ▲중국과... ',
#   'link': 'https://zdnet.co.kr/view/?no=20250305081611',
#   'org_link': 'https://zdnet.co.kr/view/?no=20250305081611',
#   'pDate': '2025-03-05 08:47:00',
#   'title': '[미장브리핑] 美 관세 부과에 中 보복 조치 단행 예고'},
#  {'cnt': 88,
#   'description': '<b>트럼프</b> 대통령의 관세는 인플레이션(물가 상승)을 유발할 수밖에 없다는 게 경제학자들의 대체적인... <b>트럼프</b> 관세가 잠재적으로 미국 성장에 부정적인 영향을 미칠 수 있을 것이라는 우려가 강해지면서 달러화는... ',
#   'link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=02069686642100368',
#   'org_link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=02069686642100368',
#   'pDate': '2025-03-05 08:46:00',
#   'title': 'NDF, 1451.8원/1452.2원…7.4원 하락'},
#  {'cnt': 89,
#   'description': "금괴(연합뉴스 자료사진) 도널드 <b>트럼프</b> 대통령의 관세 강행 조치가 '보복 관세'를 부르면서 안전자산... <b>트럼프</b> 2기 행정부는 사전 예고된 대로 이날부터 캐나다와 멕시코에 25% 보편관세를 부과하고 중국에 10... ",
#   'link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345445',
#   'org_link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345445',
#   'pDate': '2025-03-05 08:46:00',
#   'title': '[뉴욕 금가격] <b>트럼프</b> 관세 어부지리·달러 약세…연일 반등'},
#  {'cnt': 90,
#   'description': '울산시가 <b>트럼프</b> 2기 통상정책에 대응하기 위한 대책 마련에 나선다. 시는 3월 5일 오전 10시 30분 시청 본관 4층 중회의실에서 ‘수출유관기관 대책 회의’를 개최한다고 전했다. 이날 회의는 3월부터 시행될 미국의 철강... ',
#   'link': 'https://view.asiae.co.kr/article/2025030508461381214',
#   'org_link': 'https://view.asiae.co.kr/article/2025030508461381214',
#   'pDate': '2025-03-05 08:46:00',
#   'title': '울산시, 수출유관기관 대책 회의 개최'},
#  {'cnt': 91,
#   'description': '콜비 지명자는 이날 미국 워싱턴DC에서 열린 상원 군사위원회 인사청문회 서면답변에서 전작권 이전에 대한 질문에 &quot;<b>트럼프</b> 대통령의 외교정책 비전은 한국과 같은 유능하고 의욕적인 동맹국들에 힘을 실어주는 것... ',
#   'link': 'https://www.ichannela.com/news/main/news_detailPage.do?publishId=000000462158',
#   'org_link': 'https://www.ichannela.com/news/main/news_detailPage.do?publishId=000000462158',
#   'pDate': '2025-03-05 08:45:00',
#   'title': '美국방차관 후보, 韓전작권 이전 관련 “역할 강화 지지”'},
#  {'cnt': 92,
#   'description': '도널드 <b>트럼프</b> 미국 대통령이 4일(현지 시각) 캐나다와 멕시코에 25%의 관세를 부과한 다음 날인 5일 미국... 이어 “<b>트럼프</b> 대통령은 매우 공정하고 합리적”이라며 “그래서 저는 그가 그들(멕시코·캐나다)과 함께 뭔가... ',
#   'link': 'https://biz.chosun.com/international/international_general/2025/03/05/VH7SUVGR25CJVHYOREZ733USJY/?utm_source=naver&utm_medium=original&utm_campaign=biz',
#   'org_link': 'https://biz.chosun.com/international/international_general/2025/03/05/VH7SUVGR25CJVHYOREZ733USJY/?utm_source=naver&utm_medium=original&utm_campaign=biz',
#   'pDate': '2025-03-05 08:45:00',
#   'title': '美 상무 “중간서 만날 수도”…캐나다·멕시코 향해 관세 경감 가능성...'},
#  {'cnt': 93,
#   'description': '&quot;<b>트럼프</b> 리더십 아래 지속가능한 평화 원해&quot; &quot;그동안 전쟁 지원한 美에 감사…항상 존중&quot; 아주경제=황진현... com 볼로디미르 젤렌스키 우크라이나 대통령 [사진=로이터·연합뉴스] 미국 군사 원조 중단 등 도널드 <b>트럼프</b>... ',
#   'link': 'https://www.ajunews.com/view/20250305082459573',
#   'org_link': 'https://www.ajunews.com/view/20250305082459573',
#   'pDate': '2025-03-05 08:44:00',
#   'title': '[종합] 젤렌스키 &quot;백악관 일 후회…우크라 공중·해상 휴전 제안&quot;'},
#  {'cnt': 94,
#   'description': '미국은 <b>트럼프</b> 대통령이 예고한 대로 3월 4일 오전 0시부터 멕시코, 캐나다, 중국에 대한 관세를 발효했다.... 관세전쟁이 본격화되는 상황에 <b>트럼프</b> 대통령은 트루스 소셜을 통해 상호관세로 추가 보복관세를 부과할 수... ',
#   'link': 'https://www.newsquest.co.kr/news/articleView.html?idxno=240732',
#   'org_link': 'https://www.newsquest.co.kr/news/articleView.html?idxno=240732',
#   'pDate': '2025-03-05 08:44:00',
#   'title': '[박정식의 국내 주식시황] 관세전쟁 시작되며 인플레이션 및 경기침체 ...'},
#  {'cnt': 95,
#   'description': '특히 도널드 <b>트럼프</b> 미국 대통령은 이날 오후 예정된 미 상·하원 합동회의 연설 때 협정 타결 사실을 발표하길 바라는 것으로 알려졌다. 젤렌스키, 결국 <b>트럼프</b>에 &quot;유감&quot; 사과 영국 로이터통신은 이날 소식통 4명을 인용해... ',
#   'link': 'https://www.hankookilbo.com/News/Read/A2025030508360005195?did=NA',
#   'org_link': 'https://www.hankookilbo.com/News/Read/A2025030508360005195?did=NA',
#   'pDate': '2025-03-05 08:43:00',
#   'title': '로이터 &quot;미국·우크라 광물 협정, 이르면 몇 시간 내 타결 가능성&quot;'},
#  {'cnt': 96,
#   'description': '4일(현지시간) CNBC에 따르면 에버코어는 저변동성 주식이 무역전쟁 징후가 본격적으로 나타난 지난달뿐만 아니라 <b>트럼프</b> 1기였던 지난 2018년에도 더 나은 성과를 보였다고 설명했다. 줄리안 에마누엘 시니어... ',
#   'link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345443',
#   'org_link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345443',
#   'pDate': '2025-03-05 08:42:00',
#   'title': '에버코어ISI가 꼽은 무역전쟁 중 보유하기 좋은 주식은'},
#  {'cnt': 97,
#   'description': 'NH투자증권은 미국 <b>트럼프</b> 행정부의 관세 정책에 관해 &quot;미중 무역전쟁이 커질 것이란 관측은 과도하다&quot;고 5일 평했다. 김병연·강승원·권아민 연구원은 이날 미국의 정치·경제 전망에 관한 보고서에서 &quot;<b>트럼프</b> 대통령이... ',
#   'link': 'https://www.yna.co.kr/view/AKR20250305028100008?input=1195m',
#   'org_link': 'https://www.yna.co.kr/view/AKR20250305028100008?input=1195m',
#   'pDate': '2025-03-05 08:42:00',
#   'title': 'NH투자 &quot;美中 무역전쟁 우려는 과도…딥시크 덕 AI 확산&quot;'},
#  {'cnt': 98,
#   'description': '않으면 가격 상승 시점이 느려질 수 있다&quot;고 덧붙였다. 최근 비트코인 가격은 도널드 <b>트럼프</b> 미국 대통령의 관세 부과 조치와 미국 연방준비제도(연준·Fed)의 금리 변동 등에 영향을 받으며 큰 폭으로 하락했다.',
#   'link': 'https://www.businesspost.co.kr/BP?command=article_view&num=385686',
#   'org_link': 'https://www.businesspost.co.kr/BP?command=article_view&num=385686',
#   'pDate': '2025-03-05 08:42:00',
#   'title': '비트코인 1억3065만 원대 상승, 시장 둔화에도 장기적 강세 흐름 유지 전...'},
#  {'cnt': 99,
#   'description': '러트닉 장관은 5일에 <b>트럼프</b> 대통령이 이들 국가와 타협안을 발표할 가능성이 있다고 덧붙였다. 그는 &quot;<b>트럼프</b> 대통령은 매우 공정하고 합리적&quot;이라면서 &quot;그래서 저는 그가 그들(멕시코·캐나다)과 함께 뭔가 만들어낼 수... ',
#   'link': 'https://www.ngonews.kr/news/articleView.html?idxno=203525',
#   'org_link': 'https://www.ngonews.kr/news/articleView.html?idxno=203525',
#   'pDate': '2025-03-05 08:42:00',
#   'title': '美상무, 캐나다·멕시코 관세 경감 시사...&quot;<b>트럼프</b>, 5일 타협안 발표할...'},
#  {'cnt': 100,
#   'description': '&quot;관세 유예는 없다&quot;면서도 일부 타협 가능성 시사 도널드 <b>트럼프</b> 미국 대통령이 자유 무역협정을 맺고 있는... 그는 &quot;<b>트럼프</b> 대통령은 매우 공정하고 합리적&quot;이라면서 &quot;그래서 저는 그가 그들(멕시코·캐나다)과 함께 뭔가... ',
#   'link': 'https://www.dt.co.kr/contents.html?article_no=2025030502109919002001&ref=naver',
#   'org_link': 'https://www.dt.co.kr/contents.html?article_no=2025030502109919002001&ref=naver',
#   'pDate': '2025-03-05 08:41:00',
#   'title': '[속보] 미국 상무 &quot;중간서 만날 수도&quot;…5일 加·멕 관세 경감 가능성 시...'},
#  {'cnt': 101,
#   'description': '도널드 <b>트럼프</b> 미국 대통령이 캐나다와 멕시코, 중국의 모든 수입품에 부과하는 고율 관세가 이날부터... 하지만 <b>트럼프</b> 대통령이 보복 관세를 부과하면 재보복에 나서겠다고 압박하면서 관세정책의 향방은... ',
#   'link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=02036886642100368',
#   'org_link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=02036886642100368',
#   'pDate': '2025-03-05 08:41:00',
#   'title': '美경기 둔화 키우는 <b>트럼프</b> 관세…환율 1450원대로 하락[외환브리핑]'},
#  {'cnt': 102,
#   'description': '지난달 28일 미국과의 정상회담이 예상치 못한 결렬로 끝난 후, <b>트럼프</b> 대통령의 강한 압박에 직면한 젤렌스키... 않는다&quot;며 &quot;우리는 <b>트럼프</b> 대통령의 강력한 리더십 아래에서 지속적인 평화를 이루기 위해 노력할 준비가 돼... ',
#   'link': 'https://www.newdaily.co.kr/site/data/html/2025/03/05/2025030500021.html',
#   'org_link': 'https://www.newdaily.co.kr/site/data/html/2025/03/05/2025030500021.html',
#   'pDate': '2025-03-05 08:40:00',
#   'title': '고개 숙인 젤렌스키 &quot;<b>트럼프</b> 리더십 아래 평화노력 준비돼&quot; … 공중·해...'},
#  {'cnt': 103,
#   'description': "도널드 <b>트럼프</b> 미국 대통령이 4일(현지시간)부터 예고대로 캐나다·멕시코에 25% 전면 관세를, 중국산... 3일(현지시간) 월스트리트저널(WSJ)은 '<b>트럼프</b>, 가장 어리석은 관세 추락'이라는 제목의 사설에서 &quot;그는 멕시코와... ",
#   'link': 'https://www.news1.kr/world/usa-canada/5708489',
#   'org_link': 'https://www.news1.kr/world/usa-canada/5708489',
#   'pDate': '2025-03-05 08:40:00',
#   'title': 'WSJ &quot;캐·멕 관세, 가장 어리석은 세금…<b>트럼프</b>, 고삐 풀린 관세맨&quot;'},
#  {'cnt': 104,
#   'description': "2019년 7월 방한한 도널드 <b>트럼프</b> 미국 대통령은 직접 '기홍 우'를 찾으며 '천재 사업가'라고 드러내놓고 칭찬하기도 했다. 이는 대한항공이 보잉 항공기를 10조 원 이상 구매한 것과 무관치 않다는 분석이 나왔다.... ",
#   'link': 'https://www.businesspost.co.kr/BP?command=article_view&num=385682',
#   'org_link': 'https://www.businesspost.co.kr/BP?command=article_view&num=385682',
#   'pDate': '2025-03-05 08:40:00',
#   'title': '[Who Is ?] 우기홍 대한항공 대표이사 부회장'},
#  {'cnt': 105,
#   'description': "그는 &quot;엔비디아의 신형 GPU '블랙웰' 출시가 순조롭게 진행되지 않고 있지만, 회사가 문제를 해결해 나가고 있다&quot;며 가장 주목하는 위험 요소는 도널드 <b>트럼프</b> 대통령의 중국 수출 규제가 얼마나 강력하게 시행될지... ",
#   'link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345442',
#   'org_link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345442',
#   'pDate': '2025-03-05 08:40:00',
#   'title': '&quot;엔비디아 저평가?…10년 내 최저 수준 근접&quot;'},
#  {'cnt': 106,
#   'description': '국민의힘 권성동 원내대표를 비롯한 원내지도부는 이날 포스코·한국철강협회와 현장간담회를 열고 <b>트럼프</b>발 관세 전쟁으로 인한 통상 분야의 불확실성 증가와 중국발 철강제품 과잉 공급에 따른 단가 하락 등 국내... ',
#   'link': 'http://www.shinailbo.co.kr/news/articleView.html?idxno=2014972',
#   'org_link': 'http://www.shinailbo.co.kr/news/articleView.html?idxno=2014972',
#   'pDate': '2025-03-05 08:40:00',
#   'title': "與, 오늘 포항서 '철강산업 위기극복' 현장 간담회"},
#  {'cnt': 107,
#   'description': '여기에 <b>트럼프</b> 대통령의 상호 관세 부과 공식 발표로 환율마저 1460원대 수준에서 등락을 거듭하면서 사료가격 안정을 위협하는 요인이 되고 있다. 이처럼 원료곡 상승에 환율 인상 분까지 감안할 경우 사료용 원료곡의... ',
#   'link': 'https://www.farminsight.net/news/articleView.html?idxno=14364',
#   'org_link': 'https://www.farminsight.net/news/articleView.html?idxno=14364',
#   'pDate': '2025-03-05 08:40:00',
#   'title': "농협사료, 사료값 인상 요인에도 가격 인상 '최대한 지연'"},
#  {'cnt': 108,
#   'description': '뉴욕증시는 도널드 <b>트럼프</b> 대통령의 관세 전쟁에 직격탄을 맞았다. 대상국들이 <b>트럼프</b> 대통령의 관세 부과에 즉각 보복에 나서면서 글로벌 전쟁이 본격화됐다. 4일(현지시각) 뉴욕증권거래소(NYSE)에서 블루칩... ',
#   'link': 'http://www.newsprime.co.kr/news/article.html?no=677128',
#   'org_link': 'http://www.newsprime.co.kr/news/article.html?no=677128',
#   'pDate': '2025-03-05 08:40:00',
#   'title': "[해외시황] 뉴욕증시 '관세 전쟁' 격화에 하락…다우 1.55%↓"},
#  {'cnt': 109,
#   'description': '미국 <b>트럼프</b> 행정부가 4일(현지시간)부터 멕시코·캐나다·중국 수입품에 신규 관세 부과를 발효한데 대해... <b>트럼프</b> 행정부는 미 현지시간 오전 0시 1분을 기해 멕시코·캐나다·중국 등 3개국 수입품에 대한 신규... ',
#   'link': 'https://www.busan.com/view/busan/view.php?code=2025030508354861871',
#   'org_link': 'https://www.busan.com/view/busan/view.php?code=2025030508354861871',
#   'pDate': '2025-03-05 08:39:00',
#   'title': '관세전쟁에 뉴욕증시 이틀째 하락…다우 1.55% 하락'},
#  {'cnt': 110,
#   'description': '전일에도 미국증시는 <b>트럼프</b>가 관세 부과를 강행하겠다고 밝히자 나스닥이 2.64% 급락하는 등 일제히 급락했었다. 미국 증시가 이틀 연속 급락하자 저가 매수가 유입됨에 따라 지수 선물이 일제히 상승하고 있는... ',
#   'link': 'https://www.news1.kr/world/usa-canada/5708519',
#   'org_link': 'https://www.news1.kr/world/usa-canada/5708519',
#   'pDate': '2025-03-05 08:39:00',
#   'title': '미증시 급락에도 지수 선물은 일제 상승, 나스닥 0.81%↑'},
#  {'cnt': 111,
#   'description': '도널드 <b>트럼프</b> 미국 대통령이 캐나다와 멕시코, 중국의 모든 수입품에 부과하는 고율 관세가 이날부터 발효된 가운데 대상국들이 보복에 나서면서 관세 전쟁이 악화할 것이라는 우려가 시장을 짓눌렀다. <b>트럼프</b>의... ',
#   'link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345440',
#   'org_link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345440',
#   'pDate': '2025-03-05 08:38:00',
#   'title': '뉴욕증시, 관세 전쟁이 촉발한 롤러코스터…다우 1.55%↓ 마감'},
#  {'cnt': 112,
#   'description': '▲ 젤렌스키 우크라이나 대통령과 도널드 <b>트럼프</b> 미국 대통령 지난달 28일(현지시간) 미국-우크라이나... 로이터통신은 이날 <b>트럼프</b> 행정부 소식통들을 인용해 이같이 전하면서 특히 도널드 <b>트럼프</b> 대통령은 이날 오후 9시... ',
#   'link': 'https://news.sbs.co.kr/news/endPage.do?news_id=N1008007289&plink=ORI&cooper=NAVER',
#   'org_link': 'https://news.sbs.co.kr/news/endPage.do?news_id=N1008007289&plink=ORI&cooper=NAVER',
#   'pDate': '2025-03-05 08:38:00',
#   'title': '로이터 &quot;<b>트럼프</b>, 4일 의회 연설 때 광물협정 합의 발표 원해&quot;'},
#  {'cnt': 113,
#   'description': '맞춤형 컨설팅을 제공하고, 필요시 중앙정부와 협력해 추가 지원책을 마련할 예정이다.전북자치도는 지난 2월 미국 통상정책 변화에 대응하기 위해 6개 실국과 도내 12개 유관기관이 참여하는 ‘<b>트럼프</b> 2기 통상정책... ',
#   'link': 'https://news.mtn.co.kr/news-detail/2025030417335598827',
#   'org_link': 'https://news.mtn.co.kr/news-detail/2025030417335598827',
#   'pDate': '2025-03-05 08:38:00',
#   'title': '전북자치도, <b>트럼프</b> 통상정책에 맞춤형 선제 대응'},
#  {'cnt': 114,
#   'description': '이어 &quot;<b>트럼프</b> 당선 후 인플레이션 감축법(IRA) 축소나 폐지가 예상돼 제조업 기반의 전기차 산업 입지가 축소되는 등, 산업의 판도가 바뀌었다&quot;며 &quot;미국 기업이 패권을 갖고 있는 분야인 자율주행 관련 기술 중심으로 미래... ',
#   'link': 'https://www.meconomynews.com/news/articleView.html?idxno=108926',
#   'org_link': 'https://www.meconomynews.com/news/articleView.html?idxno=108926',
#   'pDate': '2025-03-05 08:38:00',
#   'title': '한투운용, 한국투자글로벌전기차&amp;배터리 펀드 리뉴얼'},
#  {'cnt': 115,
#   'description': 'LG이노텍으로선 반도체 부품업종을 새 성장동력을 삼은 데다 <b>트럼프</b> 발(發) 통상리스크에 대응하는... 현재 글로벌 시장은 <b>트럼프</b> 미국 대통령 발 보호무역주의와 관세정책으로 인해 불확실성이 대두된 상황이다. 특히... ',
#   'link': 'https://www.thebell.co.kr/free/content/ArticleView.asp?key=202502271654209360105595',
#   'org_link': 'https://www.thebell.co.kr/free/content/ArticleView.asp?key=202502271654209360105595',
#   'pDate': '2025-03-05 08:38:00',
#   'title': "[더벨][Board Change]'반도체 부품' 승부수 LG이노텍, 반도체협회 부회장..."},
#  {'cnt': 116,
#   'description': '콜비 후보자의 한국 관련 발언은 도널드 <b>트럼프</b> 행정부 출범에 따라 크게 변화할 수 있다는 우려에 달리 대체로 역대 정부의 정책과 일치하는 내용으로 평가된다. 하만주 워싱턴 특파원',
#   'link': 'https://www.asiatoday.co.kr/view.php?key=20250305010001324',
#   'org_link': 'https://www.asiatoday.co.kr/view.php?key=20250305010001324',
#   'pDate': '2025-03-05 08:38:00',
#   'title': '미 국방차관 후보자 &quot;한국, 방위 분담 우수 사례...미 확장억제 확고&quot;'},
#  {'cnt': 117,
#   'description': '미국 도널드 <b>트럼프</b> 행정부가 4일(현지시간) 멕시코·캐나다·중국 등 3개국산 수입품에 신규 관세 부과를... 뉴욕증시 3대 지수는 전날 <b>트럼프</b> 대통령의 관세 강행 예고 여파로 하락 마감한 데 이어 이날 캐나다와... ',
#   'link': 'https://economist.co.kr/article/view/ecn202503050008',
#   'org_link': 'https://economist.co.kr/article/view/ecn202503050008',
#   'pDate': '2025-03-05 08:37:00',
#   'title': '뉴욕증시, 美 <b>트럼프</b> 관세전쟁 격화에 3대 지수 하락'},
#  {'cnt': 118,
# ...
#   'pDate': '2025-03-05 01:40:00',
#   'title': '<b>트럼프</b> 1기 때와 너무 다르네… ‘보스 레이디’로 변신한 멜라니아'},
#  {'cnt': 963,
#   'description': '후속기사가 이어집니다',
#   'link': 'https://www.newsis.com/view/NISX20250305_0003086118',
#   'org_link': 'https://www.newsis.com/view/NISX20250305_0003086118',
#   'pDate': '2025-03-05 01:39:00',
#   'title': '[속보]트뤼도 &quot;<b>트럼프</b> 관세, WTO에 제소할 것&quot;'},
#  {'cnt': 964,
#   'description': '후속기사가 이어집니다',
#   'link': 'https://www.newsis.com/view/NISX20250305_0003086117',
#   'org_link': 'https://www.newsis.com/view/NISX20250305_0003086117',
#   'pDate': '2025-03-05 01:38:00',
#   'title': '[속보]트뤼도 &quot;<b>트럼프</b>, 관세는 매우 어리석은 짓&quot;'},
#  {'cnt': 965,
#   'description': '',
#   'link': 'https://www.news1.kr/world/general-world/5708391',
#   'org_link': 'https://www.news1.kr/world/general-world/5708391',
#   'pDate': '2025-03-05 01:38:00',
#   'title': '[속보] 캐나다 총리 &quot;<b>트럼프</b> 관세 어리석다…캐나다 물러서지 않아&quot;'},
#  {'cnt': 966,
#   'description': '젤렌스키 &quot;<b>트럼프</b>의 강력한 리더십 아래서 노력할 준비돼있어&quot; 미국·<b>트럼프</b>에 두 차례 &quot;감사&quot;…&quot;백악관 일 유감…바로잡을 때&quot; 대통령 고문, 신중 대응 촉구…내부선 &quot;美, 항복 강요하는 것&quot; 비판도 (파리=연합뉴스) 송진원... ',
#   'link': 'https://www.yna.co.kr/view/AKR20250304177251081?input=1195m',
#   'org_link': 'https://www.yna.co.kr/view/AKR20250304177251081?input=1195m',
#   'pDate': '2025-03-05 01:37:00',
#   'title': '美 원조중단에 속탄 젤렌스키 &quot;공중·해상 휴전&quot; 제안(종합)'},
#  {'cnt': 967,
#   'description': '그는 그간 대립각을 세우던 도널드 <b>트럼프</b> 미국 대통령에게 감사를 표하기도 했다. 젤렌스키 대통령은 이날 X에 &quot;<b>트럼프</b> 대통령의 강한 리더십 아래 지속적인 평화를 위해 노력할 것&quot;이라며 &quot;미국이 우크라이나의 주권을... ',
#   'link': 'https://www.hankookilbo.com/News/Read/A2025030500530002033?did=NA',
#   'org_link': 'https://www.hankookilbo.com/News/Read/A2025030500530002033?did=NA',
#   'pDate': '2025-03-05 01:36:00',
#   'title': '젤렌스키 &quot;가능한 빨리 테이블 앉겠다&quot;… 휴전 협상 참여 시사'},
#  {'cnt': 968,
#   'description': '<b>트럼프</b> 행정부가 탈중앙화 금융(DeFi) 브로커 규정을 철회하는 의회 결정을 지지할 것으로 보인다. 4일(현지시간) 데이비드 색스(David Sacks) <b>트럼프</b> 행정부의 AI·암호화폐 정책 책임자는 X(구 트위터)를 통해 행정부가... ',
#   'link': 'https://www.tokenpost.kr/article-225575',
#   'org_link': 'https://www.tokenpost.kr/article-225575',
#   'pDate': '2025-03-05 01:36:00',
#   'title': '<b>트럼프</b> 행정부, 디파이 브로커 규제 철회 지지… 암호화폐 업계에 호재...'},
#  {'cnt': 969,
#   'description': '<b>트럼프</b> 미국 대통령의 25% 관세 부과를 향해 &quot;어리석은 짓&quot;이라고 비판하며 300억 캐나다 달러(약 30조 원) 규모의 미국산 수입품에 맞불 보복 관세를 즉각 발효한다고 밝혔습니다. 트뤼도 총리는 이날 회견에서 <b>트럼프</b>... ',
#   'link': 'https://news.sbs.co.kr/news/endPage.do?news_id=N1008007084&plink=ORI&cooper=NAVER',
#   'org_link': 'https://news.sbs.co.kr/news/endPage.do?news_id=N1008007084&plink=ORI&cooper=NAVER',
#   'pDate': '2025-03-05 01:33:00',
#   'title': '캐나다 총리 &quot;<b>트럼프</b> 관세 어리석은 짓…보복관세 즉시 발효&quot;'},
#  {'cnt': 970,
#   'description': '김민정 특파원 = 볼로디미르 젤렌스키 우크라이나 대통령은 4일(현지시간) 지난달 28일 백악관에서 도널드 <b>트럼프</b> 미국 대통령과 벌인 설전을 유감스럽게 생각한다며 광물 협정 서명은 물론 <b>트럼프</b> 대통령과 평화를 위해... ',
#   'link': 'https://www.newspim.com/news/view/20250305000003',
#   'org_link': 'https://www.newspim.com/news/view/20250305000003',
#   'pDate': '2025-03-05 01:33:00',
#   'title': '젤렌스키 &quot;백악관 회담 유감…<b>트럼프</b> 지도력에 협력 준비됐다&quot;'},
#  {'cnt': 971,
#   'description': '(이에 대해 집중적으로 다룬 기사 (링크)가 있으니 궁금한 분들 참고하시길!) 금리 인하 <b>트럼프</b> 행정부는... 여담이지만, 중앙은행은 외부의 간섭없이 통화와 금리에 대한 결정을 할 수 있어야 하기에 <b>트럼프</b>의 행동도... ',
#   'link': 'http://www.ddanzi.com/836686984',
#   'org_link': 'http://www.ddanzi.com/836686984',
#   'pDate': '2025-03-05 01:32:00',
#   'title': '삼프로 TV, 이재명의 말을 분석한다 : 이념을 넘어, 현실 경제를 보다'},
#  {'cnt': 972,
#   'description': '<b>트럼프</b> 미국 대통령은 25%의 관세 부과를 강행한 캐나다를 향해 미국 은행의 캐나다 내 영업 불허를 거듭 지적했습니다. <b>트럼프</b>는 SNS에 올린 글에서 &quot;캐나다는 미국 은행이 캐나다에서 사업을 하는 것을 허용하지 않지만... ',
#   'link': 'https://www.ytn.co.kr/_ln/0104_202503050132406760',
#   'org_link': 'https://www.ytn.co.kr/_ln/0104_202503050132406760',
#   'pDate': '2025-03-05 01:32:00',
#   'title': '<b>트럼프</b> &quot;미국 은행의 캐나다 사업 불허는 불공평&quot;'},
#  {'cnt': 973,
#   'description': '<b>트럼프</b> 미국 대통령은 역대 외국 단일 기업 최대 투자액을 들고 온 TSMC의 웨이저자 회장 앞에서 보조금은커녕 대만의 안전 보장도 약속하지 않았다. 이를 두고 대만 공상시보는 4일 “부다페스트 안보 각서의 반복이... ',
#   'link': 'https://www.chosun.com/economy/tech_it/2025/03/05/UOHME6LBR5BNLEHQBIDUHY23PI/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news',
#   'org_link': 'https://www.chosun.com/economy/tech_it/2025/03/05/UOHME6LBR5BNLEHQBIDUHY23PI/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news',
#   'pDate': '2025-03-05 01:31:00',
#   'title': '경악한 대만 “보조금은커녕 안전보장 약속도 없어”'},
#  {'cnt': 974,
#   'description': '<b>트럼프</b>의 사업가식 외교 거래 대만의 반도체 업체 TSMC가 향후 4년간 미국에 1000억달러(약 146조원)를 투자하기로 했다. 도널드 <b>트럼프</b> 미국 대통령은 3일 워싱턴DC 백악관에서 웨이저자 TSMC 회장과 기자회견을 열고... ',
#   'link': 'https://www.chosun.com/international/international_general/2025/03/05/BEQT2L3MRRCM7O35KI5PBCHRVQ/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news',
#   'org_link': 'https://www.chosun.com/international/international_general/2025/03/05/BEQT2L3MRRCM7O35KI5PBCHRVQ/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news',
#   'pDate': '2025-03-05 01:30:00',
#   'title': '1000억달러 투자받곤 “中, 대만 침공 땐 재앙” 립서비스'},
#  {'cnt': 975,
#   'description': '미국 백악관이 도널드 <b>트럼프</b> 대통령의 새로운 관세 정책을 전면 옹호했다. 하워드 러트닉 미 상무장관은 3일(현지시간) CNBC 인터뷰에서 <b>트럼프</b> 행정부의 관세 정책이 미국 제조업 활성화, 재정적자 축소, 차입 비용 절감... ',
#   'link': 'https://www.tokenpost.kr/article-225573',
#   'org_link': 'https://www.tokenpost.kr/article-225573',
#   'pDate': '2025-03-05 01:30:00',
#   'title': "美 백악관, <b>트럼프</b> 관세 정책 전면 옹호… '美 제조업 활성화 기대'"},
#  {'cnt': 976,
#   'description': '도널드 <b>트럼프</b> 미국 대통령은 지난달 27일 워싱턴 DC 백악관을 찾은 키어 스타머 영국 총리로부터 찰스 3세... 이후 인쇄 글씨로 <b>트럼프</b>가 1기 때인 2020년 스코틀랜드의 국왕 별장 덤프리스 하우스를 방문하려던... ',
#   'link': 'https://www.chosun.com/international/international_general/2025/03/05/GBFXMD5FXNBB5B65TW6IIGUI5E/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news',
#   'org_link': 'https://www.chosun.com/international/international_general/2025/03/05/GBFXMD5FXNBB5B65TW6IIGUI5E/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news',
#   'pDate': '2025-03-05 01:30:00',
#   'title': '[깨알지식 Q] <b>트럼프</b>가 받은 초청장… 英 찰스 3세 뭘 쓴 거지'},
#  {'cnt': 977,
#   'description': '김정호 KAIST 교수는 “TSMC가 대규모 투자를 발표하면서 <b>트럼프</b> 정부의 ‘반도체 관세’ 압박이 한국에 집중될 가능성이 있다”며 “TSMC만큼은 아니더라도 미국 투자에 성의를 보여야 하는 상황에 처했다”고 말했다.',
#   'link': 'https://www.chosun.com/economy/tech_it/2025/03/05/PAYTCDZ57RBAHFRC4ACKQTBH7U/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news',
#   'org_link': 'https://www.chosun.com/economy/tech_it/2025/03/05/PAYTCDZ57RBAHFRC4ACKQTBH7U/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news',
#   'pDate': '2025-03-05 01:29:00',
#   'title': '난감한 한국 “당장 투자할 여력 부족”'},
#  {'cnt': 978,
#   'description': '쥐스탱 트뤼도 캐나다 총리가 4일(현지시간) 도널드 <b>트럼프</b> 미국 행정부의 관세 부과와 관련, &quot;정당성도 필요성도 없다&quot;며 &quot;WTO(세계무역기구)에 제소할 방침&quot;이라고 말했다고 로이터 통신이 보도했다.',
#   'link': 'http://news.mt.co.kr/mtview.php?no=2025030501252514784',
#   'org_link': 'http://news.mt.co.kr/mtview.php?no=2025030501252514784',
#   'pDate': '2025-03-05 01:28:00',
#   'title': '[속보]캐나다 총리&quot;<b>트럼프</b> 관세 정당성 없어…WTO 제소&quot;'},
#  {'cnt': 979,
#   'description': '김우중은 미국 2선 대통령 <b>트럼프</b>, 영국 여왕 엘리자베스 2세 등 세계 유력 정치인은 물론 기업가들과 만나 대한민국 직수출의 길을 열어 40대에 재벌 회장이 돼 신화를 이뤘지만, 대우 그룹의 해체와 함께 분식회계... ',
#   'link': 'https://www.topstarnews.net/news/articleView.html?idxno=15610217',
#   'org_link': 'https://www.topstarnews.net/news/articleView.html?idxno=15610217',
#   'pDate': '2025-03-05 01:28:00',
#   'title': '`셀럽병사의 비밀` 이찬원도 정독한 필독서의 저자 김우중 회장의 신기...'},
#  {'cnt': 980,
#   'description': '전날 도널드 <b>트럼프</b> 미국 대통령은 이날부터 모든 캐나다와 멕시코산 수입품에 25%의 관세가 부과된다고... <b>트럼프</b>의 관세 정책 강행 후 자산시장이 요동치는 것에 대해선 &quot;단기적으로 가격의 움직임이 있을 것&quot;이라고... ',
#   'link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345413',
#   'org_link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345413',
#   'pDate': '2025-03-05 01:26:00',
#   'title': '美 상무 &quot;캐나다·멕시코, 마약 통제하면 관세 철폐될 수도&quot;(상보)'},
#  {'cnt': 981,
#   'description': '사진출처: 연합뉴스 영국 총리 키어 스타머는 미국 대통령 도널드 <b>트럼프</b>와 전화 통화를... <b>트럼프</b> 대통령이 우크라이나에 대한 군사 지원 중단을 지시했다는 보도가 나오면서 상황이... ',
#   'link': 'https://www.jemin.com/news/articleView.html?idxno=789304',
#   'org_link': 'https://www.jemin.com/news/articleView.html?idxno=789304',
#   'pDate': '2025-03-05 01:26:00',
#   'title': '영국 총리와 <b>트럼프</b>, 우크라이나 평화 논의하며 통화'},
#  {'cnt': 982,
#   'description': "아랍연맹이 <b>트럼프</b> 미국 대통령의 '가자지구 구상'에 맞설 대안을 논의하기 위한 특별정상회의를 개최했다고... 앞서 <b>트럼프</b> 대통령이 가자지구의 팔레스타인 주민을 주변국으로 이주시키고 가자지구를 미국이 장악해... ",
#   'link': 'https://www.ytn.co.kr/_ln/0104_202503050124158558',
#   'org_link': 'https://www.ytn.co.kr/_ln/0104_202503050124158558',
#   'pDate': '2025-03-05 01:24:00',
#   'title': "아랍연맹 특별정상회의서 '<b>트럼프</b> 가자 구상' 대응 논의"},
#  {'cnt': 983,
#   'description': '',
#   'link': 'https://www.yna.co.kr/view/AKR20250305002200072?input=1195m',
#   'org_link': 'https://www.yna.co.kr/view/AKR20250305002200072?input=1195m',
#   'pDate': '2025-03-05 01:24:00',
#   'title': '[속보] 캐나다 총리 &quot;<b>트럼프</b> 관세, 매우 어리석은 짓&quot;'},
#  {'cnt': 984,
#   'description': '통해 <b>트럼프</b> 행정부에 접근해 우크라이나 전쟁 종식과 함께 노르트 스트림 2 재가동을 위한 협상을 진행 중이다. 이는 <b>트럼프</b> 대통령과 러시아 간 화해의 폭을 보여주는 움직임이다. 논의 내용에 정통한 소식통들에... ',
#   'link': 'http://www.g-enews.com/ko-kr/news/article/news_all/202503041844108854fbbec65dfb_1/article.html',
#   'org_link': 'http://www.g-enews.com/ko-kr/news/article/news_all/202503041844108854fbbec65dfb_1/article.html',
#   'pDate': '2025-03-05 01:24:00',
#   'title': '푸틴 측근 ‘워니그’, 미국 투자자와 노르트 스트림 2 재가동 추진'},
#  {'cnt': 985,
#   'description': '한편, <b>트럼프</b> 정부가 대(對)러시아 제재 완화를 추진하고 있다는 보도에 대해 페스코프 대변인은 제재 해제가 러시아와 미국의 관계 정상화에 필수적이라고 강조했다. 그는 &quot;양국 관계가 정상화되려면 제재로 인한 부정적인... ',
#   'link': 'https://www.cbci.co.kr/news/articleView.html?idxno=488359',
#   'org_link': 'https://www.cbci.co.kr/news/articleView.html?idxno=488359',
#   'pDate': '2025-03-05 01:22:00',
#   'title': "러시아, 미국의 우크라이나 무기 지원 중단을 '평화의 기여'로 환영"},
#  {'cnt': 986,
#   'description': '',
#   'link': 'https://www.yna.co.kr/view/AKR20250305002000072?input=1195m',
#   'org_link': 'https://www.yna.co.kr/view/AKR20250305002000072?input=1195m',
#   'pDate': '2025-03-05 01:21:00',
#   'title': '[1보] 트뤼도 &quot;<b>트럼프</b> 관세 어떤 정당성·필요성도 없어…WTO 제소&quot;'},
#  {'cnt': 987,
#   'description': '투자와 생산 감소는 <b>트럼프</b>발 관세 전쟁과 정치적 불확실성으로 수출이 어려워질 것이라는 전망에... 미국 <b>트럼프</b>정부는 4일(현지시간)부터 캐나다와 멕시코, 중국에 관세를 부과하며 무역전쟁의 시동을 걸었다. 그런데... ',
#   'link': 'https://www.kmib.co.kr/article/view.asp?arcid=1741076024&code=11171111&cp=nv',
#   'org_link': 'https://www.kmib.co.kr/article/view.asp?arcid=1741076024&code=11171111&cp=nv',
#   'pDate': '2025-03-05 01:21:00',
#   'title': '[사설] 생산, 소비, 투자 추락하는 한국경제'},
#  {'cnt': 988,
#   'description': '그는 &quot;<b>트럼프</b> 대통령의 강력한 리더십 아래 모든 것을 다시 올바른 방향으로 돌리고 싶다&quot;며 &quot;우크라이나에 지속 가능한 평화를 되찾고 싶다&quot;고 강조했다. 이어 지난 달 28일 <b>트럼프</b> 대통령과의 파국적인 회담에 대해... ',
#   'link': 'https://www.news1.kr/world/general-world/5708390',
#   'org_link': 'https://www.news1.kr/world/general-world/5708390',
#   'pDate': '2025-03-05 01:21:00',
#   'title': '젤렌스키, <b>트럼프</b> 무기 지원 중단에 &quot;미국에 감사…휴전 협정 체결 희망...'},
#  {'cnt': 989,
#   'description': '회의에서는 도널드 <b>트럼프</b> 미 대통령이 제시한 가자지구 관련 구상을 둘러싼 논의가 진행됐다.... <b>트럼프</b> 대통령이 제시한 구상은 가자지구에 거주하는 팔레스타인 주민들을 인근 국가로... ',
#   'link': 'https://www.jemin.com/news/articleView.html?idxno=789302',
#   'org_link': 'https://www.jemin.com/news/articleView.html?idxno=789302',
#   'pDate': '2025-03-05 01:20:00',
#   'title': '아랍연맹, <b>트럼프</b>의 가자지구 계획에 맞서는 대안 모색'},
#  {'cnt': 990,
#   'description': '인도 투자자들이 도널드 <b>트럼프</b> 미국 대통령의 국가 암호화폐 준비금 조성 발언 이후 디지털 자산 매수에... 이 날 현지 암호화폐 거래소들에 따르면, <b>트럼프</b> 대통령의 발표 직후 인도 내 암호화폐 거래량은 24시간... ',
#   'link': 'http://www.g-enews.com/ko-kr/news/article/news_all/202503041920455456fbbec65dfb_1/article.html',
#   'org_link': 'http://www.g-enews.com/ko-kr/news/article/news_all/202503041920455456fbbec65dfb_1/article.html',
#   'pDate': '2025-03-05 01:18:00',
#   'title': "<b>트럼프</b> '암호화폐 준비금' 발표 이후 인도 거래량 30% 급증"},
#  {'cnt': 991,
#   'description': '클라우디아 셰인바움 멕시코 대통령연합뉴스 자료사진 셰인바움 대통령은 이날 기자회견에서 &quot;(<b>트럼프</b> 관세를) 뒷받침할 동기나 정당성은 없으며, 이는 우리 국민과 국가에 영향을 미칠 것&quot;이라며 이렇게 말했다.... ',
#   'link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345412',
#   'org_link': 'https://news.einfomax.co.kr/news/articleView.html?idxno=4345412',
#   'pDate': '2025-03-05 01:18:00',
#   'title': '멕시코 대통령, <b>트럼프</b> 관세에 &quot;일요일에 대응책 발표&quot;'},
#  {'cnt': 992,
#   'description': '사진출처: 연합뉴스 도널드 <b>트럼프</b> 미국 대통령이 캐나다에 대해 강경한 입장을 재차 드러내며... 그러나 <b>트럼프</b> 행정부는 지난달 4일 예정된 관세 부과를 한 달간 유예한 끝에 결국 이번... ',
#   'link': 'https://www.jemin.com/news/articleView.html?idxno=789301',
#   'org_link': 'https://www.jemin.com/news/articleView.html?idxno=789301',
#   'pDate': '2025-03-05 01:16:00',
#   'title': '미국과 캐나다 간 무역갈등 고조...<b>트럼프</b>, 관세 부과와 함께 제재 경고'},
#  {'cnt': 993,
#   'description': '키어 스타머 영국 총리는 지난 3일(현지 시간) 도널드 <b>트럼프</b> 미국 대통령과 전화 회담을 가졌다고 4일... 레이너 부총리는 스타머 총리가 &quot;평화를 얻는데 집중&quot;하고 있다며 <b>트럼프</b> 대통령, 유럽 등과 &quot;대화&quot;를 계속하겠다고... ',
#   'link': 'https://www.newsis.com/view/NISX20250305_0003086112',
#   'org_link': 'https://www.newsis.com/view/NISX20250305_0003086112',
#   'pDate': '2025-03-05 01:16:00',
#   'title': '英총리, <b>트럼프</b>와 통화…美 우크라 군사원조 중단 전 전화한 듯'},
#  {'cnt': 994,
#   'description': '도널드 <b>트럼프</b> 미국 대통령과 볼로디미르 젤렌스키 우크라이나 대통령 간 갈등이 심화되면서 급물살을 타고 있다. 젤렌스키 대통령은 지난달 28일 백악관에서 <b>트럼프</b> 대통령과 JD 밴스 부통령을 만나 미국의 추가 지원과... ',
#   'link': 'http://www.g-enews.com/ko-kr/news/article/news_all/2025030419374963319a1f309431_1/article.html',
#   'org_link': 'http://www.g-enews.com/ko-kr/news/article/news_all/2025030419374963319a1f309431_1/article.html',
#   'pDate': '2025-03-05 01:14:00',
#   'title': '[초점] 유럽, ‘러 동결 자산 438조원’ 우크라이나 지원 검토'},
#  {'cnt': 995,
#   'description': '양국 정상회담이 파행으로 끝나면서 <b>트럼프</b> 대통령이 압박 수위를 한층 높이는 모습인데요. 베를린 연결해서... 결국, 외교적 대참사로 기록된 백악관 회담에 이어, 미국은 <b>트럼프</b> 대통령이 원하는 대로 광물 협정을 하고... ',
#   'link': 'https://imnews.imbc.com/replay/2025/nw2500/article/6692453_36832.html',
#   'org_link': 'https://imnews.imbc.com/replay/2025/nw2500/article/6692453_36832.html',
#   'pDate': '2025-03-05 01:13:00',
#   'title': "무기 안 주고 '최후통첩'‥&quot;항복 강요하는 것&quot;"},
#  {'cnt': 996,
#   'description': '사진출처: 연합뉴스 미국 <b>트럼프</b> 행정부가 멕시코, 캐나다, 중국산 제품에 신규 관세를... 뉴욕증시 주요 지수들은 전날 <b>트럼프</b> 대통령의 관세 강행 예고 후폭풍으로 인해 하락 마감한 데... ',
#   'link': 'https://www.jemin.com/news/articleView.html?idxno=789300',
#   'org_link': 'https://www.jemin.com/news/articleView.html?idxno=789300',
#   'pDate': '2025-03-05 01:12:00',
#   'title': '관세전쟁 격화로 뉴욕증시 급락...나스닥 조정구간 진입 위기'},
#  {'cnt': 997,
#   'description': '<b>트럼프</b> 정부가 대(對)러시아 제재 완화를 추진하고 있다는 로이터 통신 보도에 대해선 제재가 해제돼야 러시아와 미국 관계가 정상화될 수 있다고 강조했다. 페스코프 대변인은 &quot;우리가 양국 관계 정상화에 관해 얘기하고... ',
#   'link': 'https://www.yna.co.kr/view/AKR20250304171951080?input=1195m',
#   'org_link': 'https://www.yna.co.kr/view/AKR20250304171951080?input=1195m',
#   'pDate': '2025-03-05 01:10:00',
#   'title': '러, 美 우크라 군사지원 중단에 찬사…&quot;평화적 해결 희망&quot;(종합)'},
#  {'cnt': 998,
#   'description': '앞서 도널드 <b>트럼프</b> 대통령은 중국에서 만들어진 펜타닐 등 각종 마약류가 멕시코와 캐나다와 인접한 국경을 통해 자국으로 들어오고 있다면서 지난달 4일부터 이들 나라에 관세를 부과할 것이라 밝혔다. 이에 멕시코와... ',
#   'link': 'https://www.dailian.co.kr/news/view/1468373/?sc=Naver',
#   'org_link': 'https://www.dailian.co.kr/news/view/1468373/?sc=Naver',
#   'pDate': '2025-03-05 01:10:00',
#   'title': '美 관세에 발끈한 멕시코 &quot;모든 수단 동원해서 보복&quot;'},
#  {'cnt': 999,
#   'description': '한다는 <b>트럼프</b> 대통령에 동의한다&quot;고 말했다. 그러면서 &quot;우리는 대만이 적절히 인센티브를 줄 필요가 있다&quot;면서 &quot;대만이 중국과의 불필요한 분쟁을 촉발하지 않도록 동기를 부여하고, 우리가 이문제를 해결할 수 있도록... ',
#   'link': 'https://www.newsis.com/view/NISX20250304_0003086100',
#   'org_link': 'https://www.newsis.com/view/NISX20250304_0003086100',
#   'pDate': '2025-03-05 01:08:00',
#   'title': '콜비 美국방차관 후보 &quot;대만 국방비 GDP 10%로 늘려야&quot;'},
#  {'cnt': 1000,
#   'description': '이를 개선하기 위해 <b>트럼프</b> 행정부의 방향성을 따를 필요가 있다고 언급했다. 또한 우크라이나 전쟁에 대해 민감한 외교적 시기라는 이유로 구체적인 답변을 피했다. 러시아 사이버... ',
#   'link': 'https://www.jemin.com/news/articleView.html?idxno=789299',
#   'org_link': 'https://www.jemin.com/news/articleView.html?idxno=789299',
#   'pDate': '2025-03-05 01:08:00',
#   'title': '미국 국방부의 대만 정책과 국제 관계 전망'}]

# %%
# 해당 데이터에서, 기사 내용인 , message 부분의 값 추출 작업. 
# 임시 저장 문자열
message = ""
# data = [{딕션너리1},{딕션너리2},{딕션너리3},...]
for item in data:
  # if "message" in item.keys():
  if "description" in item.keys():
    # (\w : 문자, 숫자 의미 ) 앞에 ^(not) 가 아닌 것은 모두 -> 공백으로 변경함.
    # 하나의 임시 메세지 문자열 변수에 담기
    message = message + re.sub(r"[^\w]"," ", item["description"]) + ""
    # message = message + re.sub(r"[^\w]"," ", item["message"]) + ""
message
# Out:
# '로이터통신은 이날  b 트럼프  b  행정부 소식통들을 인용해 이같이 전하면서 특히 도널드  b 트럼프  b  대통령은 이날 오후 9시10분 한국시간 5일 오전 11시 10분  시작하는 상 하원 합동회의 연설 때 협정 합의를 발표하길 희망한다는    중국 국무원은 5일 올해 경제성장률 목표치를  5 안팎 으로 제시했다   CBS노컷뉴스는 여러분의 제보로 함께 세상을 바꿉니다  각종 비리와 부당대우  사건사고와 미담 등 모든 얘깃거리를 알려주세요 이메일    도널드  b 트럼프  b  미국 대통령  연합뉴스    b 트럼프  b  행정부의 관세전쟁이 격화하면서 뉴욕증시가 2일 연속 하락 마감했다  4일 미국 현지시간  뉴욕증권거래소 NYSE 에 따르면 이날 다우존스30산업평균지수는 전장보다    일부 언론에서  b 트럼프  b  행정부 인사들을 인용해 발표가 임박한 것으로 보도했지만 주무 장관은 시기상조라는 인식을 드러낸 것이다  로이터통신은 4일 현지시간   b 트럼프  b  행정부 소식통들을 인용해 양국이 광물 협정에    도널드  b 트럼프  b  미국 대통령이 개입해 타결이 임박한 것처럼 보였던 PGA 투어와 LIV 골프 통합 협상이 이른 시일 안에 마무리되기 쉽지 않다는 뜻이다   b 트럼프  b  대통령은 최근 2차례나 모너핸 커미셔너를 포함한 PGA 투어    도널드  b 트럼프  b  대통령의 예고대로 이날 주요 무역국에 대한 관세 부과에 이어 상대국들도 즉각 보복관세로 맞불을 놓으면서 글로벌 무역전쟁 우려 확대 속에 이 같은 흐름이 나타났다고 미국 경제방송     영국판  b 트럼프  b  로 불리는 나이절 패라지 영국개혁당 대표도   밴스는  틀렸다  틀렸다  틀렸다 면서 영국은 아프가니스탄에서 20년 동안  미국의 편 에 섰다고 강조했습니다  프랑스군 대령 출신인 미셸 고야도    도널드  b 트럼프  b  대통령이 파나마 운하를 미국이 소유해야 한다는 주장의 근거로 삼았던 홍콩 회사의 항만    그런데 지난해 당선된  b 트럼프  b  미국 대통령이 파나마 운하를 미국 소유로 만들어야 한다면서 중국이 파나마    김학균 신영證 리서치센터장 인터뷰  b 트럼프  b  관세戰  美 증시에 부담 불가피 전망  證 조정기  장기 박스권에    도널드  b 트럼프  b  미국 대통령 발 發  글로벌  관세 전쟁 이 국내외 증시에 미칠 영향과 이에 따른 투자     b 트럼프  b  정부가 대 對 러시아 제재 완화를 추진하고 있다는 로이터 통신 보도에 대해선 제재가 해제돼야 러시아와 미국 관계가 정상화될 수 있다고 강조했다  페스코프 대변인은  quot 우리가 양국 관계 정상화에 관해 얘기하고    올해는  b 트럼프  b  2기의 보호무역과 관세 부과 등이 인천항에 미치는 영향이 클 것으로 보인다  이 사장은 물동량 유치 해법으로 타깃 마케팅 강화와 항로 다변화  특화화물 유치 등을 내세웠다  구체적으로 미주에서    사진 연합 미 EPA  70억 달러 규모 태양광 프로그램 보조금 동결 해제 블룸버그의 5일 현지시간  보도에 따르면  미국 환경보호청 EPA 이 도널드  b 트럼프  b  대통령 취임 이후 동결했던 모두를 위한     b 트럼프  b 발 관세 영향으로 미국 증시가 하락 마감했지만  미국 장 마감 이후 미국 상무부 장관이 캐나다와 멕시코에 부과한 25  관세 정책과 관련 타협안을 발표할 수 있다고 밝히면서 일부 투자심리가 개선된    온타리오와 퀘벡 등 캐나다 주요 주 州 들이 4일 현지시간  도널드  b 트럼프  b  미국 행정부의 관세 부과에 맞서 미국산 술 판매를 금지했다  더그 포드 온타리오 주지사는 미국산 알코올 판매 금지 조치를 발표하며  quot 이는    도널드  b 트럼프  b  2기 행정부 출범 이후 미국의 한미동맹에 대한 변함없는 의지를 보여주는 신호라는 해석도 나온다  에반스 리비어 전 국무부 동아태 담당 수석 부차관보는 미국의소리 VOA  방송에   b 트럼프  b  행정부에서    도널드  b 트럼프  b  미국 대통령은 전쟁 중인 우크라이나에 군사원조를 잠정적으로 중단하기로 하면서 유럽 국가들의 안보 우려감을 키우고 있다  유럽 정상들은  b 트럼프  b  대통령 탈세계화 정책이 가시화되자 군사력 증강을    도널드  b 트럼프  b  대통령이 4일 현지시간  멕시코 캐나다 중국 등 3개국산 수입품에 신규 관세 부과를 발효하고 이들 3개국이 보복 조치에 나서거나 보복을 예고  관세전쟁이 격화 양상을 보이면서 위험회피    도널드  b 트럼프  b  미국 대통령이 자유무역협정을 맺은 캐나다와 멕시코에 25 의 관세를 부과한 가운데 미    그는  quot  b 트럼프  b  대통령은 매우 공정하고 합리적 quot 이라면서  quot 그래서 저는 그가 그들 멕시코 캐나다 과 함께 뭔가    도널드  b 트럼프  b  미국 대통령이 4일 현지시간 부터 부과하기 시작한 대캐나다 25 의 관세에 대해 캐나다 측이  보복관세 로 맞불을 놓자  이에 상응하는 상호관세를 추가로 즉각 부과하겠다고 맞받았다   b 트럼프  b  대통령은 이날     b 트럼프  b  미국 대통령이 캐나다와 멕시코에 대한 관세 경감을 고려하고 있다고 밝혔다  미국 관세부과 소식 전하는 멕시코 신문 멕시코시티 연합뉴스  이재림 특파원   멕시코산 제품에 대한 미국 도널드  b 트럼프  b  2기    볼로디미르 젤렌스키 우크라이나 대통령 왼쪽 과 도널드  b 트럼프  b  미국 대통령  사진 AFP 연합뉴스  미국이 군사    않는다 quot 며  quot 우리는  b 트럼프  b  대통령의 강력한 리더십 아래에서 지속적인 평화를 이루기 위해 노력할 준비가 돼    미국  b 트럼프  b  2기 행정부의 국방정책을 설계할 엘브리지 콜비 미국 국방부 정책 담당 차관 지명자가 4일 현지    도널드  b 트럼프  b  대통령의 비전에는 한국과 같이 유능하고 의욕적인 동맹국에 힘을 실어주는 것이 포함된다 quot 고    라이언 대표는  미국이 해외 원조 사업에 믿을 수 없을 정도로 큰 지원을 해 오다 도널드  b 트럼프  b  대통령 취임 이후 갑작스레 지원을 중단해 그리스도교 박해와 난민 발생의 중요한 원인이 되고 있다 고    도널드  b 트럼프  b  미국 대통령의 재집권과 함께 백악관에 복귀한 배우자 멜라니아  b 트럼프  b  여사의 갑작스러운 스타일 변화가 눈길을 끌고 있다  멜라니아  b 트럼프  b  미국 영부인이 3일 베이지색 정장 차림으로 미국 워싱턴 DC    그는  quot  b 트럼프  b  대통령은 매우 공정하고 합리적 quot 이라며  quot 그래서 저는 그가 그들 멕시코 캐나다 과 함께 뭔가를 해결할 것이라고 생각한다 quot 고 했습니다  이어  quot 그것은  관세 부과  유예가 아니며  b 트럼프  b  대통령은 방법을    국민의힘은  b 트럼프  b  2기 행정부 출범 등 급변하는 국제정세 속에서 국내 철강산업이 당면하고 있는 과제를 논의하고자 포스코 포항제철소를 방문합니다  권성동 원내대표를 비롯한 원내지도부는 오늘 포스코    도널드  b 트럼프  b  Donald Trump  미국 대통령이 지난 주말 국가 암호화폐 준비금 계획에 비트코인 Bitcoin 뿐    이 소식에 암호화폐 시장 매도세는 잠시 주춤했으나 다시 하락했으며 업계 리더들은  b 트럼프  b 의 다자산 계획에    도널드  b 트럼프  b  미국 대통령이 서구 동맹이 아닌 러시아와 밀착하면서 유럽의 안보 위기가 고조되고    월스트리트저널 WSJ 은  quot 이 계획은 유럽 지도자들이  b 트럼프  b 의 요구에 패닉에 빠져 있는 순간에 중요한 정책 변화를    미국교회가  b 트럼프  b  행정부의 정책  특히 이민자와 난민 정책에 저항할 것을 공개적으로 촉구했다  또한 교황은 미국의 JD 밴스 부통령이 국수주의적 정책을 정당화하기 위해 가톨릭 신학을 사용하는 것을 거부했다   b 트럼프  b     IBM 같은 기업들로 구성된 이사회가 관리하며  의사 결정과 토큰 배포를 담당한다  도널드  b 트럼프  b  대통령의 재선 이후  미국에서는 비트코인과 이더리움을 넘어 다양한 토큰 기반의 암호화폐 E ...

# %%
# 품사 태깅, Okt 패키지 사용하기. 
nlp = Okt()
message_N = nlp.nouns(message)
message_N
# Out:
# ['로이터',
#  '통신',
#  '날',
#  '트럼프',
#  '행정부',
#  '소식통',
#  '인용',
#  '전하',
#  '면서',
#  '도널드',
#  '트럼프',
#  '대통령',
#  '날',
#  '오후',
#  '한국',
#  '시간',
#  '오전',
#  '시작',
#  '상',
#  '하원',
#  '합동',
#  '회의',
#  '연설',
#  '때',
#  '협정',
#  '합의',
#  '발표',
#  '희망',
#  '중국',
#  '국무원',
#  '올해',
#  '경제성장률',
#  '목표',
#  '안팎',
#  '제시',
#  '노컷뉴스',
#  '여러분',
#  '제보',
#  '세상',
#  '각종',
#  '비리',
#  '부당',
#  '대우',
#  '사건',
#  '사고',
#  '미담',
#  '등',
#  '모든',
#  '얘깃',
#  '거리',
#  '이메일',
#  '도널드',
#  '트럼프',
#  '미국',
#  '대통령',
#  '연합뉴스',
#  '트럼프',
#  '행정부',
#  '관세',
#  '전쟁',
#  '격',
#  '뉴욕증시',
#  '연속',
#  '하락',
#  '마감',
#  '미국',
#  '현지',
#  '시간',
#  '뉴욕',
#  '증권',
#  '거래소',
#  '날',
#  '다우존스',
#  '산업',
#  '평균',
#  '지수',
#  '전장',
#  '일부',
#  '언론',
#  '트럼프',
#  '행정부',
#  '인사',
#  '인용',
#  '발표',
#  '임박',
#  '것',
#  '보도',
#  '주무',
#  '장관',
#  '시기상조',
#  '인식',
#  '것',
#  '로이터',
#  '통신',
#  '현지',
#  '시간',
#  '트럼프',
#  '행정부',
#  '소식통',
#  '인용',
#  '양국',
#  '광물',
#  '협정',
#  '도널드',
#  '트럼프',
#  '미국',
#  '대통령',
#  '개입',
#  '타결',
#  '임박',
#  '것',
#  '투어',
#  '골프',
#  '통합',
#  '협상',
#  '시일',
#  '안',
#  '마무리',
#  '뜻',
#  '트럼프',
#  '대통령',
#  '최근',
#  '차례',
#  '핸',
#  '너',
#  '포함',
#  '투어',
#  '도널드',
#  '트럼프',
#  '대통령',
#  '예고',
#  '날',
#  '주요',
#  '무역',
#  '국',
#  '대한',
#  '관세',
#  '부과',
#  '상대',
#  '국',
#  '즉각',
#  '보복',
#  '관세',
#  '불',
#  '글로벌',
#  '무역',
#  '전쟁',
#  '우려',
#  '확대',
#  '속',
#  '이',
#  '흐름',
#  '미국',
#  '경제',
#  '방송',
#  '국판',
#  '트럼프',
#  '로',
#  '나이',
#  '절',
#  '패',
#  '영국',
#  '개혁당',
#  '대표',
#  '밴스',
#  '면서',
#  '영국',
#  '아프가니스탄',
#  '동안',
#  '미국',
#  '편',
#  '강조',
#  '프랑스군',
#  '대령',
#  '출신',
#  '미셸',
#  '도널드',
#  '트럼프',
#  '대통령',
#  '파나마',
#  '운하',
#  '미국',
#  '소유',
#  '주장',
#  '근거',
#  '홍콩',
#  '회사',
#  '항만',
#  '지난해',
#  '당선',
#  '트럼프',
#  '미국',
#  '대통령',
#  '파나마',
#  '운하',
#  '미국',
#  '소유',
#  '중국',
#  '파나마',
#  '김학균',
#  '신영',
#  '리서치',
#  '센터',
#  '인터뷰',
#  '트럼프',
#  '관세',
#  '증시',
#  '부담',
#  '불가피',
#  '전망',
#  '정기',
#  '장기',
#  '박스',
#  '도널드',
#  '트럼프',
#  '미국',
#  '대통령',
#  '발',
#  '글로벌',
#  '관세',
#  '전쟁',
#  '이',
#  '국내외',
#  '증시',
#  '영향',
#  '이',
#  '투자',
#  '트럼프',
#  '정부',
#  '러시아',
#  '제재',
#  '완화',
#  '추진',
#  '로이터',
#  '통신',
#  '보도',
#  '대해',
#  '선',
#  '제재',
#  '해제',
#  '러시아',
#  '미국',
#  '관계',
#  '정상화',
#  '수',
#  '강조',
#  '페',
#  '스코프',
#  '대변인',
#  '우리',
#  '양국',
#  '관계',
#  '정상화',
#  '관해',
#  '얘기',
#  '올해',
#  '트럼프',
#  '기',
#  '보호무역',
#  '관세',
#  '부과',
#  '등',
#  '인천',
#  '항',
#  '영향',
#  '것',
#  '이',
#  '사장',
#  '물동량',
#  '유치',
#  '해법',
#  '타깃',
#  '마케팅',
#  '강화',
#  '항로',
#  '다변',
#  '특',
#  '화물',
#  '유치',
#  '등',
#  '내',
#  '구체',
#  '미주',
#  '사진',
#  '연합',
#  '달러',
#  '규모',
#  '태양광',
#  '프로그램',
#  '보조금',
#  '동결',
#  '해제',
#  '블룸버그',
#  '현지',
#  '시간',
#  '보도',
#  '미국',
#  '환경보호',
#  '청',
#  '이',
#  '도널드',
#  '트럼프',
#  '대통령',
#  '취임',
#  '이후',
#  '동결',
#  '모두',
#  '위',
#  '트럼프',
#  '발',
#  '관세',
#  '영향',
#  '미국',
#  '증시',
#  '하락',
#  '마감',
#  '미국',
#  '장',
#  '마감',
#  '이후',
#  '미국',
#  '상무부',
#  '장관',
#  '캐나다',
#  '멕시코',
#  '부과',
#  '관세',
#  '정책',
#  '관련',
#  '타협',
#  '안',
#  '발표',
#  '수',
#  '일부',
#  '투자',
#  '심리',
#  '개선',
#  '온타리오',
#  '퀘벡',
#  '등',
#  '캐나다',
#  '주요',
#  '주',
#  '현지',
#  '시간',
#  '도널드',
#  '트럼프',
#  '미국',
#  '행정부',
#  '관세',
#  '부과',
#  '미국',
#  '산',
#  '술',
#  '판매',
#  '금지',
#  '더그',
#  '포드',
#  '온타리오',
#  '지사',
#  '미국',
#  '산',
#  '알코올',
#  '판매',
#  '금지',
#  '조치',
#  '발표',
#  '도널드',
#  '트럼프',
#  '기',
#  '행정부',
#  '출범',
#  '이후',
#  '미국',
#  '한미',
#  '동맹',
#  '대한',
#  '의지',
#  '신호',
#  '해석',
#  '에반스',
#  '리비어',
#  '전',
#  '국무부',
#  '아태',
#  '담당',
#  '수석',
#  '부차',
#  '관보',
#  '미국의소리',
#  '방송',
#  '트럼프',
#  '행정부',
#  '도널드',
#  '트럼프',
#  '미국',
#  '대통령',
#  '전쟁',
#  '중인',
#  '우크라이나',
#  '군사',
#  '원조',
#  '잠정',
#  '중단',
#  '유럽',
#  '국가',
#  '안보',
#  '우려',
#  '감',
#  '유럽',
#  '정상',
#  '트럼프',
#  '대통령',
#  '탈',
#  '세계',
#  '정책',
#  '가시',
#  '군사력',
#  '증강',
#  '도널드',
#  '트럼프',
#  '대통령',
#  '현지',
#  '시간',
#  '멕시코',
#  '캐나다',
#  '중국',
#  '등',
#  '개국',
#  '산',
#  '수입품',
#  '신규',
#  '관세',
#  '부과',
#  '발효',
#  '이',
#  '개국',
#  '보복',
#  '조치',
#  '보복',
#  '예고',
#  '관세',
#  '전쟁',
#  '격화',
#  '양상',
#  '위험',
#  '회피',
#  '도널드',
#  '트럼프',
#  '미국',
#  '대통령',
#  '자유무역',
#  '협정',
#  '캐나다',
#  '멕시코',
#  '의',
#  '관세',
#  '부과',
#  '가운데',
#  '그',
#  '트럼프',
#  '대통령',
#  '매우',
#  '합리',
#  '저',
#  '그',
#  '그',
#  '멕시코',
#  '캐나다',
#  '과',
#  '뭔가',
#  '도널드',
#  '트럼프',
#  '미국',
#  '대통령',
#  '현지',
#  '시간',
#  '부터',
#  '부과',
#  '시작',
#  '캐나다',
#  '의',
#  '관세',
#  '대해',
#  '캐나다',
#  '측',
#  '보복',
#  '관세',
#  '로',
#  '불',
#  '이',
#  '상응',
#  '상호',
#  '관세',
#  '추가',
#  '즉각',
#  '부과',
#  '트럼프',
#  '대통령',
#  '날',
#  '트럼프',
#  '미국',
#  '대통령',
#  '캐나다',
#  '멕시코',
#  '대한',
#  '관세',
#  '경감',
#  '고려',
#  '미국',
#  '관세',
#  '부과',
#  '소식',
#  '전하',
#  '멕시코',
#  '신문',
#  '멕시코시티',
#  '연합뉴스',
#  '재림',
#  '특파원',
#  '멕시코',
#  '산',
#  '제품',
#  '대한',
#  '미국',
#  '도널드',
#  '트럼프',
#  '기',
#  '볼',
#  '로디',
#  '미르',
#  '젤',
#  '렌스',
#  '키',
#  '우크라이나',
#  '대통령',
#  '왼쪽',
#  '과',
#  '도널드',
#  '트럼프',
#  '미국',
#  '대통령',
#  '사진',
#  '연합뉴스',
#  '미국',
#  '군사',
#  '며',
#  '우리',
#  '트럼프',
#  '대통령',
#  '리더십',
#  '아래',
#  '지속',
#  '평화',
#  '위해',
#  '노력',
#  '준비',
#  '미국',
#  '트럼프',
#  '기',
#  '행정부',
#  '국방',
#  '정책',
#  '설계',
#  '엘',
#  '브리지',
#  '콜비',
#  '미국',
#  '국방부',
#  '정책',
#  '담당',
#  '차관',
#  '지명자',
#  '현지',
#  '도널드',
#  '트럼프',
#  '대통령',
#  '한국',
#  '의욕',
#  '동맹국',
#  '힘',
#  '실어',
#  '것',
#  '포함',
#  '고',
#  '라이언',
#  '대표',
#  '미국',
#  '해외',
#  '원조',
#  '사업',
#  '수',
#  '정도',
#  '지원',
#  '해',
#  '도널드',
#  '트럼프',
#  '대통령',
#  '취임',
#  '이후',
#  '갑작스레',
#  '지원',
#  '중단',
#  '그리스도교',
#  '박해',
#  '난민',
#  '발생',
#  '원인',
#  '고',
#  '도널드',
#  '트럼프',
#  '미국',
#  '대통령',
#  '재',
#  '집권',
#  '백악관',
#  '복귀',
#  '배우자',
#  '멜라',
#  '니아',
#  '트럼프',
#  '여사',
#  '스타일',
#  '변화',
#  '눈길',
#  '끌',
#  '멜라',
#  '니아',
#  '트럼프',
#  '미국',
#  '영부인',
#  '베이지색',
#  '정장',
#  '차림',
#  '미국',
#  '워싱턴',
#  '그',
#  '트럼프',
#  '대통령',
#  '매우',
#  '합리',
#  '라며',
#  '저',
#  '그',
#  '그',
#  '멕시코',
#  '캐나다',
#  '과',
#  '뭔가',
#  '해결',
#  '것',
#  '생각',
#  '고',
#  '그것',
#  '관세',
#  '부과',
#  '유예',
#  '트럼프',
#  '대통령',
#  '방법',
#  '국민',
#  '힘',
#  '트럼프',
#  '기',
#  '행정부',
#  '출범',
#  '등',
#  '급변',
#  '국제',
#  '정세',
#  '속',
#  '국내',
#  '철강',
#  '산업',
#  '당면',
#  '과제',
#  '논의',
#  '포스코',
#  '포항',
#  '제철소',
#  '방문',
#  '권성동',
#  '원내대표',
#  '비롯',
#  '내지',
#  '도부',
#  '오늘',
#  '포스코',
#  '도널드',
#  '트럼프',
#  '미국',
#  '대통령',
#  '지난',
#  '주말',
#  '국가',
#  '암호',
#  '화폐',
#  '준비',
#  '금',
#  '계획',
#  '비트코인',
#  '뿐',
#  '이',
#  '소식',
#  '암호',
#  '화폐',
#  '시장',
#  '도세',
#  '잠시',
#  '주춤',
#  '다시',
#  '하락',
#  '업계',
#  '리더',
#  '트럼프',
#  '의',
#  '다자',
#  '산',
#  '계획',
#  '도널드',
#  '트럼프',
#  '미국',
#  '대통령',
#  '서구',
#  '동맹',
#  '러시아',
#  '밀착',
#  '유럽',
#  '안보',
#  '위기',
#  '고조',
#  '월스트리트저널',
#  '은',
#  '이',
#  '계획',
#  '유럽',
#  '지도자',
#  '트럼프',
#  '의',
#  '요구',
#  '패닉',
#  '순간',
#  '정책',
#  '변화',
#  '미국',
#  '교회',
#  '트럼프',
#  '행정부',
#  '정책',
#  '이민자',
#  '난민',
#  '정책',
#  '저항',
#  '것',
#  '공개',
#  '촉구',
#  '또한',
#  '교황',
#  '미국',
#  '밴스',
#  '부통령',
#  '국수',
#  '주의',
#  '정책',
#  '정당화',
#  '위해',
#  '가톨릭',
#  '신학',
#  '사용',
#  '것',
#  '거부',
#  '트럼프',
#  '기업',
#  '구성',
#  '이사회',
#  '관리',
#  '의사',
#  '결정',
#  '토큰',
#  '배포',
#  '담당',
#  '도널드',
#  '트럼프',
#  '대통령',
#  '재선',
#  '이후',
#  '미국',
#  '비트코인',
#  '더',
#  '리움',
#  '토큰',
#  '기반',
#  '암호',
#  '화폐',
#  '신청',
#  '쇄도',
#  '도널드',
#  '트럼프',
#  '미국',
#  '대통령',
#  '멕시코',
#  '캐나다',
#  '중국',
#  '수입품',
#  '신규',
#  '관세',
#  '부과',
#  '발효',
#  '첫날',
#  '트럼프',
#  '의',
#  '율',
#  '관세',
#  '발효',
#  '불확실',
#  '제거',
#  '장',
#  '중',
#  '저가',
#  '유입',
#  '장',
#  '마감',
#  '여분',
#  '그',
#  '도널드',
#  '트럼프',
#  '미국',
#  '대통령',
#  '그',
#  '멕시코',
#  '캐나다',
#  '과',
#  '뭔가',
#  '낼',
#  '수',
#  '생각',
#  '며',
#  '그것',
#  '관세',
#  '부과',
#  '유예',
#  '그',
#  '트럼프',
#  '대통령',
#  '방법',
#  '것',
#  '도널드',
#  '트럼프',
#  '미국',
#  '대통령',
#  '현지',
#  '시간',
#  '부터',
#  '시행',
#  '예고',
#  '중국',
#  '멕시코',
#  '캐나다',
#  '산',
#  '수입품',
#  '대한',
#  '이',
#  '현대',
#  '기아',
#  '트럼프',
#  '의',
#  '관세',
#  '정책',
#  '오히려',
#  '수혜',
#  '볼',
#  '수',
#  '관측',
#  '주요',
#  '도널드',
#  '트럼프',
#  '미국',
#  '대통령',
#  '암호',
#  '화폐',
#  '준비',
#  '금',
#  '발표',
#  '이후',
#  '급등',
#  '뒤',
#  '관세',
#  '우려',
#  '매도',
#  '발생',
#  '수준',
#  '현지',
#  '시간',
#  '경제',
#  '매체',
#  '트럼프',
#  '대통령',
#  '관세',
#  '시행',
#  '발표',
#  '박용진',
#  '트럼프',
#  '시대',
#  '트럼프',
#  '기',
#  '기',
#  '때',
#  '저희',
#  '고전',
#  '면치',
#  '기',
#  '때',
#  '지금',
#  '정부',
#  '국가',
#  '상황',
#  '때문',
#  '준비',
#  '안',
#  '상황',
#  '더',
#  '걱정',
#  '아랍',
#  '국가',
#  '팔레스타인',
#  '가자지구',
#  '미국',
#  '점령',
#  '소유',
#  '개발',
#  '도널드',
#  '트럼프',
#  '행정부',
#  '구상',
#  '자체',
#  '재건',
#  '계획',
#  '채택',
#  '아랍',
#  '국가',
#  '참여',
#  '위원회',
#  '가자지구',
#  '관리',
#  '요르단강',
#  '트럼프',
#  '대통령',
#  '회담',
#  '젤',
#  '렌스',
#  '키',
#  '대통령',
#  '사진',
#  '연합뉴스',
#  '지난달',
#  '백악관',
#  '정상회담',
#  '보도',
#  '다수',
#  '소식통',
#  '트럼프',
#  '대통령',
#  '날',
#  '오후',
#  '한국',
#  '시간',
#  '오전',
#  '상',
#  '하원',
#  '미국',
#  '워싱턴주',
#  '공용',
#  '전기차',
#  '충전',
#  '소',
#  '사진',
#  '로이터',
#  '통신',
#  '도널드',
#  '트럼프',
#  '행정부',
#  '촉발',
#  '관세',
#  '전쟁',
#  '자동차',
#  '이',
#  '트럼프',
#  '행정부',
#  '움직임',
#  '미국',
#  '외',
#  '다른',
#  '나라',
#  '입장',
#  '매체',
#  '캐나다',
#  '미국',
#  '트럼프',
#  '행정부',
#  '관세',
#  ...]

# %%
# 집계 데이터 기본 탐색, 모델 구축 하기. 
count = Counter(message_N)
count
# Out:
# Counter({'트럼프': 1776,
#          '대통령': 1162,
#          '미국': 1001,
#          '관세': 946,
#          '도널드': 692,
#          '캐나다': 447,
#          '부과': 338,
#          '멕시코': 305,
#          '행정부': 287,
#          '현지': 240,
#          '것': 227,
#          '시간': 226,
#          '중국': 207,
#          '날': 186,
#          '전쟁': 186,
#          '의': 166,
#          '정책': 160,
#          '대한': 155,
#          '보복': 153,
#          '이': 149,
#          '등': 142,
#          '우크라이나': 134,
#          '그': 122,
#          '기': 115,
#          '키': 105,
#          '렌스': 100,
#          '젤': 99,
#          '이후': 91,
#          '대해': 90,
#          '무역': 88,
#          '수입품': 84,
#          '한국': 83,
#          '총리': 81,
#          '트뤼': 77,
#          '우려': 75,
#          '발표': 71,
#          '산': 71,
#          '영향': 70,
#          '추가': 70,
#          '수': 69,
#          '가운데': 68,
#          '하락': 66,
#          '예고': 66,
#          '정부': 65,
#          '백악관': 65,
#          '발효': 64,
#          '경제': 62,
#          '뉴욕': 61,
#          '발': 61,
#          '조치': 61,
#          '준비': 61,
#          '고': 60,
#          '대응': 60,
#          '협정': 59,
#          '지난달': 58,
#          '지난': 57,
#          '시장': 57,
#          '중단': 55,
#          '전': 53,
#          '볼': 50,
#          '본격': 50,
#          '시작': 48,
#          '회의': 48,
#          '취임': 48,
#          '상호': 48,
#          '미르': 48,
#          '로디': 47,
#          '며': 47,
#          '글로벌': 46,
#          '우리': 46,
#          '화폐': 46,
#          '뉴욕증시': 44,
#          '위해': 44,
#          '로이터': 43,
#          '장관': 43,
#          '암호': 43,
#          '후': 43,
#          '기자': 43,
#          '사진': 42,
#          '과': 42,
#          '때': 41,
#          '군사': 41,
#          '지원': 41,
#          '기업': 41,
#          '연방': 41,
#          '강행': 41,
#          '통신': 40,
#          '세계': 40,
#          '매우': 40,
#          '시행': 40,
#          '를': 40,
#          '즉각': 39,
#          '출범': 39,
#          '쥐스탱': 39,
#          '전날': 39,
#          '이번': 39,
#          '경기': 39,
#          '지수': 38,
#          '로': 38,
#          '투자': 38,
#          '제품': 38,
#          '의회': 38,
#          '데': 38,
#          '지난해': 37,
#          '증시': 37,
#          '관련': 37,
#          '상황': 37,
#          '산업': 36,
#          '협상': 36,
#          '리더십': 36,
#          '예정': 36,
#          '연설': 35,
#          '국가': 35,
#          '국내': 35,
#          '계획': 35,
#          '상승': 35,
#          '반도체': 35,
#          '최근': 34,
#          '불': 34,
#          '주요': 33,
#          '평화': 33,
#          '연합뉴스': 32,
#          '아래': 32,
#          '워싱턴': 32,
#          '중': 32,
#          '급락': 32,
#          '압박': 32,
#          '통해': 32,
#          '국': 31,
#          '불확실': 31,
#          '윌리엄스': 31,
#          '총재': 31,
#          '인상': 31,
#          '시각': 31,
#          '전망': 30,
#          '개국': 30,
#          '노력': 30,
#          '가격': 30,
#          '모든': 29,
#          '당선': 29,
#          '유럽': 29,
#          '더': 29,
#          '가능성': 29,
#          '은행': 29,
#          '분석': 29,
#          '둔화': 29,
#          '소식통': 28,
#          '보도': 28,
#          '영국': 28,
#          '달러': 28,
#          '특파원': 28,
#          '재': 28,
#          '정상회담': 28,
#          '수출': 28,
#          '외교': 28,
#          '전략': 28,
#          '추진': 27,
#          '신규': 27,
#          '지속': 27,
#          '동맹국': 27,
#          '중국산': 27,
#          '대비': 27,
#          '및': 27,
#          '말': 27,
#          '오후': 26,
#          '오전': 26,
#          '부터': 26,
#          '집권': 26,
#          '회담': 26,
#          '통상': 26,
#          '첫': 26,
#          '자국': 26,
#          '광물': 25,
#          '관계': 25,
#          '내': 25,
#          '다시': 25,
#          '결정': 25,
#          '율': 25,
#          '뒤': 25,
#          '또': 25,
#          '물가': 25,
#          '여파': 25,
#          '자산': 25,
#          '마감': 24,
#          '문제': 24,
#          '방위': 24,
#          '운하': 23,
#          '러시아': 23,
#          '정상': 23,
#          '합리': 23,
#          '저': 23,
#          '뭔가': 23,
#          '철강': 23,
#          '자동차': 23,
#          '테슬라': 23,
#          '러트닉': 23,
#          '위': 22,
#          '측': 22,
#          '촉발': 22,
#          '정치': 22,
#          '주가': 22,
#          '대로': 22,
#          '예상': 22,
#          '대만': 22,
#          '증권': 21,
#          '안': 21,
#          '파나마': 21,
#          '원조': 21,
#          '라며': 21,
#          '오늘': 21,
#          '폭탄': 21,
#          '경고': 21,
#          '자신': 21,
#          '앞서': 21,
#          '달': 21,
#          '합동': 20,
#          '목표': 20,
#          '확대': 20,
#          '장': 20,
#          '수준': 20,
#          '기자회견': 20,
#          '기술': 20,
#          '존': 20,
#          '비': 20,
#          '세': 20,
#          '주장': 19,
#          '은': 19,
#          '가자지구': 19,
#          '구상': 19,
#          '악화': 19,
#          '스': 19,
#          '서명': 19,
#          '약': 19,
#          '생산': 19,
#          '면서': 18,
#          '일부': 18,
#          '동맹': 18,
#          '안보': 18,
#          '상응': 18,
#          '금': 18,
#          '비판': 18,
#          '갈등': 18,
#          '유로화': 18,
#          '연': 18,
#          '거래': 18,
#          '전일': 18,
#          '소비자': 18,
#          '향': 18,
#          '수입': 18,
#          '머스크': 18,
#          '인용': 17,
#          '올해': 17,
#          '대표': 17,
#          '블룸버그': 17,
#          '주': 17,
#          '비트코인': 17,
#          '아랍': 17,
#          '짓': 17,
#          '업체': 17,
#          '상품': 17,
#          '나토': 17,
#          '상': 16,
#          '하원': 16,
#          '포함': 16,
#          '속': 16,
#          '강조': 16,
#          '인터뷰': 16,
#          '규모': 16,
#          '상무부': 16,
#          '상국': 16,
#          '가상': 16,
#          '소셜': 16,
#          '제공': 16,
#          '후보자': 16,
#          '대상': 16,
#          '확산': 16,
#          '상대': 15,
#          '모두': 15,
#          '콜비': 15,
#          '생각': 15,
#          '일': 15,
#          '처음': 15,
#          '하워드': 15,
#          '리스크': 15,
#          '틱톡': 15,
#          '보이': 15,
#          '조만간': 15,
#          '회장': 15,
#          '합의': 14,
#          '제시': 14,
#          '회사': 14,
#          '격화': 14,
#          '유예': 14,
#          '타격': 14,
#          '대선': 14,
#          '지역': 14,
#          '트루': 14,
#          '금리': 14,
#          '폭': 14,
#          '협력': 14,
#          '중심': 14,
#          '계속': 14,
#          '충격': 14,
#          '기존': 14,
#          '통제': 14,
#          '통화': 14,
#          '양상': 13,
#          '힘': 13,
#          '멜라': 13,
#          '니아': 13,
#          '변화': 13,
#          '논의': 13,
#          '위기': 13,
#          '때문': 13,
#          '입장': 13,
#          '강세': 13,
#          '이상': 13,
#          '현재': 13,
#          '일본': 13,
#          '성장': 13,
#          '전면': 13,
#          '경우': 13,
#          '대형': 13,
#          '종전': 13,
#          '간': 13,
#          '론': 13,
#          '비축': 13,
#          '유지': 13,
#          '이집트': 13,
#          '거래소': 12,
#          '제재': 12,
#          '선': 12,
#          '의지': 12,
#          '가시': 12,
#          '소식': 12,
#          '사업': 12,
#          '여사': 12,
#          '업계': 12,
#          '공개': 12,
#          '재선': 12,
#          '전기차': 12,
#          '더욱': 12,
#          '인': 12,
#          '이전': 12,
#          '방침': 12,
#          '사실': 12,
#          '규제': 12,
#          '투자자': 12,
#          '반발': 12,
#          '파행': 12,
#          '연맹': 12,
#          '나선': 12,
#          '완화': 11,
#          '해외': 11,
#          '국제': 11,
#          '요구': 11,
#          '또한': 11,
#          '다른': 11,
#          '연구원': 11,
#          '줄': 11,
#          '자유': 11,
#          '발언': 11,
#          '위협': 11,
#          '시위': 11,
#          '작년': 11,
#          '주민': 11,
#          '최고경영자': 11,
#          '상대로': 11,
#          '소셜미디어': 11,
#          '모습': 11,
#          '일제': 11,
#          '언급': 11,
#          '가장': 11,
#          '원': 11,
#          '침체': 11,
#          '북한': 11,
#          '당시': 11,
#          '직후': 11,
#          '두': 11,
#          '리플': 11,
#          '무기': 11,
#          '환경': 11,
#          '이자': 11,
#          '한편': 11,
#          '각각': 11,
#          '즉시': 11,
#          '푸틴': 11,
#          '이란': 11,
#          '스타': 11,
#          '전하': 10,
#          '밴스': 10,
#          '심리': 10,
#          '국민': 10,
#          '첫날': 10,
#          '시대': 10,
#          '확정': 10,
#          '지지': 10,
#          '행보': 10,
#          '운영': 10,
#          '도': 10,
#          '제도': 10,
#          '엔비디아': 10,
#          '진행': 10,
#          '휴전': 10,
#          '다만': 10,
#          '유통업체': 10,
#          '향후': 10,
#          '현실': 10,
#          '체결': 10,
#          '농산물': 10,
#          '강경': 10,
#          '앞': 10,
#          '환수': 10,
#          '이제': 10,
#          '장면': 10,
#          '방향': 10,
#          '안팎': 9,
#          '격': 9,
#          '뜻': 9,
#          '방송': 9,
#          '동안': 9,
#          '강화': 9,
#          '자유무역': 9,
#          '국방': 9,
#          '정도': 9,
#          '비롯': 9,
#          '고조': 9,
#          '낼': 9,
#          '평가': 9,
#          '공급망': 9,
#          '인플레이션': 9,
#          '연내': 9,
#          '그룹': 9,
#          '공식': 9,
#          '기구': 9,
#          '북미': 9,
#          '약속': 9,
#          '안전': 9,
#          '사전': 9,
#          '다음': 9,
#          '유감': 9,
#          '시사': 9,
#          '증가': 9,
#          '서비스': 9,
#          '행정명령': 9,
#          '실제': 9,
#          '의사당': 9,
#          '관심': 9,
#          '조정': 9,
#          '우리나라': 9,
#          '공포': 9,
#          '카이로': 9,
#          '인도': 9,
#          '연속': 8,
#          '흐름': 8,
#          '홍콩': 8,
#          '보조금': 8,
#          '타협': 8,
#          '지사': 8,
#          '국방부': 8,
#          '방문': 8,
#          '촉구': 8,
#          '주의': 8,
#          '저가': 8,
#          '유입': 8,
#          '지금': 8,
#          '개발': 8,
#          '나라': 8,
#          '패권': 8,
#          '점': 8,
#          '대책': 8,
#          '기관': 8,
#          '벌이': 8,
#          '사': 8,
#          '허치슨': 8,
#          '최대': 8,
#          '단행': 8,
#          '출처': 8,
#          '주목': 8,
#          '폭락': 8,
#          '변동성': 8,
#          '준': 8,
#          '직접': 8,
#          '나스닥': 8,
#          '매수': 8,
#          '감축': 8,
#          '중이': 8,
#          '기사': 8,
#          '금융': 8,
#          '이유': 8,
#          '감소': 8,
#          '적극': 8,
#          '브라이언': 8,
#          '건': 8,
#          '선언': 8,
#          '약세': 8,
#          '며칠': 8,
#          '역시': 8,
#          '이투데이': 8,
#          '방안': 8,
#          '입항': 8,
#          '미군': 8,
#          '부진': 8,
#          '정당성': 8,
#          '불법': 8,
#          '설전': 8,
#          '회견': 8,
#          '희망': 7,
#          '양국': 7,
#          '정상화': 7,
#          '금지': 7,
#          '포드': 7,
#          '담당': 7,
#          '위험': 7,
#          '의욕': 7,
#          '해결': 7,
#          '월스트리트저널': 7,
#          '이민자': 7,
#          '급등': 7,
#          '매체': 7,
#          '움직임': 7,
#          '공격': 7,
#          '오타와': 7,
#          '경쟁': 7,
#          '마약': 7,
#          '울산': 7,
#          '반납': 7,
#          '시': 7,
#          '각국': 7,
#          '요인': 7,
#          '수요': 7,
#          '이주': 7,
#          '배': 7,
#          '인수': 7,
#          '웨이': 7,
#          '저자': 7,
#          '혼란': 7,
#          '의존': 7,
#          '셰인': 7,
#          '바움': 7,
#          '환율': 7,
#          '감사': 7,
#          '관': 7,
#          '공급': 7,
#          '이틀': 7,
#          '책': 7,
#          '개': 7,
#          '눈': 7,
#          '제철': 7,
#          '건설': 7,
#          '채': 7,
#          '탓': 7,
#          '전문가': 7,
#          '공중': 7,
#          '코인': 7,
#          '핵': 7,
#          '카드': 7,
#          '우선주': 7,
#          '일방': 7,
#          '지시': 7,
#          '조': 7,
#          '바이든': 7,
#          '최고': 7,
#          '겹친': 7,
#          '전반': 7,
#          '수위': 7,
#          '여러': 7,
#          '품목': 7,
#          '반영': 7,
#          '대한민국': 7,
#          '압력': 7,
#          '계약': 7,
#          '사회': 7,
#          '기조': 7,
#          '바': 7,
#          '전화': 7,
#          '노조': 7,
#          '펜타닐': 7,
#          '에너지': 7,
#          '다우존스': 6,
#          '평균': 6,
#          '마무리': 6,
#          '차례': 6,
#          '근거': 6,
#          '항만': 6,
#          '장기': 6,
#          '보호무역': 6,
#          '타깃': 6,
#          '연합': 6,
#          '중인': 6,
#          '엘': 6,
#          '브리지': 6,
#          '차관': 6,
#          '스타일': 6,
#          '부통령': 6,
#          '관리': 6,
#          '팔레스타인': 6,
#          '참여': 6,
#          '위원회': 6,
#          '코': 6,
#          '인텔': 6,
#          '그래프': 6,
#          '공장': 6,
#          '경쟁력': 6,
#          '마련': 6,
#          '시청': 6,
#          '개최': 6,
#          '거의': 6,
#          '대가': 6,
#          '베스트': 6,
#          '상무': 6,
#          '베스트바이': 6,
#          '서도': 6,
#          '임기': 6,
#          '예산': 6,
#          '악재': 6,
#          '질문': 6,
#          '아주경제': 6,
#          '추락': 6,
#          '치': 6,
#          '분야': 6,
#          '법': 6,
#          '축소': 6,
#          '유가': 6,
#          '정보': 6,
#          '비용': 6,
#          '인하': 6,
#          '포인트': 6,
#          '해상': 6,
#          '제안': 6,
#          '개월': 6,
#          '등장': 6,
#          '보장': 6,
#          '함': 6,
#          '주식시장': 6,
#          '자정': 6,
#          '나': 6,
#          '배터리': 6,
#          '인근': 6,
#          '긍정': 6,
#          '검토': 6,
#          '파리': 6,
#          '전환': 6,
#          '앵커': 6,
#          '질서': 6,
#          '조선': 6,
#          '국채': 6,
#          '기록': 6,
#          '집무실': 6,
#          '항모': 6,
#          '곧': 6,
#          '처': 6,
#          '제한': 6,
#          '민주당': 6,
#          '재작년': 6,
#          '요동': 6,
#          '기적': 6,
#          '머': 6,
#          '특별': 6,
#          '풀이': 6,
#          '예외': 6,
#          '장벽': 6,
#          '명의': 6,
#          '집중': 6,
#          '인공': 6,
#          '지능': 6,
#          '전차': 6,
#          '미사일': 6,
#          '석유': 6,
#          '대우': 5,
#          '인사': 5,
#          '골프': 5,
#          '프로그램': 5,
#          '개선': 5,
#          '왼쪽': 5,
#          '발생': 5,
#          '복귀': 5,
#          '정장': 5,
#          '관측': 5,
#          '자체': 5,
#          '재건': 5,
#          '전문': 5,
#          '반등': 5,
#          '제기': 5,
#          '루트': 5,
#          '닉': 5,
#          '가속': 5,
#          '보유': 5,
#          '길': 5,
#          '비상': 5,
#          '시가': 5,
#          '당일': 5,
#          '폭풍': 5,
#          '수장': 5,
#          '반': 5,
#          '방어': 5,
#          '전작권': 5,
#          '후보': 5,
#          '온': 5,
#          '기간': 5,
#          '지구': 5,
#          '자료': 5,
#          '설명': 5,
#          '실적': 5,
#          '클라우디아': 5,
#          '만': 5,
#          '천명': 5,
#          '보편': 5,
#          '과잉': 5,
#          '기해': 5,
#          '내용': 5,
#          '금지법': 5,
#          '동부': 5,
#          '대신': 5,
#          '식': 5,
#          '어제': 5,
#          '하나': 5,
#          '뉴스': 5,
#          '도입': 5,
#          '영상': 5,
#          '피': 5,
#          '물': 5,
#          '적용': 5,
#          '미국인': 5,
#          '개편': 5,
#          '캐즘': 5,
#          '대외': 5,
#          '필요': 5,
#          '임명': 5,
#          '성사': 5,
#          '망': 5,
#          '끝': 5,
#          '긴장': 5,
#          '설립': 5,
#          '칼빈슨함': 5,
#          '오': 5,
#          '일시': 5,
#          '초유': 5,
#          '말다툼': 5,
#          '연출': 5,
#          '타겟': 5,
#          '피해': 5,
#          '하우스': 5,
#          '여지': 5,
#          '만약': 5,
#          '누군가': 5,
#          '단속': 5,
#          '집행': 5,
#          '논란': 5,
#          '군복': 5,
#          '규정': 5,
#          '로비': 5,
#          '지난주': 5,
#          '링크': 5,
#          '블라디미르': 5,
#          '협의': 5,
#          '불구': 5,
#          '필요성': 5,
#          '전혀': 5,
#          '장주': 5,
#          '진단': 5,
#          '농': 5,
#          '재블린': 5,
#          '영업': 5,
#          '미로': 5,
#          '김민정': 5,
#          '세상': 4,
#          '전장': 4,
#          '언론': 4,
#          '임박': 4,
#          '투어': 4,
#          '부담': 4,
#          '해제': 4,
#          '대변인': 4,
#          '관해': 4,
#          '얘기': 4,
#          '청': 4,
#          '온타리오': 4,
#          '판매': 4,
#          '한미': 4,
#          '탈': 4,
#          '고려': 4,
#          '재림': 4,
#          '설계': 4,
#          '지명자': 4,
#          '실어': 4,
#          '그것': 4,
#          '방법': 4,
#          '포스코': 4,
#          '주말': 4,
#          '뿐': 4,
#          '지도자': 4,
#          '리움': 4,
#          '기반': 4,
#          '제거': 4,
#          '오히려': 4,
#          '수혜': 4,
#          '과도': 4,
#          '권': 4,
#          '보고서': 4,
#          '레': 4,
#          '하루': 4,
#          '간밤': 4,
#          '당장': 4,
#          '내일': 4,
#          '사가': 4,
#          '공화당': 4,
#          '자리': 4,
#          '산시': 4,
#          '유관': 4,
#          '알루미늄': 4,
#          '단독': 4,
#          '관계자': 4,
#          '점도': 4,
#          '부각': 4,
#          '휴양지': 4,
#          '자산운용': 4,
#          '블랙록': 4,
#          '매각': 4,
#          '불안': 4,
#          '연휴': 4,
#          '폭스뉴스': 4,
#          '글': 4,
#          '판단': 4,
#          '막판': 4,
#          '누구': 4,
#          '지적': 4,
#          '주식': 4,
#          '게': 4,
#          '경제학자': 4,
#          '부정': 4,
#          '상원': 4,
#          '인사청문회': 4,
#          '사과': 4,
#          '결렬': 4,
#          '직면': 4,
#          '사설': 4,
#          '협회': 4,
#          '회': 4,
#          '여기': 4,
#          '폐지': 4,
#          '미래': 4,
#          '새': 4,
#          '크게': 4,
#          '역대': 4,
#          '지점': 4,
#          '수도': 4,
#          '목전': 4,
#          '대감': 4,
#          '과정': 4,
#          '일간': 4,
#          '친': 4,
#          '탄핵': 4,
#          '악': 4,
#          '사람': 4,
#          '격화되': 4,
#          '연기': 4,
#          '대충': 4,
#          '곳': 4,
#          '해당': 4,
#          '위축': 4,
#          '효과': 4,
#          '전시': 4,
#          '국민총생산': 4,
#          '수익률': 4,
#          '공언': 4,
#          '일단': 4,
#          '듯': 4,
#          '서울': 4,
#          '역할': 4,
#          '외신': 4,
#          '거': 4,
#          '차': 4,
#          '중앙': 4,
#          '여왕': 4,
#          '엘리자베스': 4,
#          '유력': 4,
#          '정치인': 4,
#          '기업가': 4,
#          '직수출': 4,
#          '남자': 4,
#          '재벌': 4,
#          '이익': 4,
#          '실세': 4,
#          '멕': 4,
#          '공세': 4,
#          '변수': 4,
#          '보': 4,
#          '마': 4,
#          '무시': 4,
#          '해명': 4,
#          '체제': 4,
#          '특별법': 4,
#          '토': 4,
#          '전통': 4,
#          '부산': 4,
#          '만이': 4,
#          '코넬': 4,
#          '일보': 4,
#          '매입': 4,
#          '각서': 4,
#          '브래드': 4,
#          '링': 4,
#          '총': 4,
#          '혜택': 4,
#          '성은': 4,
#          '파국': 4,
#          '동시': 4,
#          '행동': 4,
#          '행사': 4,
#          '동의': 4,
#          '확인': 4,
#          '자': 4,
#          '상당': 4,
#          '조처': 4,
#          '언쟁': 4,
#          '핵심': 4,
#          '헤럴드경제': 4,
#          '권력': 4,
#          '변국': 4,
#          '인터넷': 4,
#          '대규모': 4,
#          '우산': 4,
#          '약화': 4,
#          '교수': 4,
#          '효율': 4,
#          '기회': 4,
#          '강압': 4,
#          '교역': 4,
#          '표명': 4,
#          '환영': 4,
#          '표현': 4,
#          '철회': 4,
#          '김여정': 4,
#          '부분': 4,
#          '성향': 4,
#          '우군': 4,
#          '중견': 4,
#          '구조조정': 4,
#          '기지': 4,
#          '고문': 4,
#          '서방': 4,
#          '태': 4,
#          '국무원': 3,
#          '각종': 3,
#          '비리': 3,
#          '타결': 3,
#          '통합': 3,
#          '나이': 3,
#          '절': 3,
#          '개혁당': 3,
#          '출신': 3,
#          '소유': 3,
#          '국내외': 3,
#          '페': 3,
#          '스코프': 3,
#          '사장': 3,
#          '물동량': 3,
#          '태양광': 3,
#          '더그': 3,
#          '국무부': 3,
#          '부차': 3,
#          '관보': 3,
#          '회피': 3,
#          '경감': 3,
#          '난민': 3,
#          '눈길': 3,
#          '차림': 3,
#          '급변': 3,
#          '정세': 3,
#          '도부': 3,
#          '도세': 3,
#          '의사': 3,
#          '신청': 3,
#          '매도': 3,
#          '채택': 3,
#          '다수': 3,
#          '외': 3,
#          '김병연': 3,
#          '추방': 3,
#          '전역': 3,
#          '미대': 3,
#          '주력': 3,
#          '처지': 3,
#          '달러화': 3,
#          '승리': 3,
#          '시절': 3,
#          '재무': 3,
#          '테이블': 3,
#          '선포': 3,
#          '불법체류자': 3,
#          '거짓': 3,
#          '본관': 3,
#          '회의실': 3,
#          '최저': 3,
#          '캘리포니아주': 3,
#          '밖': 3,
#          '이슈': 3,
#          '다가': 3,
#          '앤드': 3,
#          ...})

# %%
# 임시 딕션너리에 담아서, 필요한 부분 추출해서 조사. 
word_count = dict()

# 상위 80개 정도 
for tag, counts in count.most_common(80):
  if(len(str(tag))>1):
    word_count[tag] = counts
    # print(f" tag : {tag}, counts : {counts}")
word_count
# Out:
# {'트럼프': 1776,
#  '대통령': 1162,
#  '미국': 1001,
#  '관세': 946,
#  '도널드': 692,
#  '캐나다': 447,
#  '부과': 338,
#  '멕시코': 305,
#  '행정부': 287,
#  '현지': 240,
#  '시간': 226,
#  '중국': 207,
#  '전쟁': 186,
#  '정책': 160,
#  '대한': 155,
#  '보복': 153,
#  '우크라이나': 134,
#  '렌스': 100,
#  '이후': 91,
#  '대해': 90,
#  '무역': 88,
#  '수입품': 84,
#  '한국': 83,
#  '총리': 81,
#  '트뤼': 77,
#  '우려': 75,
#  '발표': 71,
#  '영향': 70,
#  '추가': 70,
#  '가운데': 68,
#  '하락': 66,
#  '예고': 66,
#  '정부': 65,
#  '백악관': 65,
#  '발효': 64,
#  '경제': 62,
#  '뉴욕': 61,
#  '조치': 61,
#  '준비': 61,
#  '대응': 60,
#  '협정': 59,
#  '지난달': 58,
#  '지난': 57,
#  '시장': 57,
#  '중단': 55,
#  '본격': 50,
#  '시작': 48,
#  '회의': 48,
#  '취임': 48,
#  '상호': 48,
#  '미르': 48,
#  '로디': 47,
#  '글로벌': 46,
#  '우리': 46,
#  '화폐': 46,
#  '뉴욕증시': 44,
#  '위해': 44,
#  '로이터': 43,
#  '장관': 43,
#  '암호': 43,
#  '기자': 43,
#  '사진': 42}

# %%
# 시각화1, 막대 그래프 
# 폰트 임포트 , 메모리에 설정 
font_path = "c:/Windows/Fonts/malgunbd.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
matplotlib.rc("font", family = font_name)

#, x축, y축, 가로x세로 비율, x 라벨, 폰트 설정 등
plt.figure(figsize=(12,6))
plt.xlabel("키워드")
plt.ylabel("빈도수")
plt.grid(True)

# 딕션너리의 키, 값 , 정렬 내림차순 
sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorted_Values = sorted(word_count.values(),reverse=True)

# 막대 그래프 그리기. 
plt.bar(range(len(word_count)), sorted_Values, align="center")

# x 축 라벨 설정. 
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = "vertical")

plt.show()

# %%
# !pip install Numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Numpy in c:\users\it\appdata\roaming\python\python310\site-packages (2.0.1)

# %%
# 시각화2, 워드 클라우드 
import numpy as np

import os
import re
from PIL import Image
from os import path

alice_mask = np.array(Image.open("dog-test2-sh.png"))

# 실행시, 한글이 깨져서, 해당 폰트 패스 경로 지정 필요.
wc = WordCloud(font_path, background_color="white", max_words=1000, mask=alice_mask,width=800,height=1000)
# generate word cloud
sampleImage = wc.generate_from_frequencies(word_count)

# show
plt.imshow(sampleImage, interpolation="bilinear")
# plt.imshow(sampleImage)

plt.axis("off")
plt.show()

# %%
# 해당 출력을 이미지로 저장 하기. 
sampleImage.to_file(inputFileName + "_cloud.jpg")
